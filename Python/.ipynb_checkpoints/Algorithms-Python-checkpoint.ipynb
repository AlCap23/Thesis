# %%
import numpy as np

# %%
## Define the Area Fit Method
def Area_Fit(y,u,t):
    """Returns a FOTD Model from the given data.
    y - array of outputs
    u - array of inputs
    t - array of time values
    """
    # Truncate for Maximum
    i_end = abs(y).argmax(axis=0)
    yp = y[0:i_end+1]
    up = u[0:i_end+1]
    tp = t[0:i_end+1]
    # Get Gain
    KM = (yp[-1]-yp[0])/(up[-1])
    # Get the Residence Time
    Tar = 1/KM * np.trapz(yp[-1]-yp,tp)
    # Time Constant
    T = np.exp(1)/KM*np.trapz(yp[np.where(tp<=Tar)],tp[np.where(tp<=Tar)])
    # Delay
    L = Tar-T
    # Check if all arguments are valid
    if (T < 0):
        print("Error - Negative lag")
        return -1
    if (L < 0):
        if (L < 1e-2):
            L = 0
        else:    
            print("Error - Negative delay")
            return -1
    return KM,T,L

# %%
# Define the AMIGO Tuning
def AMIGO_Tune(K,T,L, structure = 'PI'):
    """Computes the PI(D) controller parameter based on AMIGO algorithm;
       Parameter are returned as parallel notation KP,KI,KD and set point;
       Needs first order time delay parameter as input
    """
    # Check for small delay
    if L < 1e-1:
        L = 1e-1
    # PI Controller
    if structure == 'PI':
        # Parameter as Defined in Aström et. al., Advanced PID Control,p.229 
        KP = 0.15/K + (0.35 - L*T /(L+T)**2)*T/(K*L)
        TI = 0.35*L+(13*L*T**2)/(T**2+12*L*T+7*L**2)
        TD = 0.0
        # Set Point Weight, as given on p.235
        if L/(T+L) > 0.5:
            b = 1
        else:
            b = 0.0
        
    elif structure == 'PID':
        KP = 1/K*(0.2+0.45*T/L)
        TI = (0.4*L + 0.8*T)/(L+0.1*T)*L
        TD = (0.5*L*T)/(0.3*L+T)
        # Set Point Weight, Derived from Fig. 7.2, p. 230
        if L/(T+L) < 0.2:
            b = 0.4
        elif L/(T+L) > 0.3:
            b = 1.0
        else:
            # Approximate as Linear Function
            b = 0.4 + (1.0 - 0.4)/(0.3-0.2)*L/(T+L)
    else:
        print("Undefined controller Structure")
        return np.NaN
    KI = KP/TI
    KD = KP*TD
    return [KP,KI,KD],b

# Define AMIGO Detuning
def AMIGO_DETUNE(K,T,L,params,KP, MS = 1.4, structure = 'PI'):
    """Detunes the AMIGO parameter according to Astrom"""
    # Check for small delay
    if L < 1e-1:
        L = 1e-1
    # Needed Parameter
    alpha_D = (MS-1)/MS # See p.255 Eq. 7.19
    beta_D = MS*(MS+np.sqrt(MS**2-1))/2# See p.257 Eq. 7.24
    
    # Define old set of parameter
    KP0 = params[0]
    KI0 = params[1]
    KD0 = params[2]
    
    if structure=='PI':
        # Needed constrain for switch case,See p. 258 Eq. 7.27
        c = KP*K - KP0*K*(L+T)/(beta_D*(alpha_D+KP*K)) - alpha_D
        if c < 0:
            KI = beta_D*(alpha_D+KP*K)**2/(K*(L+T))
        else:
            KI = KI0*(alpha_D+KP*K)/(alpha_D+KP0*K)
        return [KP,KP/KI,0.0]
    if structure == 'PID':
        print("Not implemented")
        return np.NaN
    else:
        print("Undefined controller Structure")
        return np.NaN

# %%
def RGA(K,T,L,w=0):
    """Takes a FOTD System and computes the RGA of the system"""
    if (K.shape != T.shape) or (K.shape != L.shape) or (L.shape != T.shape):
        print("Shapes of parameter array are not equal!")
    # Compute the System
    G = np.absolute(FOTD_IMAG(K,T,L,w))
    # Calculate the RGA
    RGA = np.multiply(G, np.transpose(np.linalg.inv(G)))
    return RGA

# %%
def FOTD_IMAG(K,T,L,w=0):
    """Creates a FOTD MIMO system from the parameter matrices and the current frequency"""
    # Check if all dimensions match
    if (K.shape != T.shape) or (K.shape != L.shape) or (L.shape != T.shape):
        print("Shapes of parameter array are not equal!")
        return np.NaN
    # System Dimension
    if K.ndim == 1:
        # Using system Identity by multiplying with the complex conjugate
        G = 1/(T**2 * w**2 +1)*(K-1j*T*w)*(np.cos(-L*w)+1j*np.sin(-L*w))
    else:
        outputs,inputs = K.shape
        # Create a system within the complex numbers
        G = np.zeros_like(K)
        for i in range(0,inputs):
            for o in range(0,outputs):
                # Using system Identity by multiplying with the complex conjugate
                G[o][i] = 1 /(T[o][i]**2 * w**2 +1) * ( K[o][i] - 1j*T[o][i]*w) *(np.cos(-L[o][i]*w)+1j*np.sin(-L[o][i]*w))
    return G

# %%
def Control_Decentral(K,T,L, w = 0, b=np.empty, structure = 'PI'):
    """ Computes decentralised controller with AMIGO algorithm based on RGA pairing"""
    # Compute SISO Case
    if K.ndim <= 1:
        # Using system Identity by multiplying with the complex conjugate
        params, b0 = AMIGO_Tune(K,T,L)
        # If b is not given, use b from AMIGO
        if b == np.empty:
            Kr = [b0*params[0], params[1], params[2]]
            Ky = params
        else:
            Kr = [b*params[0],params[1],params[2]]
            Ky = params
    # Compute general MIMO Case
    else:
        # Systems dimensions
        outputs,inputs = K.shape
        # Create an empty controller
        Ky = np.empty([outputs,inputs,3])
        Kr = np.empty([outputs,inputs,3])
        # Compute RGA -> Checks for Shape
        LG = RGA(K,T,L,w)
        # Get Pairing as an array for every column
        Pairing = np.argmax(LG, axis=0)
        # Iterate through the pairing
        for o in range(0,outputs):
            # Best Pairing
            i = Pairing[o]
            # Compute controller via recursion
            Ky[o][i],Kr[o][i] = Control_Decentral(K[o][i],T[o][i],L[o][i],b)
    return Ky, Kr

def Control_Astrom(K,T,L,H, MS= None, w = 0, b=np.empty, structure = 'PI'):
    """Computes a Decoupling Controller via Aström Algortihm based on FOTD"""
    # Check Input for Maximum Sensitivity
    if MS is None:
        MS = 1.4*np.eye(K.shape[0],K.shape[1])
    # Compute Determinant of Maximum Sensitivity
    ms = np.linalg.det(MS)
    # Compute SISO Case
    if K.ndim <= 1:
        return Control_Decentral(K,T,L,w,b,structure)
    # Compute General MIMO Case
    else:
        # Systems dimensions
        outputs,inputs = K.shape
        # Check dimensions
        if (K.shape != T.shape) or (K.shape != H.shape) or (K.shape != MS.shape) or (K.shape != L.shape) or (L.shape != T.shape):
            print("Shapes of parameter array are not equal!")
            return np.NaN
        
        # Create an empty controller
        Ky = np.empty([outputs,inputs,3])
        Kr = np.empty([outputs,inputs,3])
               
        # Get minimal Delay/ Time Constant for robust limit of crossover frequency, ignore zeros
        if (L[np.where(L>0)].size !=0) or (T[np.where(T>0)].size !=0):
            if (L[np.where(L>0)].size !=0):
                wc_min = np.min([np.min(L[np.nonzero(L)]),np.min(T[np.nonzero(T)])])
            else:
                wc_min = np.min(np.min(T[np.nonzero(T)]))
        else:
            # Use very high frequency
            wc_min = 1e10
        
        # Compute the decoupler
        D = np.linalg.inv(K)
        # Compute the interaction indeces
        # Since d/ds(Q*K) = d/ds(Q)*K = d/ds(G) we can write the Taylor coefficient
        Gamma = np.abs(np.dot(np.multiply(-K,T+L),D))
        # Set main diagonal to zero
        np.fill_diagonal(Gamma,0)
        # Get the maximum of each row
        GMax = np.argmax(Gamma,axis=0)
        # Iterate through the outputs 
        for o in range(0,outputs):
            # Estimate the new system parameter
            # Get the maximal gain
            l = np.max(L[o][:])
            # Add the systems gain -> scaled
            k = np.dot(K[o][:],D[:][o])
            # Get the system time constant
            t = np.sum(np.multiply(np.multiply(K[o][:],D[:][o]),T[o][:]+L[o][:]))/k - l
            
            # Design a controller based on estimated system
            ky,kr = Control_Decentral(k,t,l,w,b,structure)
            
            # Test for Interaction
            
            # Current maximum interaction
            gmax = Gamma[o][GMax[o]]
            # Check for set point weight, either given
            if b == np.empty:
                # Or computed from AMIGO_TUNE
                b = kr[0]/ky[0]
            # Check for structure
            if structure == 'PI':
                # Set counter for while
                counter=0
                # Set shrinking rate in accordance with golden ratio
                shrink_rate = 0.618
                while (np.abs(H[o][o]/(ms*gmax)) - np.sqrt( (b*ky[0]/wc_min)**2 + ky[1]**2 ) < 0):
                    if counter > 10:
                        #print('Maximal Iteration for detuning reached! Abort')
                        break
                    # Detune the controller with the shrinking rate    
                    ky = AMIGO_DETUNE(k,t,l,ky,shrink_rate*ky[0])
                    # Increment counter
                    counter += 1
                # Get the controller parameter
                Ky[o][o][:] = ky
                Kr[o][o][:] = [b*ky[0], ky[1], ky[2]]
        # Rescale controller for real system
        for c in range(0,2):
            Ky[:][:][c] = np.dot(D,Ky[:][:][c])
            Kr[:][:][c] = np.dot(D,Kr[:][:][c])
        return Ky,Kr

# %% [markdown]
# # Test Area
# ### Testing the Algorithm on robustness etc

# %%
# Import the needed packages
# python control for LTI systems
import control as cn
# Import bokeh for Ploting
import bokeh.plotting as bk
import bokeh.io as bi
bi.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a5416dcf-6e84-4a66-b799-f3f996eef60b">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### SISO Test
# Testing Identification / AMIGO Tuning / AMIGO Detuning

# %%
# Test Identification
# Make a system
num = [1,0,20]
den = [50,10,1]
G = cn.tf(num,den)
G = G*G
# Step response
t = np.linspace(0,100,500)
y,t = cn.matlab.step(G,t)
# Add noise
y = y +np.random.normal(0,0.3,np.size(y))
u = np.ones_like(y)
# Parameter
K,T,L = Area_Fit(y,u,t)
num,den = cn.pade(L,15)
GM = cn.tf([K],[T,1])*cn.tf(num,den)
yM,tM = cn.matlab.step(GM, t)
# Plot
p1 = bk.figure()
p1.line(t,y, line_color= "tomato")
p1.line(tM,yM)
p1.circle(t[abs(y).argmax(axis=0)],y[abs(y).argmax(axis=0)], fill_color='orange', size=10)
bk.show(p1)

# Calculate the controller
params, b = AMIGO_Tune(K,T,L)
ky = cn.tf([params[0]],[1])+cn.tf([params[1]],[1,0])
kr = cn.tf([params[1]],[1,0])
cl =cn.feedback(G,ky)*kr
yc,tc = cn.step(cl)
# Plot
p2 = bk.figure()
p2.line(tc,yc, line_color= "tomato")
bk.show(p2)

# Find the Maximum Sensitivity
# Compute sensitivity
S = 1/(1+G*ky)
# compute the gain of the sensitivity
w = np.logspace(-5,5,1000)
mag, phase, freq = cn.matlab.bode(S,w)
MS = np.max(mag)

# Make a plot
p3= bk.figure(x_axis_type="log")
p3.line(freq,mag)
bk.show(p3)

#Detune the controller -> DOES NOT WORK!!! WHY!?
params = AMIGO_DETUNE(K,T,L,params, params[0])
ky2 = cn.tf([params[0]],[1])+cn.tf([params[1]],[1,0])
kr2 = cn.tf([params[1]],[1,0])
cl2 =cn.feedback(G,ky2)*kr2
yc2,tc2 = cn.step(cl2)
# Plot
p4 = bk.figure()
p4.line(tc,yc)
p4.line(tc2,yc2, line_color= "tomato")
bk.show(p4)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ad159ba0-266c-4c7b-9a1c-5b3a5fd135a8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ad159ba0-266c-4c7b-9a1c-5b3a5fd135a8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ad159ba0-266c-4c7b-9a1c-5b3a5fd135a8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ad159ba0-266c-4c7b-9a1c-5b3a5fd135a8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"813310a6-0e36-45b9-91b4-a62984ecb292":{"roots":{"references":[{"attributes":{},"id":"8fd23e1d-d379-420e-92dd-6455baf5793c","type":"BasicTickFormatter"},{"attributes":{},"id":"a3dfe0e7-c71b-4043-aca3-b3a0e8d83a70","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"6d7908d0-f057-44be-b811-a45b0ad57bfa","type":"DataRange1d"},{"attributes":{"data_source":{"id":"418b831a-b832-4948-8b1f-0f60036b50ca","type":"ColumnDataSource"},"glyph":{"id":"3c3e873b-679e-428c-abdf-cc91d54a0b60","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8eb37952-6b74-4c1b-abf5-8e00d85c2cf1","type":"Line"},"selection_glyph":null},"id":"4d2e21fc-2231-4771-9854-35094e7d2c22","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"82dc9241-cd4a-4344-bae8-2f0c0f5b96ba","subtype":"Figure","type":"Plot"}},"id":"442bf74e-31fb-4b65-87b0-5c98b60e09f8","type":"WheelZoomTool"},{"attributes":{},"id":"2d427270-b8bd-4506-a6da-4b6097c80530","type":"BasicTicker"},{"attributes":{"data_source":{"id":"3bd94f89-d6d0-4349-86b1-c0aef81587c3","type":"ColumnDataSource"},"glyph":{"id":"baa6bc48-0150-4d69-afae-70ea496ea664","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8463a79e-970d-4b38-abc8-14692722103e","type":"Line"},"selection_glyph":null},"id":"c5ff2e32-eccd-459a-9329-be5378bfcef6","type":"GlyphRenderer"},{"attributes":{},"id":"1c54dc6a-251a-4fa8-9cae-6e5a6312cd1a","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"82dc9241-cd4a-4344-bae8-2f0c0f5b96ba","subtype":"Figure","type":"Plot"},"ticker":{"id":"048663f2-6dee-4761-a214-6f90fc225664","type":"BasicTicker"}},"id":"088bf82d-8dd0-4834-89d2-1aa6a11ff07a","type":"Grid"},{"attributes":{"fill_color":{"value":"orange"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"value":44.28857715430862},"y":{"value":425.2040621890663}},"id":"619211b1-7d99-4e18-bcf8-e174afa1e968","type":"Circle"},{"attributes":{"below":[{"id":"2ba27882-a895-446c-9cd9-cac59f99a48a","type":"LinearAxis"}],"left":[{"id":"a75a031c-05c7-467f-a59b-d98ccbfc1d58","type":"LinearAxis"}],"renderers":[{"id":"2ba27882-a895-446c-9cd9-cac59f99a48a","type":"LinearAxis"},{"id":"fb8ade33-9f13-485d-a268-3b2179a75f7e","type":"Grid"},{"id":"a75a031c-05c7-467f-a59b-d98ccbfc1d58","type":"LinearAxis"},{"id":"088bf82d-8dd0-4834-89d2-1aa6a11ff07a","type":"Grid"},{"id":"b402bd43-ed66-457a-b845-0992a72c88d6","type":"BoxAnnotation"},{"id":"4d2e21fc-2231-4771-9854-35094e7d2c22","type":"GlyphRenderer"},{"id":"c5ff2e32-eccd-459a-9329-be5378bfcef6","type":"GlyphRenderer"},{"id":"0a83d84e-f037-4c77-b7c0-eeb860c0388f","type":"GlyphRenderer"}],"title":{"id":"381c801d-8891-48a1-91d6-f8b0ff2becb5","type":"Title"},"tool_events":{"id":"1c54dc6a-251a-4fa8-9cae-6e5a6312cd1a","type":"ToolEvents"},"toolbar":{"id":"ca9548eb-932f-4338-a66d-2be36bd23090","type":"Toolbar"},"x_range":{"id":"701f7be6-1aec-45c0-b768-2fac18fce951","type":"DataRange1d"},"x_scale":{"id":"6d97e4dd-3797-4c40-bca7-36fa9b70a3a7","type":"LinearScale"},"y_range":{"id":"6d7908d0-f057-44be-b811-a45b0ad57bfa","type":"DataRange1d"},"y_scale":{"id":"faca527d-6620-4f3e-9fb4-d1d2b1c008f7","type":"LinearScale"}},"id":"82dc9241-cd4a-4344-bae8-2f0c0f5b96ba","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"baa6bc48-0150-4d69-afae-70ea496ea664","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8463a79e-970d-4b38-abc8-14692722103e","type":"Line"},{"attributes":{"overlay":{"id":"b402bd43-ed66-457a-b845-0992a72c88d6","type":"BoxAnnotation"},"plot":{"id":"82dc9241-cd4a-4344-bae8-2f0c0f5b96ba","subtype":"Figure","type":"Plot"}},"id":"c27b587e-45f8-41f3-812f-52237b2ee179","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"1111a01e-54c7-46b0-bb86-d68ce1ce74cf","type":"ColumnDataSource"},"glyph":{"id":"619211b1-7d99-4e18-bcf8-e174afa1e968","type":" ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="939fd552-844b-46c1-b7f5-f1a09c6c5761"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("939fd552-844b-46c1-b7f5-f1a09c6c5761");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("939fd552-844b-46c1-b7f5-f1a09c6c5761");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '939fd552-844b-46c1-b7f5-f1a09c6c5761' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c589339a-d675-4f1d-9b0b-1f86823a1b10":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"6c89867a-45c8-4a4e-964d-61ce0c1c41cd","type":"ColumnDataSource"},{"attributes":{},"id":"c62deec6-1201-483c-843a-1203774cf738","type":"LinearScale"},{"attributes":{"dimension":1,"plot":{"id":"74b290c2-2e15-48ee-a36b-8993a707d54d","subtype":"Figure","type":"Plot"},"ticker":{"id":"3994a479-bb63-4ac5-9d88-d73269e0dedb","type":"BasicTicker"}},"id":"4710f958-d107-46c0-a4b3-8d0fa79e85f4","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"ef913143-f9fd-4707-b5dc-1560014caf7d","type":"Title"},{"attributes":{"data_source":{"id":"6c89867a-45c8-4a4e-964d-61ce0c1c41cd","type":"ColumnDataSource"},"glyph":{"id":"69f0d0c7-50c4-483d-ba0e-4ec10f5305c6","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d2c6350b-1c03-4c10-bcfc-70cfbdfd8b4d","type":"Line"},"selection_glyph":null},"id":"f801f780-14c1-4870-a2e0-f922714432aa","type":"GlyphRenderer"},{"attributes":{},"id":"02ddb2a7-a96f-468b-838e-d99040bc75e5","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"02ddb2a7-a96f-468b-838e-d99040bc75e5","type":"BasicTickFormatter"},"plot":{"id":"74b290c2-2e15-48ee-a36b-8993a707d54d","subtype":"Figure","type":"Plot"},"ticker":{"id":"3994a479-bb63-4ac5-9d88-d73269e0dedb","type":"BasicTicker"}},"id":"32e4ee6c-dbd5-4ad8-b995-955bbbb59b42","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a1886b07-f2fa-44b0-af25-a94acbcaa617","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"74b290c2-2e15-48ee-a36b-8993a707d54d","subtype":"Figure","type":"Plot"}},"id":"d48b35ec-a2aa-4f39-b41d-cd94abf29caf","type":"ResetTool"},{"attributes":{"plot":{"id":"74b290c2-2e15-48ee-a36b-8993a707d54d","subtype":"Figure","type":"Plot"}},"id":"579e3b13-292d-473d-b778-ce35877a5053","type":"PanTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"579e3b13-292d-473d-b778-ce35877a5053","type":"PanTool"},{"id":"311ec18b-e6ae-4fd4-9bd0-a1791254652e","type":"WheelZoomTool"},{"id":"d017a7dd-958b-43b8-a4a2-5fe18107446f","type":"BoxZoomTool"},{"id":"324f4039-679d-46e3-ae9c-e0840581d7e1","type":"SaveTool"},{"id":"d48b35ec-a2aa-4f39-b41d-cd94abf29caf","type":"ResetTool"},{"id":"98f05432-6217-4a49-96e5-ce04a0303436","type":"HelpTool"}]},"id":"dcaa9744-ac70-42f7-9e7b-0af402fc6799","type":"Toolbar"},{"attributes":{"plot":{"id":"74b290c2-2e15-48ee-a36b-8993a707d54d","subtype":"Figure","type":"Plot"}},"id":"98f05432-6217-4a49-96e5-ce04a0303436","type":"HelpTool"},{"attributes":{},"id":"a92f3bc1-08fb-46cb-9bd8-e383c2e0b0a7","type":"LinearScale"},{"attributes":{"overlay":{"id":"a1886b07-f2fa-44b0-af25-a94acbcaa617","type":"BoxAnnotation"},"plot":{"id":"74b290c2-2e15-48ee-a36b-8993a707d54d","subtype":"Figure","type":"Plot"}},"id":"d017a7dd-958b-43b8-a4a2-5fe18107446f","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"74b290c2-2e15-48ee-a36b-8993a707d54d","subtype":"Figure","type":"Plot"}},"id":"324f4039-679d-46e3-ae9c-e0840581d7e1","type":"SaveTool"},{"attributes":{},"id":"e40d8dc0-78a1-4480-8b94-7192bf3586fb","type":"BasicTicker"},{"attributes":{"line_color":{"value":"tomato"},"x":{"field":"x"},"y":{"field":"y"}},"id":"69f0d0c7-50c4-483d-ba0e-4ec10f5305c6","type":"Line"},{"attributes":{"plot":{"id":"74b290c2-2e15-48ee-a36b-8993a707d54d","subtype":"Figure","type":"Plot"},"ticker":{"id":"e40d8dc0-78a1-4480-8b94-7192bf3586fb","type":"BasicTicker"}},"id":"10aa246c-15f6-48cb-8b44-09fcf85d15ae","type":"Grid"},{"attributes":{" ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="325a45b0-77af-433a-a633-635090db3ab9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("325a45b0-77af-433a-a633-635090db3ab9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("325a45b0-77af-433a-a633-635090db3ab9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '325a45b0-77af-433a-a633-635090db3ab9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"af6bfb3c-9760-4487-8b03-e3ed0f3dbb7d":{"roots":{"references":[{"attributes":{"plot":{"id":"d1b35d01-1775-4cbb-8794-1c5e2e3c1f5e","subtype":"Figure","type":"Plot"}},"id":"90382ec2-c6dd-41e4-a68b-3453c948bfc1","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"c8569f39-fe26-4785-b316-eb02688ad802","type":"Title"},{"attributes":{"callback":null},"id":"90a9b77c-e171-4473-a072-12c2b36e02be","type":"DataRange1d"},{"attributes":{},"id":"8a9892bf-6944-4de8-9859-c3271e3388df","type":"ToolEvents"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4b177ace-d39b-4f5c-a58a-b9c2cca974af","type":"Line"},{"attributes":{"below":[{"id":"0647b141-3aa9-4938-bd1d-34e343d34576","type":"LogAxis"}],"left":[{"id":"a6d45d78-002e-408f-8010-fbe4c956df9a","type":"LinearAxis"}],"renderers":[{"id":"0647b141-3aa9-4938-bd1d-34e343d34576","type":"LogAxis"},{"id":"14654b47-2c8d-4e85-a277-cf4f753169aa","type":"Grid"},{"id":"a6d45d78-002e-408f-8010-fbe4c956df9a","type":"LinearAxis"},{"id":"1a49c2f0-5e3a-4068-b700-bb77fc9cb7a8","type":"Grid"},{"id":"cc98b0d0-3789-4543-b795-d5243869cdf2","type":"BoxAnnotation"},{"id":"2539b1a7-abc3-4ea9-9e47-55f61f560da1","type":"GlyphRenderer"}],"title":{"id":"c8569f39-fe26-4785-b316-eb02688ad802","type":"Title"},"tool_events":{"id":"8a9892bf-6944-4de8-9859-c3271e3388df","type":"ToolEvents"},"toolbar":{"id":"bedc3b15-7936-4515-a7ae-544ee245c8cd","type":"Toolbar"},"x_range":{"id":"504cbfa2-58db-40e7-82c7-d3f642849343","type":"DataRange1d"},"x_scale":{"id":"e940cc85-deca-4e63-8671-314dd426a406","type":"LogScale"},"y_range":{"id":"90a9b77c-e171-4473-a072-12c2b36e02be","type":"DataRange1d"},"y_scale":{"id":"f571f596-3c2a-4adb-a203-8376c98fe068","type":"LinearScale"}},"id":"d1b35d01-1775-4cbb-8794-1c5e2e3c1f5e","subtype":"Figure","type":"Plot"},{"attributes":{"ticker":null},"id":"f50376a0-29fd-4f96-9d7c-ad37cdf2742f","type":"LogTickFormatter"},{"attributes":{},"id":"f571f596-3c2a-4adb-a203-8376c98fe068","type":"LinearScale"},{"attributes":{},"id":"e940cc85-deca-4e63-8671-314dd426a406","type":"LogScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c31a7180-2302-46e4-b7d2-d73721c698cd","type":"PanTool"},{"id":"7fb0336a-1164-4e9d-83eb-483a1282391e","type":"WheelZoomTool"},{"id":"00dfafda-a5e9-48e0-8566-03df4d96979f","type":"BoxZoomTool"},{"id":"df7ba199-a7f5-41a2-b98c-cb5b73f3f645","type":"SaveTool"},{"id":"90382ec2-c6dd-41e4-a68b-3453c948bfc1","type":"ResetTool"},{"id":"18bcebef-c883-40d7-878c-b7361927fb1f","type":"HelpTool"}]},"id":"bedc3b15-7936-4515-a7ae-544ee245c8cd","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cc98b0d0-3789-4543-b795-d5243869cdf2","type":"BoxAnnotation"},{"attributes":{"num_minor_ticks":10},"id":"36616cb7-d2c6-48fd-8115-b14ed74e59e4","type":"LogTicker"},{"attributes":{"formatter":{"id":"f50376a0-29fd-4f96-9d7c-ad37cdf2742f","type":"LogTickFormatter"},"plot":{"id":"d1b35d01-1775-4cbb-8794-1c5e2e3c1f5e","subtype":"Figure","type":"Plot"},"ticker":{"id":"36616cb7-d2c6-48fd-8115-b14ed74e59e4","type":"LogTicker"}},"id":"0647b141-3aa9-4938-bd1d-34e343d34576","type":"LogAxis"},{"attributes":{"formatter":{"id":"d7038dc8-384a-4a35-b957-1ef2d6dfba20","type":"BasicTickFormatter"},"plot":{"id":"d1b35d01-1775-4cbb-8794-1c5e2e3c1f5e","subtype":"Figure","type":"Plot"},"ticker":{"id":"57a4c0d5-0e41-48e0-9bf8-7f73348622ce","type":"BasicTicker"}},"id":"a6d45d78-002e-408f-8010-fbe4c956df9a","type":"LinearAxis"},{"attributes":{"plot":{"id":"d1b35d01-1775-4cbb-8794-1c5e2e3c1f5e","subtype":"Figure","type":"Plot"}},"id":"18bcebef-c883-40d7-878c-b7361927fb1f","type":"HelpTool"},{"attributes": ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="94f891a0-d49c-4b1c-92ad-37253d73207a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("94f891a0-d49c-4b1c-92ad-37253d73207a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("94f891a0-d49c-4b1c-92ad-37253d73207a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '94f891a0-d49c-4b1c-92ad-37253d73207a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5642e362-1158-46df-87a9-99081733e38a":{"roots":{"references":[{"attributes":{"formatter":{"id":"292e23c0-3e9e-477b-bf95-dbc9dd17cfe0","type":"BasicTickFormatter"},"plot":{"id":"8d4b95ec-5338-45b5-ab69-06b31f7e8a0e","subtype":"Figure","type":"Plot"},"ticker":{"id":"4cbe7674-9810-4e23-9e8f-52cdb5d0ed08","type":"BasicTicker"}},"id":"2ef0fdc4-b208-4444-9e37-9aad7054ae0c","type":"LinearAxis"},{"attributes":{},"id":"05a3b83a-422c-4145-b7ee-69fb6f752247","type":"LinearScale"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"accfea8a-1c99-4071-91c5-77f9bc6da29f","type":"Line"},{"attributes":{"callback":null},"id":"f68a601a-c910-4528-82fe-d1f297739abe","type":"DataRange1d"},{"attributes":{},"id":"956fefd9-f073-4d8e-a54a-2e69fabb19c2","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7293f008-87c0-4cda-badd-f78a09ea41c2","type":"PanTool"},{"id":"e912fabc-e63e-4171-b02d-88428da52e51","type":"WheelZoomTool"},{"id":"364c6334-b96e-4008-992a-b055bbb01d46","type":"BoxZoomTool"},{"id":"1ab3da9e-0c16-427c-92c8-6c98bb02f723","type":"SaveTool"},{"id":"ef44afd1-9644-4481-995a-5eeb90b6fbdd","type":"ResetTool"},{"id":"6f9e3c94-2da4-43cf-a916-4b56de515403","type":"HelpTool"}]},"id":"a7aedff7-491e-4706-87d2-6df03af17524","type":"Toolbar"},{"attributes":{"below":[{"id":"d3d4a82f-7833-4645-8fa5-ea4b0b197511","type":"LinearAxis"}],"left":[{"id":"2ef0fdc4-b208-4444-9e37-9aad7054ae0c","type":"LinearAxis"}],"renderers":[{"id":"d3d4a82f-7833-4645-8fa5-ea4b0b197511","type":"LinearAxis"},{"id":"cfbfbb29-fd16-4fed-b5c2-1e1a25b2982b","type":"Grid"},{"id":"2ef0fdc4-b208-4444-9e37-9aad7054ae0c","type":"LinearAxis"},{"id":"eda242cd-77d1-448c-bbf3-4308d696548b","type":"Grid"},{"id":"d1c92d08-91d7-4a8a-825a-0632a47f1c9e","type":"BoxAnnotation"},{"id":"fa9387c0-04f7-4817-a212-b64fbab20747","type":"GlyphRenderer"},{"id":"549e66a5-a524-4502-a7e5-308aac4bd733","type":"GlyphRenderer"}],"title":{"id":"feb40d5c-1fb7-41cc-a2df-e9afb2d3bb6d","type":"Title"},"tool_events":{"id":"99ee2a9b-3aa5-4cb6-a500-b306520d04de","type":"ToolEvents"},"toolbar":{"id":"a7aedff7-491e-4706-87d2-6df03af17524","type":"Toolbar"},"x_range":{"id":"f68a601a-c910-4528-82fe-d1f297739abe","type":"DataRange1d"},"x_scale":{"id":"05a3b83a-422c-4145-b7ee-69fb6f752247","type":"LinearScale"},"y_range":{"id":"2959013f-59d2-4e6e-b204-21c5be27f590","type":"DataRange1d"},"y_scale":{"id":"956fefd9-f073-4d8e-a54a-2e69fabb19c2","type":"LinearScale"}},"id":"8d4b95ec-5338-45b5-ab69-06b31f7e8a0e","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d1c92d08-91d7-4a8a-825a-0632a47f1c9e","type":"BoxAnnotation"},{"attributes":{},"id":"d2e32096-4628-4839-8aa0-28111950c580","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"8d4b95ec-5338-45b5-ab69-06b31f7e8a0e","subtype":"Figure","type":"Plot"}},"id":"ef44afd1-9644-4481-995a-5eeb90b6fbdd","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"8d4b95ec-5338-45b5-ab69-06b31f7e8a0e","subtype":"Figure","type":"Plot"},"ticker":{"id":"4cbe7674-9810-4e23-9e8f-52cdb5d0ed08","type":"BasicTicker"}},"id":"eda242cd-77d1-448c-bbf3-4308d696548b","type":"Grid"},{"attributes":{"plot":{"id":"8d4b95ec-5338-45b5-ab69-06b31f7e8a0e","subtype":"Figure","type":"Plot"}},"id":"e912fabc-e63e-4171-b02d-88428da52e51","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e6dd8071-aa92-43bf-8ce1-b26b53031d01","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dty ...

# %% [markdown]
# ### TEST MIMO System

# %%
# Make a system
num = [[[3],[10]], [[5],[1]]]
den = [[[10,1],[50,1]],[[20,1],[30,1]]]
#G = cn.tf(num,den)

# Time array
t = np.linspace(0,300,600)
# Store the output
y = np.empty([2,2,t.size])
# Input Array
u = np.ones_like(t)

# Define Parameter
K = np.empty([2,2])
T = np.empty([2,2])
L = np.empty([2,2])
G = [[0 for x in range(2)] for y in range(2)] 

# Identify from step response
for ins in range(0,2):
    for out in range(0,2):
        G[out][ins] = cn.tf(num[out][ins],den[out][ins])
        y[out][ins][:],t = cn.step(G[out][ins],t)
        K[out][ins],T[out][ins],L[out][ins] = Area_Fit(y[out][ins][:],u,t)
    
# Compute the decentralized controller
Ky1,Kr1 = Control_Decentral(K,T,L)
Ky2,Kr2 = Control_Astrom(K,T,L, 0.2*np.eye(2))

#g = G[0][0]
#ky = Ky1[0][0]
#kr = Kr1[0][0]
#ky = cn.tf([ky[0]],[1])+cn.tf([ky[1]],[1,0])
#kr = cn.tf([kr[1]],[1,0])
#cl =cn.feedback(g,ky)*kr
#yc,tc = cn.step(cl)
# Plot
#p4 = bk.figure()
#p4.line(tc,yc)
#bk.show(p4)
#g
# Out:
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:18: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
# Test Identification
# Make a system
num = [5,10]
den = [10,20,1]
G = cn.tf(num,den)
# Step response
t = np.linspace(0,100,500)
y,t = cn.matlab.step(G,t)

# Plot
p1 = bk.figure()
p1.line(t,y, line_color= "tomato")
bk.show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="911ab24e-cf88-4ab1-811b-b79c6eca26e8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("911ab24e-cf88-4ab1-811b-b79c6eca26e8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("911ab24e-cf88-4ab1-811b-b79c6eca26e8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '911ab24e-cf88-4ab1-811b-b79c6eca26e8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ece05452-b0b7-4fe3-b30b-7de24425ae92":{"roots":{"references":[{"attributes":{},"id":"006fac1f-a198-4208-9f5f-148ff55851ed","type":"LinearScale"},{"attributes":{"line_color":{"value":"tomato"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b4a1e689-4aaa-43ee-9a79-a73da25428db","type":"Line"},{"attributes":{"formatter":{"id":"2ffd4264-3a3e-414b-9b62-a0d3f050a8f5","type":"BasicTickFormatter"},"plot":{"id":"3d9321cc-b248-4276-8800-151d4b66203b","subtype":"Figure","type":"Plot"},"ticker":{"id":"73c0d692-ca9d-441c-932c-53f6febc6d10","type":"BasicTicker"}},"id":"da3820d3-6b1e-44cc-a358-63238b0a51df","type":"LinearAxis"},{"attributes":{"data_source":{"id":"3373fb40-aeec-41de-858b-5e9ece2bc5f8","type":"ColumnDataSource"},"glyph":{"id":"b4a1e689-4aaa-43ee-9a79-a73da25428db","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"61367b25-1d5e-478b-abf2-4d792773554e","type":"Line"},"selection_glyph":null},"id":"d18c1fc8-09d2-470d-8e85-c03f955efcc7","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"858e5aab-3a5e-417e-8e04-4853e65f7d74","type":"BasicTickFormatter"},"plot":{"id":"3d9321cc-b248-4276-8800-151d4b66203b","subtype":"Figure","type":"Plot"},"ticker":{"id":"928da7c0-7242-4406-8ca6-97966e4c9eb6","type":"BasicTicker"}},"id":"fa990447-ce30-4ff6-bec0-a0836257a6f8","type":"LinearAxis"},{"attributes":{"plot":{"id":"3d9321cc-b248-4276-8800-151d4b66203b","subtype":"Figure","type":"Plot"}},"id":"62b68233-5d9e-4c14-a9c1-eb2112595578","type":"PanTool"},{"attributes":{"plot":{"id":"3d9321cc-b248-4276-8800-151d4b66203b","subtype":"Figure","type":"Plot"}},"id":"b8ed9c61-7966-4f7f-bd14-ed705b4e4099","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8c6e7e6b-feb2-42b6-8ce5-e8db83a6e03c","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"3d9321cc-b248-4276-8800-151d4b66203b","subtype":"Figure","type":"Plot"},"ticker":{"id":"928da7c0-7242-4406-8ca6-97966e4c9eb6","type":"BasicTicker"}},"id":"c511159c-4f2b-473c-a747-f6e407443ded","type":"Grid"},{"attributes":{"below":[{"id":"fa990447-ce30-4ff6-bec0-a0836257a6f8","type":"LinearAxis"}],"left":[{"id":"da3820d3-6b1e-44cc-a358-63238b0a51df","type":"LinearAxis"}],"renderers":[{"id":"fa990447-ce30-4ff6-bec0-a0836257a6f8","type":"LinearAxis"},{"id":"c511159c-4f2b-473c-a747-f6e407443ded","type":"Grid"},{"id":"da3820d3-6b1e-44cc-a358-63238b0a51df","type":"LinearAxis"},{"id":"9e593381-b38f-4c6a-b95c-d37123ca3d67","type":"Grid"},{"id":"8c6e7e6b-feb2-42b6-8ce5-e8db83a6e03c","type":"BoxAnnotation"},{"id":"d18c1fc8-09d2-470d-8e85-c03f955efcc7","type":"GlyphRenderer"}],"title":{"id":"aaf0cb8b-f7fd-48d1-b6fa-7196abe2a7ba","type":"Title"},"tool_events":{"id":"3863ca21-305b-471f-8ed4-9bf409d258ef","type":"ToolEvents"},"toolbar":{"id":"b515f572-1e02-4633-8f9b-6e6a0c8a52e2","type":"Toolbar"},"x_range":{"id":"a7777831-5610-4e99-ab82-d8f30d438ff0","type":"DataRange1d"},"x_scale":{"id":"f3da5888-70e5-40ba-91bb-188c611e85e7","type":"LinearScale"},"y_range":{"id":"1a0c2535-eadd-465a-a772-6a8ec2a5971f","type":"DataRange1d"},"y_scale":{"id":"006fac1f-a198-4208-9f5f-148ff55851ed","type":"LinearScale"}},"id":"3d9321cc-b248-4276-8800-151d4b66203b","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"2ffd4264-3a3e-414b-9b62-a0d3f050a8f5","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"aaf0cb8b-f7fd-48d1-b6fa-7196abe2a7ba","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"3d9321cc-b248-4276-8800-151d4b66203b","subtype":"Figure","type":"Plot"},"ticker":{"id":"73c0d692-ca9d-441c-932c-53f6febc6d10","type":"BasicTicker"}},"id":"9e593381-b38f-4c6a-b95c-d37123ca3d67","type":"Grid"},{"attributes":{"overlay":{"id":"8c6e7e6b-feb2-42b6-8ce5-e8db83a6e03c","ty ...

# %%
# Modified Detuning
def Control_Decoupled(K,T,L,H, MS= None, w = 0, b=np.empty, structure = 'PI'):
    # Check Input for Maximum Sensitivity
    if MS is None:
        MS = 1.4*np.eye(K.shape[0],K.shape[1])
    
    # Compute Determinant of Maximum Sensitivity
    ms = np.linalg.det(MS)

    # Compute SISO Case
    if K.ndim <= 1:
        return Control_Decentral(K,T,L,w,b,structure)
    
    # Compute General MIMO Case
    else:

        # Compute a decentralized control structure based on RGA
        Ky, Kr = Control_Decentral(K,T,L, w , b, structure)
        
        # Get minimal Delay/ Time Constant for robust limit of crossover frequency, ignore zeros
        # Important note: wc_min is actually 1/w_c !!!
        if (L[np.where(L>0)].size !=0) or (T[np.where(T>0)].size !=0):
            if (L[np.where(L>0)].size !=0):
                wc_min = np.min([np.min(L[np.nonzero(L)]),np.min(T[np.nonzero(T)])])
            else:
                wc_min = np.min(np.min(T[np.nonzero(T)]))
        else:
            # Use very high frequency
            wc_min = 1e10
        
        # Calculate the Pairing
        # Compute RGA -> Checks for Shape
        LG = RGA(K,T,L,w)
        # Get Pairing as an array for every column
        Pairing = np.argmax(LG, axis=0)
        
        # Compute the Taylor Series 
        Gamma =  np.multiply(-K,T+L)

        # Initialize 
        KD = np.zeros_like(Gamma)
        GD = np.zeros_like(Gamma)
        
        # Get the Diagonal entries for decoupling
        for outputs in range(0,K.shape[0]):
            inputs = Pairing[outputs]
            KD[outputs][inputs] = K[outputs][inputs]
            GD[outputs][inputs] = Gamma[outputs][inputs]
    
        # Get the Antidiagonal
        KA = K-KD
        GA = Gamma-GD
        
        # Define the splitter
        S = np.dot(np.linalg.inv(KD),KA)

        # Get the interaction
        GammaA = np.abs(GA + np.dot(GD,S))
        print(GammaA)
        # Get the maximum of each row 
        GMax = np.argmax(GammaA,axis=0)
        print(GMax)
        #Iterate through the outputs
        for outputs in range(0,K.shape[0]):
            inputs = Pairing[outputs]
            
            # Test the current controller for interaction
            # Every controller has the dimension 3 for kp, ki, kd
            ky = Ky[outputs][inputs]
            kr = Kr[outputs][inputs]
            
            # Get the current parameter
            k = K[outputs][inputs]
            t = T[outputs][inputs]
            l = L[outputs][inputs]
            
            # Check for set point weight, either given
            if b == np.empty:
                # Or computed from AMIGO_TUNE
                b = kr[0]/ky[0]
            print(b)
            gmax = GammaA[outputs][GMax[outputs]]
            print(gmax)
            # Check for PI Structure
            if structure == 'PI':
                # Define the counter
                counter = 0
                # Set shrinking rate 
                shrink_rate = 0.9
                
                print(np.abs(H[outputs][outputs]/(ms*gmax)) - np.sqrt( (b*ky[0]/wc_min)**2 + ky[1]**2 ))
                while (np.abs(H[outputs][outputs]/(ms*gmax)) - np.sqrt( (b*ky[0]/wc_min)**2 + ky[1]**2 ) < 0):
                    if counter > 1e5:
                        #print('Maximal Iteration for detuning reached! Abort')
                        break
                    # Detune the controller with the shrinking rate    
                    ky = AMIGO_DETUNE(k,t,l,ky,shrink_rate*ky[0])
                    # Increment counter
                    counter += 1
                print(counter)
                # Get the controller parameter
                Ky[outputs][inputs][:] = ky
                Kr[outputs][inputs][:] = [b*ky[0], ky[1], ky[2]]

    return Ky,Kr

# %%
K = np.array([[10,6],[7,1]])
T = np.array([[1,1],[1,1]])
L = np.array([[0,0],[0,0]])
H = np.diag([0.01,0.01])
Ky,Kr = Control_Decoupled(K,T,L,H)
# Out:
# [[ 20.   0.]
#  [  0.   2.]]
# [0 1]
# 0.0
# 20.0
# -0.774143745586
# 109
# 0.0
# 2.0
# -0.661219420414
# 87
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:18: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
Ky
# Out:
# array([[[  6.91427007e-310,   2.87953632e-316,   6.91420096e-310],
#         [  5.13856018e-009,   2.49392636e-007,   0.00000000e+000]],
#
#        [[  4.47259372e-008,   2.53248896e-006,   0.00000000e+000],
#         [  0.00000000e+000,   0.00000000e+000,   0.00000000e+000]]])

# %%
Kr
# Out:
# array([[[  6.91427007e-310,   2.86763211e-316,   6.91420096e-310],
#         [  0.00000000e+000,   2.49392636e-007,   0.00000000e+000]],
#
#        [[  0.00000000e+000,   2.53248896e-006,   0.00000000e+000],
#         [  0.00000000e+000,   0.00000000e+000,   0.00000000e+000]]])

# %%
AMIGO_Tune(6,1,0)
# Out:
# ([0.4705922865013773, 0.7743988476263195, 0.0], 0.0)
