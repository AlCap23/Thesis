# %% [markdown]
# # FOTD Model Fit Example
#
# Fit some high order Model to a FOTD System

# %%
# General Pacakages
import sympy as sp
import numpy as np
import control as cn
#Plotting
import bokeh.plotting as bk
import bokeh.io as bi
from bokeh.io import export_svgs
bi.output_notebook()

import matplotlib.pyplot as plt
# %matplotlib inline

# Algorithms
import Algorithms as alg

# TUBS Rot, Gelb, Orange, Hellgrün, Grün, Dunkelgrün, Hellblau, Blau, Dunkelblau, Violett
TUBScolorscale=[(190,30,60,0.9),
               (255,200,42,0.9),
               (225,109,0,0.9),
               (172,193,58,0.9),
               (109,131,0,0.9),
               (0,83,74,0.9),
               (102,180,211,0.9),
               (0,112,155,0.9),
               (0,63,87,0.9),
               (138,48,127,0.9)]
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c4da7630-5cd4-46b0-8e2e-047e67152987">Loading BokehJS ...</span>
#     </div>

# %%
## Generate a High Order System
num = [[[1]]]
den = [[[1,1.8,0.9]]]
G = cn.tf(num,den)
t = np.linspace(0,10,1000)
y, t = cn.step(G,t)
u = np.ones_like(t)
# Identify the parameter
K,T,L = alg.Integral_Identification(y,u,t)
num, den = cn.pade(L,10)
GM = cn.tf([K],[T,1])*cn.tf(num,den)
yM,tM = cn.step(GM,t)

# %%
# Define the figure
p1 = bk.figure(x_range=(t[0],t[-1]), y_range = (-0.1,np.ceil(np.max(y))), plot_width = 800, plot_height = 300)
#p1.grid.minor_grid_line_color = '#eeeeee'
# Define the Data
p1.line(tM,yM, line_color=TUBScolorscale[2], line_width = 2, legend="Model")
#p1.scatter(t,yreal, size=1,fill_color=TUBScolorscale[5],fill_alpha=0.4, legend="Measurement")
p1.line(t,y, line_color=TUBScolorscale[6], line_width = 2, line_dash = "dashed",legend="Original")
# Define the axis label
p1.xaxis.axis_label = "Time [min]"
p1.yaxis.axis_label = "Output"
p1.legend.location = "bottom_right"
# Show and Export
p1.output_backend = "svg"
export_svgs(p1, filename="Area_Example.svg")
bk.show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1c8a4c8a-ee54-4dd8-9f0c-d180137f7274"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("1c8a4c8a-ee54-4dd8-9f0c-d180137f7274");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1c8a4c8a-ee54-4dd8-9f0c-d180137f7274");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1c8a4c8a-ee54-4dd8-9f0c-d180137f7274' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"856fce08-42b7-4a76-ae85-707410b114f0":{"roots":{"references":[{"attributes":{"callback":null,"end":10.0},"id":"3a1172c3-b4fc-40ac-bc2c-ded6d11d29bb","type":"Range1d"},{"attributes":{},"id":"11499890-2de3-4d27-8557-c089f0584d9f","type":"WheelZoomTool"},{"attributes":{},"id":"85df21e5-9246-4772-8354-1fc46bf82b5f","type":"BasicTicker"},{"attributes":{"items":[{"id":"2e1fa831-28ff-42c5-8e89-1968807c9ca0","type":"LegendItem"},{"id":"a2ce0d34-4832-470a-b50e-337743105473","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"1ab69b23-ef62-4729-8a07-3fd8613d2ab8","subtype":"Figure","type":"Plot"}},"id":"453370d6-9277-4732-b672-7099c8a871b5","type":"Legend"},{"attributes":{"source":{"id":"e9d90dbc-4714-4fd5-a7ef-6d9fcb6cbe23","type":"ColumnDataSource"}},"id":"30f947be-c8e7-4226-9fde-476e85d1b343","type":"CDSView"},{"attributes":{},"id":"1c0911c5-571d-4907-9267-829c794f34be","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"e9d90dbc-4714-4fd5-a7ef-6d9fcb6cbe23","type":"ColumnDataSource"},{"attributes":{},"id":"71ed0931-2fa1-45eb-84fd-57242c93fbfa","type":"PanTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"71ed0931-2fa1-45eb-84fd-57242c93fbfa","type":"PanTool"},{"id":"11499890-2de3-4d27-8557-c089f0584d9f","type":"WheelZoomTool"},{"id":"41e76982-1c0e-452a-bd3f-e134cc0764e4","type":"BoxZoomTool"},{"id":"198bb7dd-0b88-4f4d-bbd5-5b320db8298a","type":"SaveTool"},{"id":"68bd8b47-00e4-4aac-82af-9ab1b5393b11","type":"ResetTool"},{"id":"6b8e2548-e6f8-492c-94a7-90473eecd654","type":"HelpTool"}]},"id":"5c0c1035-6409-400d-98c4-13b394e7528f","type":"Toolbar"},{"attributes":{},"id":"198bb7dd-0b88-4f4d-bbd5-5b320db8298a","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"1b600719-ee5f-4f12-84d2-9fc0570e3559","type":"Title"},{"attributes":{"plot":{"id":"1ab69b23-ef62-4729-8a07-3fd8613d2ab8","subtype":"Figure","type":"Plot"},"ticker":{"id":"85df21e5-9246-4772-8354-1fc46bf82b5f","type":"BasicTicker"}},"id":"0f623528-090a-4572-866c-4460f2525124","type":"Grid"},{"attributes":{"label":{"value":"Model"},"renderers":[{"id":"812c0862-9aa9-467a-a0d0-8285183a4766","type":"GlyphRenderer"}]},"id":"2e1fa831-28ff-42c5-8e89-1968807c9ca0","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e80caef-d1d5-45a2-8138-32c0d3461067","type":"Line"},{"attributes":{},"id":"33a5a525-1f6c-4172-b4a0-cd6b3c0b7653","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Time [min]","formatter":{"id":"1c0911c5-571d-4907-9267-829c794f34be","type":"BasicTickFormatter"},"plot":{"id":"1ab69b23-ef62-4729-8a07-3fd8613d2ab8","subtype":"Figure","type":"Plot"},"ticker":{"id":"85df21e5-9246-4772-8354-1fc46bf82b5f","type":"BasicTicker"}},"id":"5514018b-3818-4be9-a0ef-393d72ad313f","type":"LinearAxis"},{"attributes":{"line_color":{"value":"rgba(225, 109, 0, 0.9)"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3f365507-47b0-40e3-928a-c1d95e4a017e","type":"Line"},{"attributes":{"source":{"id":"170e0970-b615-44a4-b36e-043b4826c92e","type":"ColumnDataSource"}},"id":"55b81bd6-2044-443f-8707-5886479de185","type":"CDSView"},{"attributes":{},"id":"5ca3bd1b-1908-4039-bb6e-cd99aa98528d","type":"LinearScale"},{"attributes":{"overlay":{"id":"f79990dd-ace7-4aac-a136-b3ee47f2361b","type":"BoxAnnotation"}},"id":"41e76982-1c0e-452a-bd3f-e134cc0764e4","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"413bb60e-0588-4cdd-9253-8031f35ce334","type":"Line"},{"attributes":{},"id":"68bd8b47-00e4-4aac-82af-9ab1b5393b11","type":"ResetTool"},{"attributes":{"callback":n ...

# %%
# Make an area plot
from bokeh.charts import Area

p2 = Area()
# Out:
# (102, 180, 211, 0.9)

# %%
w = np.logspace(-5,5,1000)

real1,imag1,omega1 = cn.nyquist_plot(G,w)
real2,imag2,omega2 = cn.nyquist_plot(GM,w)

# Define the figure
p2 = bk.figure(plot_width = 800, plot_height = 300)
#p1.grid.minor_grid_line_color = '#eeeeee'
# Define the Data
p2.line(real2,imag2, line_color=TUBScolorscale[2], line_width = 2, legend="Model")
p2.line(real1,imag1, line_color=TUBScolorscale[6], line_width = 2, line_dash = "dashed",legend="Original")
# Define the axis label
p2.xaxis.axis_label = "Re"
p2.yaxis.axis_label = "Im"
p2.legend.location = "top_right"
# Show and Export
p2.output_backend = "svg"
export_svgs(p2, filename="Area_Nyquist.svg")
bk.show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="018e1142-3ac9-4e3d-9cf4-65087264807f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("018e1142-3ac9-4e3d-9cf4-65087264807f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("018e1142-3ac9-4e3d-9cf4-65087264807f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '018e1142-3ac9-4e3d-9cf4-65087264807f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f3cb3433-7fdb-4f1c-9eec-3e0dfa824e52":{"roots":{"references":[{"attributes":{"label":{"value":"Model"},"renderers":[{"id":"4abfbf26-17bf-4ea4-a88a-4d175f31373f","type":"GlyphRenderer"}]},"id":"1f2a7912-e338-4fb8-8e35-c6f2724b1ee2","type":"LegendItem"},{"attributes":{"data_source":{"id":"462feaea-c91d-4edf-9b4c-8fdfb7fc9f5b","type":"ColumnDataSource"},"glyph":{"id":"6de4b02d-8e44-4d99-8be8-2e8fb53bf681","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5321c6a7-9f5a-445a-9eb6-06303109b52e","type":"Line"},"selection_glyph":null},"id":"8a7ba758-ae2f-46f6-9600-b221258a3497","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"dea2d1f8-bff2-49a3-bdc4-7555c0ed1e84","subtype":"Figure","type":"Plot"},"ticker":{"id":"a670f2bb-d176-40af-9391-b82bf3dba4ba","type":"BasicTicker"}},"id":"d40d16c4-4e39-47a3-ae2f-c3f0857b3248","type":"Grid"},{"attributes":{},"id":"198743a9-ada7-4a76-8a5c-922987e5150e","type":"LinearScale"},{"attributes":{"plot":{"id":"dea2d1f8-bff2-49a3-bdc4-7555c0ed1e84","subtype":"Figure","type":"Plot"}},"id":"47280c3f-6fa6-4cd3-a862-4a73ee4bc67a","type":"PanTool"},{"attributes":{"callback":null},"id":"50124141-9431-46e9-8ea5-4bd4be87b0d1","type":"DataRange1d"},{"attributes":{},"id":"af1483e6-f3f7-4386-a649-24c945fed709","type":"LinearScale"},{"attributes":{"data_source":{"id":"ecf1e0c7-0428-4791-bd46-8d63159488f7","type":"ColumnDataSource"},"glyph":{"id":"fbcbd5da-1b06-4c7b-9a60-5f0ee7d25d56","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"cb8f01e6-7f00-496e-84c5-bb1bec1f58bc","type":"Line"},"selection_glyph":null},"id":"4abfbf26-17bf-4ea4-a88a-4d175f31373f","type":"GlyphRenderer"},{"attributes":{},"id":"af96c337-c9f4-43cb-bdd1-27bc48556d27","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"d114dbb9-19ae-4cab-897b-018fb694d293","type":"Title"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"cb8f01e6-7f00-496e-84c5-bb1bec1f58bc","type":"Line"},{"attributes":{"line_color":{"value":"rgba(102, 180, 211, 0.9)"},"line_dash":[6],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"6de4b02d-8e44-4d99-8be8-2e8fb53bf681","type":"Line"},{"attributes":{"plot":{"id":"dea2d1f8-bff2-49a3-bdc4-7555c0ed1e84","subtype":"Figure","type":"Plot"}},"id":"bb801e40-ee9c-4cdd-8d05-470026cacac9","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"ecf1e0c7-0428-4791-bd46-8d63159488f7","type":"ColumnDataSource"},{"attributes":{},"id":"a670f2bb-d176-40af-9391-b82bf3dba4ba","type":"BasicTicker"},{"attributes":{},"id":"3e62b169-5544-4292-955e-329281ef4b02","type":"BasicTickFormatter"},{"attributes":{"items":[{"id":"1f2a7912-e338-4fb8-8e35-c6f2724b1ee2","type":"LegendItem"},{"id":"84f87a75-8f3b-4be2-91bc-051aefb3c39d","type":"LegendItem"}],"plot":{"id":"dea2d1f8-bff2-49a3-bdc4-7555c0ed1e84","subtype":"Figure","type":"Plot"}},"id":"a3cc52c9-9318-418b-a86f-6d6f20887d57","type":"Legend"},{"attributes":{"plot":{"id":"dea2d1f8-bff2-49a3-bdc4-7555c0ed1e84","subtype":"Figure","type":"Plot"}},"id":"0b042f12-caab-444b-a0f5-32613dc429f0","type":"SaveTool"},{"attributes":{"line_color":{"value":"rgba(225, 109, 0, 0.9)"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"fbcbd5da-1b06-4c7b-9a60-5f0ee7d25d56","type":"Line"},{"attributes":{},"id":"bf23ef40-339e-4b8c-a8f4-5ce390dabb40","type":"BasicTicker"},{"attributes":{"axis_label":"Im","formatter":{"id":"af96c337-c9f4-43cb-bdd1-27bc48556d27","type":"BasicTickFormatter"},"plot":{"id":"dea2d1f8-bff2-49a3-bdc4-7555c0ed1e84","subtype":"Figure","type":"Plot"},"ticker":{"id":"a670f2bb-d176-40af-9391-b82bf3dba4ba","type":"BasicTicker"}},"id":"83e6addc-87ec-4182-add5-9329636e886b","type":"LinearAxis"},{"attributes":{" ...

# %%
mag1,phase1,omega1 = cn.bode_plot(G,w)
mag2,phase2,omega2 = cn.bode_plot(GM,w)

# Define the figure
p3 = bk.figure(plot_width = 800, plot_height = 300, x_axis_type="log", y_axis_type="log")

# Define the Data
p3.line(omega2,mag2, line_color=TUBScolorscale[2], line_width = 2, legend="Model")
p3.line(omega1,mag1, line_color=TUBScolorscale[6], line_width = 2, line_dash = "dashed",legend="Original")
# Define the axis label
p3.xaxis.axis_label = "Frequency [rad/s]"
p3.yaxis.axis_label = "Gain [dB]"

# Define the figure
p4 = bk.figure(plot_width = 800, plot_height = 300, x_axis_type="log", y_range = [-360,0])
# Define the Data
p4.line(omega2[np.where(phase2>-360)],phase2[np.where(phase2>-360)], line_color=TUBScolorscale[2], line_width = 2, legend="Model")
p4.line(omega1,phase1, line_color=TUBScolorscale[6], line_width = 2, line_dash = "dashed",legend="Original")
# Define the axis label
p4.xaxis.axis_label = "Frequency [rad/s]"
p4.yaxis.axis_label = "Phase [rad]"


c1 = bk.gridplot([[p3],[p4]])
# Show and Export
p3.output_backend = "svg"
p4.output_backend = "svg"

export_svgs(p3, filename="Area_Bode_Gain.svg")
export_svgs(p4, filename="Area_Bode_Phase.svg")

bk.show(c1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7511add2-bd0f-4f3d-8b83-b2a087d548bc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7511add2-bd0f-4f3d-8b83-b2a087d548bc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7511add2-bd0f-4f3d-8b83-b2a087d548bc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7511add2-bd0f-4f3d-8b83-b2a087d548bc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9d4fae9f-f829-4c0a-ba45-21d60bdc0dec":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"dc66dc18-ddd8-44bf-addf-9b1503e95e1c","subtype":"Figure","type":"Plot"},"ticker":{"id":"ce9d4661-1c33-4e8f-9558-102d3abdc760","type":"LogTicker"}},"id":"bf3a2389-915a-4a1e-9e20-61f77d2115fe","type":"Grid"},{"attributes":{"ticker":null},"id":"e1f498b8-3f41-42d9-a07f-1bc12c18922d","type":"LogTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"0de6459f-9a3c-45d1-973f-ae374c272cb1","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"6de5b227-82f8-419f-b4ff-758cf1d467c5","type":"ColumnDataSource"},"glyph":{"id":"ac7516f4-dd79-4e8d-8973-2993f3c9c951","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"97a70d9f-239b-401f-8c67-8aca15686f71","type":"Line"},"selection_glyph":null},"id":"14de146b-eee5-494f-ae60-a29ab4fc75f0","type":"GlyphRenderer"},{"attributes":{"children":[{"id":"070a00b9-4c39-43f8-8bfd-d4ff09793b9c","type":"Row"},{"id":"5267af98-8ceb-42ac-b1cf-6621302299ac","type":"Row"}]},"id":"a34ac89e-b809-4c26-9852-2990ca726a83","type":"Column"},{"attributes":{"callback":null},"id":"0d1edc7c-6d6b-4226-8619-d370ba5b7520","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fd7d87f0-9fb1-41cd-a8ea-58a813124728","type":"PanTool"},{"id":"a9b0e3f9-dbac-45f6-8a18-bc8020c9750a","type":"WheelZoomTool"},{"id":"96f3c772-aedc-4d77-8675-d85f9f43905f","type":"BoxZoomTool"},{"id":"d5330742-2246-4522-930b-e86110a97338","type":"SaveTool"},{"id":"d6cdb797-2b89-4788-857d-a177b7e8be7c","type":"ResetTool"},{"id":"ecce4dff-014b-41cf-9516-0aece9e1a07d","type":"HelpTool"}]},"id":"49f47945-94a2-4a57-a378-d6b30775cda4","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"97a70d9f-239b-401f-8c67-8aca15686f71","type":"Line"},{"attributes":{},"id":"2dd5188f-9910-4b60-8ed2-2487652eb55e","type":"LogScale"},{"attributes":{"line_color":{"value":"rgba(225, 109, 0, 0.9)"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac7516f4-dd79-4e8d-8973-2993f3c9c951","type":"Line"},{"attributes":{"axis_label":"Frequency [rad/s]","formatter":{"id":"e1f498b8-3f41-42d9-a07f-1bc12c18922d","type":"LogTickFormatter"},"plot":{"id":"dc66dc18-ddd8-44bf-addf-9b1503e95e1c","subtype":"Figure","type":"Plot"},"ticker":{"id":"5df78835-0083-4102-a4e7-3302179320f6","type":"LogTicker"}},"id":"9a153585-9028-4ce5-bab8-f01f80388c2f","type":"LogAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ca832323-5a95-41dd-87b7-95c618f1b6e4","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"dc66dc18-ddd8-44bf-addf-9b1503e95e1c","subtype":"Figure","type":"Plot"}},"id":"a9b0e3f9-dbac-45f6-8a18-bc8020c9750a","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"51921453-7f15-4c17-8afe-139003fc6664","type":"DataRange1d"},{"attributes":{"plot":{"id":"dc66dc18-ddd8-44bf-addf-9b1503e95e1c","subtype":"Figure","type":"Plot"}},"id":"ecce4dff-014b-41cf-9516-0aece9e1a07d","type":"HelpTool"},{"attributes":{"label":{"value":"Model"},"renderers":[{"id":"624b3d08-353b-4fb2-a372-a1ccc836ef03","type":"GlyphRenderer"}]},"id":"fefb89a0-37d0-4169-bfc6-3b69ec2b2d36","type":"LegendItem"},{"attributes":{},"id":"0d89f9c6-75ff-401c-bdfc-ba8e262a85f7","type":"ToolEvents"},{"attributes":{"line_color":{"value":"rgba(102, 180, 211, 0.9)"},"line_dash":[6],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}} ...

# %%
# Define the figure
p5 = bk.figure(plot_width = 800, plot_height = 300, x_axis_type="log", y_axis_type="log")
# Define the Data
p5.line(omega2[np.where(mag2>mag1)],mag2[np.where(mag2>mag1)], line_color=TUBScolorscale[2], line_width = 2, legend="Robust")
p5.line(omega2[np.where(mag2<mag1)],mag2[np.where(mag2<mag1)], line_color=TUBScolorscale[0], line_width = 2, legend="Robust")
p5.line(omega1,mag1, line_color=TUBScolorscale[6], line_width = 2, line_dash = "dashed",legend="Original")
# Define the axis label
p5.xaxis.axis_label = "Frequency [rad/s]"
p5.yaxis.axis_label = "Gain [dB]"


# Define the figure
p6 = bk.figure(plot_width = 800, plot_height = 300, x_axis_type="log", y_range = [-360,0])
# Define the Data
p6.line(omega2[np.where(phase2<phase1)],phase2[np.where(phase2<phase1)], line_color=TUBScolorscale[2], line_width = 2, legend="Robust")
p6.line(omega2[np.where(phase2>phase1)],phase2[np.where(phase2> phase1)], line_color=TUBScolorscale[0], line_width = 2, legend="Not Robust")
p6.line(omega1,phase1, line_color=TUBScolorscale[6], line_width = 2, line_dash = "dashed",legend="Original")
# Define the axis label
p6.xaxis.axis_label = "Frequency [rad/s]"
p6.yaxis.axis_label = "Phase [rad]"


c1 = bk.gridplot([[p5],[p6]])
# Show and Export
p5.output_backend = "svg"
p6.output_backend = "svg"

#export_svgs(p3, filename="Area_Bode_Gain.svg")
#export_svgs(p4, filename="Area_Bode_Phase.svg")

bk.show(c1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bd1d61a2-d9ae-4dc4-9718-0d16742c72c0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bd1d61a2-d9ae-4dc4-9718-0d16742c72c0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bd1d61a2-d9ae-4dc4-9718-0d16742c72c0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bd1d61a2-d9ae-4dc4-9718-0d16742c72c0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b3b9182d-946f-41fa-813c-8338e07da0fe":{"roots":{"references":[{"attributes":{},"id":"e102f1fa-6338-4198-ab14-fa082e95c1e7","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5ededb44-2b0f-4ead-a000-f6a5d251bc43","type":"PanTool"},{"id":"676491d9-cb8c-4b7f-a835-eaab3f4d3288","type":"WheelZoomTool"},{"id":"78133bfc-e846-4843-b25f-95cdb86da29e","type":"BoxZoomTool"},{"id":"c95293ed-5ca6-47cf-95a6-7f173c42e6d7","type":"SaveTool"},{"id":"4d106057-3454-4cac-adc2-ecb30895e6ae","type":"ResetTool"},{"id":"c1da31ec-0919-477a-bed5-9325ed13aeb6","type":"HelpTool"}]},"id":"73bb3956-1f21-4a5f-b791-01a2c9911d93","type":"Toolbar"},{"attributes":{"num_minor_ticks":10},"id":"a2cbd984-3727-46af-aa82-8d12381d0acb","type":"LogTicker"},{"attributes":{},"id":"a1fdbe6a-6c21-40d4-94ab-61f4b9859ed7","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3f8a173b-a89f-4fbf-a9a5-c3c0feb3a873","subtype":"Figure","type":"Plot"}},"id":"9bd4bbe7-8561-46a9-ae05-f66ecb2cdb35","type":"SaveTool"},{"attributes":{"items":[{"id":"a25456e1-d412-4d7d-9d50-cc32bccef7d7","type":"LegendItem"},{"id":"aee31b81-03d4-47f1-abbc-f20f689931ae","type":"LegendItem"},{"id":"5ab9637d-766c-4b76-8e0f-486159b0ead2","type":"LegendItem"}],"plot":{"id":"7c4210a6-2a73-499d-a69a-8babd417abbe","subtype":"Figure","type":"Plot"}},"id":"a431b72b-4fa1-47ee-9263-e90b0cf159a3","type":"Legend"},{"attributes":{"axis_label":"Phase [rad]","formatter":{"id":"a1fdbe6a-6c21-40d4-94ab-61f4b9859ed7","type":"BasicTickFormatter"},"plot":{"id":"7c4210a6-2a73-499d-a69a-8babd417abbe","subtype":"Figure","type":"Plot"},"ticker":{"id":"e102f1fa-6338-4198-ab14-fa082e95c1e7","type":"BasicTicker"}},"id":"64dd1ebe-c517-4464-8882-a9c3fe6a86b7","type":"LinearAxis"},{"attributes":{},"id":"7369dfe3-e05f-438b-a0da-8abf32d8f1e3","type":"ToolEvents"},{"attributes":{"callback":null},"id":"b4be86c8-5a4a-43cc-b9f2-e31c294ac66c","type":"DataRange1d"},{"attributes":{"plot":{"id":"3f8a173b-a89f-4fbf-a9a5-c3c0feb3a873","subtype":"Figure","type":"Plot"},"ticker":{"id":"928dfb04-75bc-4b48-a002-ddba32b949b1","type":"LogTicker"}},"id":"6c0d0ccb-ad02-4ba2-a403-a6fc0268f035","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"7c4210a6-2a73-499d-a69a-8babd417abbe","subtype":"Figure","type":"Plot"},"ticker":{"id":"e102f1fa-6338-4198-ab14-fa082e95c1e7","type":"BasicTicker"}},"id":"9a1b72d3-a786-4466-9fa5-b594a364dbb4","type":"Grid"},{"attributes":{"data_source":{"id":"0a64dbfe-b14e-4ba4-a6cd-864769e3513e","type":"ColumnDataSource"},"glyph":{"id":"f46726c5-ec55-46b1-a178-b379ec15c6bd","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9f595221-5438-44f3-9385-b40e50c62eb8","type":"Line"},"selection_glyph":null},"id":"bcb69cd4-c286-45ca-8bb3-4d46c41e5338","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"7c4210a6-2a73-499d-a69a-8babd417abbe","subtype":"Figure","type":"Plot"}},"id":"676491d9-cb8c-4b7f-a835-eaab3f4d3288","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"dfa04000-09a2-449f-98ef-bd432befba2d","type":"PanTool"},{"id":"b8073506-9216-41ce-80c6-8e125f5a3e9d","type":"WheelZoomTool"},{"id":"dc37fbdb-2a4c-4dd9-babb-bdb107f4a66d","type":"BoxZoomTool"},{"id":"9bd4bbe7-8561-46a9-ae05-f66ecb2cdb35","type":"SaveTool"},{"id":"f2f04f2b-f9d9-4dfa-b045-98738d61f51f","type":"ResetTool"},{"id":"0d46b03d-79f8-47e3-a126-291875fdefef","type":"HelpTool"}]},"id":"a9be4fb2-4400-4d2d-9e1d-5147b6c0c30e","type":"Toolbar"},{"attributes":{},"id":"979b73b5-e159-445b-a1f3-2495bee51679","type":"ToolEvents"},{"attributes":{"line_color":{"value":"rgba(102, 180, 211, 0.9)"},"line_dash":[6],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"48663fe0-87e4-42a7-8b6b-99bd4ab1c4b4","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64" ...

# %%
## Generate a High Order System
num = [[[1]]]
den = [[[1,.5,1]]]
G = cn.tf(num,den)
t = np.linspace(0,130,1300)
y1, t1 = cn.step(G,t)
u = np.ones_like(y)
np.argmax(yreal), np.size(yreal)
GM = Area_Fit(y1,u,t)
yM1,tM1 = cn.step(GM,t)

## Generate a High Order System
num = [[[1]]]
den = [[[1,1.5,1]]]
G = cn.tf(num,den)
t = np.linspace(0,130,1300)
y2, t2 = cn.step(G,t)
u = np.ones_like(y2)
np.argmax(yreal), np.size(yreal)
GM = Area_Fit(y2,u,t2)
yM2,tM2 = cn.step(GM,t)

## Generate a High Order System
num = [[[1]]]
den = [[[1,10,1]]]
G = cn.tf(num,den)
t = np.linspace(0,130,1300)
y3, t3 = cn.step(G,t)
u = np.ones_like(y3)
np.argmax(yreal), np.size(yreal)
GM = Area_Fit(y3,u,t3)
yM3,tM3 = cn.step(GM,t3)
# Out:
# 1300
# 32
# 1.44394660057
# 1.44394660057
# 0.667262449091
# 0.830443161261
# 1.49770561035
# 1300
# 47
# 1.02834469168
# 1.02834469168
# 0.983750154171
# 0.647211076527
# 1.6309612307
# 1300
# 1299
# 0.999998000092
# 0.999998000092
# 9.74130391083
# 0.258437663845
# 9.99974157468

# %%
# Define the figure
p1 = bk.figure(x_range=(t[0],t[-1]), plot_width = 800, plot_height = 300)
#p1.grid.minor_grid_line_color = '#eeeeee'
# Define the Data
p1.line(tM1,yM1, line_color=TUBScolorscale[2], line_width = 2, legend="Underdamped Model")
p1.line(t1,y1, line_color=TUBScolorscale[6], line_width = 2, line_dash = "dashed",legend="Underdamped System")

p1.line(tM2,yM2, line_color=TUBScolorscale[2], line_width = 2, legend="Damped Model")
p1.line(t2,y2, line_color=TUBScolorscale[6], line_width = 2, line_dash = "dashed",legend="Damped System")


p1.line(tM3,yM3, line_color=TUBScolorscale[2], line_width = 2, legend="Overdamped Model")
p1.line(t3,y3, line_color=TUBScolorscale[6], line_width = 2, line_dash = "dashed",legend="Overdamped System")


# Define the axis label
p1.xaxis.axis_label = "Time [min]"
p1.yaxis.axis_label = "Output"
p1.legend.visible = False
# Show and Export
p1.output_backend = "svg"
export_svgs(p1, filename="Area_Fitting.svg")
bk.show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0edadb6e-f39f-4a95-bf1d-0fb75ec218a4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0edadb6e-f39f-4a95-bf1d-0fb75ec218a4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0edadb6e-f39f-4a95-bf1d-0fb75ec218a4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0edadb6e-f39f-4a95-bf1d-0fb75ec218a4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7ba217ff-ec5f-4957-bd4b-ba56d1c881fe":{"roots":{"references":[{"attributes":{"plot":{"id":"65a2243a-d3d0-4392-84bb-d3ce1b34ab4c","subtype":"Figure","type":"Plot"}},"id":"4f0e5267-69ac-4fd7-8061-927146f58e89","type":"HelpTool"},{"attributes":{"plot":{"id":"65a2243a-d3d0-4392-84bb-d3ce1b34ab4c","subtype":"Figure","type":"Plot"}},"id":"a97521b7-b367-4f49-8d4a-aa6419f57535","type":"ResetTool"},{"attributes":{"plot":{"id":"65a2243a-d3d0-4392-84bb-d3ce1b34ab4c","subtype":"Figure","type":"Plot"}},"id":"1b1befda-b792-4e17-a684-e4db79a73101","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1300]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1300]}}},"id":"fbc913e0-865a-44e0-af5b-21774c74b0e3","type":"ColumnDataSource"},{"attributes":{},"id":"90990f2e-2b94-4d6e-8090-dfcc48108685","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"84fdc636-87f5-4b33-a09a-99865ea3452e","type":"ColumnDataSource"},"glyph":{"id":"3ddeee6f-e278-4f47-a47a-788cafbbd0a0","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"754cd7e8-5e9c-48a9-92f1-7e93d185dc8d","type":"Line"},"selection_glyph":null},"id":"b5d9b8bb-5f69-4dbb-9d11-25ecbc583e03","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"e64b1a4a-5148-4711-9573-eeca396213ce","type":"Line"},{"attributes":{"label":{"value":"Damped Model"},"renderers":[{"id":"33f57040-acde-47e0-95f8-0cf8659d646e","type":"GlyphRenderer"}]},"id":"3bafc436-43fa-4673-a69f-cfc110dbc297","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a84b1333-cdc8-4b7b-b674-863520482896","type":"BoxAnnotation"},{"attributes":{"axis_label":"Time [min]","formatter":{"id":"1c5a26ae-7d9c-4e44-a32a-f841f57ba5ec","type":"BasicTickFormatter"},"plot":{"id":"65a2243a-d3d0-4392-84bb-d3ce1b34ab4c","subtype":"Figure","type":"Plot"},"ticker":{"id":"4c9d0fad-266a-439c-9eac-925315516e75","type":"BasicTicker"}},"id":"8e02e26a-6734-465a-acce-8bff3ed9e96a","type":"LinearAxis"},{"attributes":{"overlay":{"id":"a84b1333-cdc8-4b7b-b674-863520482896","type":"BoxAnnotation"},"plot":{"id":"65a2243a-d3d0-4392-84bb-d3ce1b34ab4c","subtype":"Figure","type":"Plot"}},"id":"e5f21db3-7a5a-40f7-93ba-506a8884401c","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"65a2243a-d3d0-4392-84bb-d3ce1b34ab4c","subtype":"Figure","type":"Plot"}},"id":"51d19b87-487d-493f-a987-56897801c64d","type":"PanTool"},{"attributes":{"plot":{"id":"65a2243a-d3d0-4392-84bb-d3ce1b34ab4c","subtype":"Figure","type":"Plot"},"ticker":{"id":"4c9d0fad-266a-439c-9eac-925315516e75","type":"BasicTicker"}},"id":"4883f061-ec22-4ad2-9d9e-cb47605fba29","type":"Grid"},{"attributes":{},"id":"5e327b7d-36a2-4186-b97a-d22e658afe1b","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1300]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1300]}}},"id":"b8785891-ad93-4cfe-9821-7a1d2ced14b9","type":"ColumnDataSource"},{"attributes":{"label":{"value":"Damped System"},"renderers":[{"id":"48e5b494-9cca-4fca-8302-3461308b69cf","type":"GlyphRenderer"}]},"id":"9be7243a-b2d3-4507-99a2-5262123c6123","type":"LegendItem"},{"attributes":{},"id":"4c9d0fad-266a-439c-9eac-925315516e75","type":"BasicTicker"},{"attributes":{"axis_label":"Output","formatter":{"id":"90990f2e-2b94-4d6e-8090-dfcc48108685","type":"BasicTickFormatter"},"plot":{"id":"65a2243a-d3d0-4392-84bb-d3ce1b34ab4c","subtype":"Figure","type":"Plot"},"ticker":{"id":"5e327b7d-36a2-4186-b97a-d22e658afe1b","type" ...
