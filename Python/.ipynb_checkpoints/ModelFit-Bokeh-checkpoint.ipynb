# %% [markdown]
# # FOTD Model Fit Example
#
# Fit some high order Model to a FOTD System

# %%
# General Pacakages
import sympy as sp
import numpy as np
import control as cn
#Plotting
import bokeh.plotting as bk
import bokeh.io as bi
from bokeh.io import export_svgs
bi.output_notebook()
import holoviews as hv
hv.extension('bokeh')

# Define the TUBS Colorscale for 10 Colors
# TUBS Rot, Gelb, Orange, Hellgrün, Grün, Dunkelgrün, Hellblau, Blau, Dunkelblau, Violett
TUBScolorscale=['rgba(190,30,60,0.9)',
               'rgba(255,200,42,0.9)',
               'rgba(225,109,0,0.9)',
               'rgba(172,193,58,0.9)',
               'rgba(109,131,0,0.9)',
               'rgba(0,83,74,0.9)',
               'rgba(102,180,211,0.9)',
               'rgba(0,112,155,0.9)',
               'rgba(0,63,87,0.9)',
               'rgba(138,48,127,0.9)']
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-124aceb7e3fd> in <module>()
#       6 import bokeh.plotting as bk
#       7 import bokeh.io as bi
# ----> 8 from bokeh.io import export_svgs
#       9 bi.output_notebook()
#      10 import holoviews as hv
#
# ImportError: cannot import name 'export_svgs'

# %%
## Generate a High Order System
num = [[[10]]]
den = [[[3,20,1]]]
G = cn.tf(num,den)*cn.tf([[[1,1]]],[[[0.1,5,1]]])
t = np.linspace(0,130,1300)
y, t = cn.step(G,t)
# Add noise
ynoise = np.random.normal(0,.2,np.size(y))
yreal = y+ynoise
u = np.ones_like(y)
np.argmax(yreal), np.size(yreal)

def Area_Fit(y,u,t):
    'Returns a FOTD Model'
    # Truncate for Maximum
    i_end = y.argmax(axis=0)
    print(np.size(y))
    print(i_end)
    yp = y[0:i_end+1]
    up = u[0:i_end+1]
    tp = t[0:i_end+1]
    print(yp[-1])
    print(np.max(y))
    # Get Gain
    KM = (yp[-1]-yp[0])/(up[-1])
    # Get the Residence Time
    Tar = 1/KM * np.trapz(yp[-1]-yp,tp)
    # Time Constant
    T = np.exp(1)/KM*np.trapz(yp[np.where(tp<=Tar)],tp[np.where(tp<=Tar)])
    # Delay
    L = Tar-T
    # Create Model
    print(T)
    print(L)
    print(Tar)
    num,den = cn.pade(L,9)
    GM = cn.tf([[np.convolve([KM],num)]],[[np.convolve([T,1],den)]])
    return GM

GM = Area_Fit(yreal,u,t)
yM,tM = cn.step(GM,t)
# Out:
# 1300
# 962
# 10.4481795056
# 10.4481795056
# 22.3406464618
# 3.74931263656
# 26.0899590983

# %%
# Define the figure
p1 = bk.figure(x_range=(t[0],t[-1]), y_range = (y[0],np.ceil(np.max(yreal))), plot_width = 800, plot_height = 300)
#p1.grid.minor_grid_line_color = '#eeeeee'
# Define the Data
p1.line(tM,yM, line_color="navy", line_width = 2, legend="Model")
p1.scatter(t,yreal, size=2,line_color = "orange",fill_color="orange", fill_alpha=0.01,legend="Measurement")
p1.line(t,y, line_color="red", line_width = 2, line_dash = "dashed",legend="Original")
# Define the axis label
p1.xaxis.axis_label = "Time [min]"
p1.yaxis.axis_label = "Output"
p1.legend.location = "bottom_right"
# Show and Export
p1.output_backend = "svg"
export_svgs(p1, filename="TEST.svg")
bk.show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c66af598-a600-4f6c-867e-465b4eef54d7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c66af598-a600-4f6c-867e-465b4eef54d7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c66af598-a600-4f6c-867e-465b4eef54d7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c66af598-a600-4f6c-867e-465b4eef54d7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ce00c915-32b5-4ca0-9a38-85baa8ef9a63":{"roots":{"references":[{"attributes":{},"id":"95785ae3-f97e-43f6-925d-ff5c2c5a5500","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":11.0},"id":"1732641f-c025-4435-bb03-49465e8c97f6","type":"Range1d"},{"attributes":{"plot":{"id":"aeceb2cc-8547-4b6b-a231-172a4cec0120","subtype":"Figure","type":"Plot"}},"id":"18e7b11f-d905-485b-b4ce-768416c621d7","type":"PanTool"},{"attributes":{"label":{"value":"Measurement"},"renderers":[{"id":"8b29231f-21bb-4153-b2c0-8e8dc1fb2f2b","type":"GlyphRenderer"}]},"id":"f474891e-956e-4591-91f2-25805f8d9325","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1300]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1300]}}},"id":"f275a1d3-02de-41f6-a125-5f3078b7192f","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"6e9b96bf-bfd3-4113-ae2d-7ac61b89e1b8","type":"BoxAnnotation"},"plot":{"id":"aeceb2cc-8547-4b6b-a231-172a4cec0120","subtype":"Figure","type":"Plot"}},"id":"45586f32-448b-4e24-9c25-7fd7db628365","type":"BoxZoomTool"},{"attributes":{},"id":"f7bc2433-d273-4b2a-970b-b1175ce89f4c","type":"LinearScale"},{"attributes":{"dimension":1,"plot":{"id":"aeceb2cc-8547-4b6b-a231-172a4cec0120","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5ad3e27-cb17-4992-b4df-19f0696e1952","type":"BasicTicker"}},"id":"0478dfc4-18fd-451c-bfa6-b2abfeb68ed5","type":"Grid"},{"attributes":{"line_color":{"value":"navy"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"8b79e073-b604-49e0-aa26-263856c0db6f","type":"Line"},{"attributes":{"line_color":{"value":"red"},"line_dash":[6],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"a9f395ff-5729-45da-aea2-96811fa13fa4","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1300]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1300]}}},"id":"048ab728-449e-4a71-85c1-40f2e74c0bbf","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"aeceb2cc-8547-4b6b-a231-172a4cec0120","subtype":"Figure","type":"Plot"}},"id":"46e647f5-3e8f-4e68-8599-e9eb0abb83d2","type":"HelpTool"},{"attributes":{},"id":"e5ad3e27-cb17-4992-b4df-19f0696e1952","type":"BasicTicker"},{"attributes":{"plot":{"id":"aeceb2cc-8547-4b6b-a231-172a4cec0120","subtype":"Figure","type":"Plot"}},"id":"8d7aaf30-f189-47b3-87c4-76b47c92a623","type":"SaveTool"},{"attributes":{"callback":null,"end":130.0},"id":"4eba111d-77f5-44eb-a96a-cd83ffe81f71","type":"Range1d"},{"attributes":{"plot":{"id":"aeceb2cc-8547-4b6b-a231-172a4cec0120","subtype":"Figure","type":"Plot"}},"id":"dbac4c33-f20e-4681-8d6f-1aac4d09e38c","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"18e7b11f-d905-485b-b4ce-768416c621d7","type":"PanTool"},{"id":"dbac4c33-f20e-4681-8d6f-1aac4d09e38c","type":"WheelZoomTool"},{"id":"45586f32-448b-4e24-9c25-7fd7db628365","type":"BoxZoomTool"},{"id":"8d7aaf30-f189-47b3-87c4-76b47c92a623","type":"SaveTool"},{"id":"7b0e4f6d-4746-4b9d-943f-23c916100f18","type":"ResetTool"},{"id":"46e647f5-3e8f-4e68-8599-e9eb0abb83d2","type":"HelpTool"}]},"id":"3d8110ab-6cc2-4dc0-b566-70dafd920de6","type":"Toolbar"},{"attributes":{"data_source":{"id":"f275a1d3-02de-41f6-a125-5f3078b7192f","type":"ColumnDataSource"},"glyph":{"id":"8b79e073-b604-49e0-aa26-263856c0db6f","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"510bf17d-fff9-47ea-97b6-62ab978492a7","type":"Line"},"selection_glyph":null},"id":"f2e3eb97-5438-42c7-b902-67a76872b581","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"048ab728-449e-4a71-85c1-40f2e74c0bbf","type":"ColumnDataSource"},"glyph":{"id":"a9f395ff-5729-45da-aea2-96811fa13fa4","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0a2c35ae-2edf-495e-afea-ea6f15535357","type ...

# %%
yend = yM[-1]*np.ones_like(yreal)
ye1 = yend[np.where(t<4)]
yM1 = yM[np.where(t<4)]
t1 = t[np.where(t<4)]
ye2 = yend[np.where(t>=4)]
yM2 = yM[np.where(t>=4)]
t2 = t[np.where(t>=4)]

dims = dict(kdims=['Time'], vdims=['Output'])
line1 = hv.Area((y,yM), label='Steady State', **dims)
#line2 = hv.Area(y, label='Dynamic', **dims)
#jython = hv.Area(jython, label='jython', **dims)

style1 = dict(fill_alpha=0.5, fill_color="navy")
style2 = dict(fill_alpha=0.5, fill_color="orange")

plot  = dict(width=800, height=300)
opts = {'Curve': {'style': style, 'plot': plot}}

p2 = hv.Area((t1, ye1, yM1),kdims = ['Time'], vdims = ['Output','Error'])(style={'Area': style1}, plot={'Area':plot})*hv.Area((t2, ye2, yM2),kdims = ['Time'], vdims = ['Output','Error'])(style={'Area': style2}, plot={'Area':plot})
# Out:
# :Overlay
#    .Area.I  :Area   [Time]   (Output,Error)
#    .Area.II :Area   [Time]   (Output,Error)

# %%
w = np.logspace(-5,5,10000)
real1,imag1,freq1 = cn.nyquist_plot(G,w)
real2,imag2,freq2 = cn.nyquist_plot(GM,w)

# %%
# Define the figure
p2 = bk.figure(plot_width = 800, plot_height = 300)
#p1.grid.minor_grid_line_color = '#eeeeee'
# Define the Data
p2.line(real2,imag2, line_color="navy", line_width = 2, legend="Model")
p2.line(real1,imag1, line_color="red", line_width = 2, line_dash = "dashed",legend="Original")
# Define the axis label
p2.xaxis.axis_label = "Re"
p2.yaxis.axis_label = "Im"
p2.legend.location = "bottom_left"
# Show and Export
p2.output_backend = "svg"
export_svgs(p2, filename="TEST3.svg")
bk.show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bcd486b8-8275-466c-a7c0-04b4bda309d1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bcd486b8-8275-466c-a7c0-04b4bda309d1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"73fd3df4-32e6-4495-8937-167097d4a7cd","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"a3a8902a-e6b0-4eaf-8f45-38bd2f42a601","type":"Line"},{"attributes":{"overlay":{"id":"eb39a310-a4cf-4a43-9d9e-77193a4e9131","type":"BoxAnnotation"},"plot":{"id":"2248a7a5-34b0-44f6-a5b4-88ac71182669","subtype":"Figure","type":"Plot"}},"id":"c17f62df-e4cc-4ba5-9b36-e20c3e554e8a","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"2248a7a5-34b0-44f6-a5b4-88ac71182669","subtype":"Figure","type":"Plot"}},"id":"bf2970b3-e46b-44cd-b33d-9bb7f66310f4","type":"PanTool"},{"attributes":{},"id":"ce9d2a56-eb4b-409f-9307-a3944e981fe1","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"], ...

# %%
mag1,phase1,omega1 = cn.bode_plot(G,w)
mag2,phase2,omega2 = cn.bode_plot(GM,w)

# Define the figure
p3 = bk.figure(plot_width = 800, plot_height = 300, x_axis_type="log", y_axis_type="log")

# Define the Data
p3.line(omega2,mag2, line_color="navy", line_width = 2, legend="Model")
p3.line(omega1,mag1, line_color="red", line_width = 2, line_dash = "dashed",legend="Original")
# Define the axis label
p3.xaxis.axis_label = "Frequency [rad/s]"
p3.yaxis.axis_label = "Gain [dB]"

# Define the figure
p4 = bk.figure(plot_width = 800, plot_height = 300, x_axis_type="log", y_range = [-360,0])
# Define the Data
p4.line(omega2,phase2, line_color="navy", line_width = 2, legend="Model")
p4.line(omega1,phase1, line_color="red", line_width = 2, line_dash = "dashed",legend="Original")
# Define the axis label
p4.xaxis.axis_label = "Frequency [rad/s]"
p4.yaxis.axis_label = "Phase [rad]"


c1 = bk.gridplot([[p3],[p4]])
# Show and Export
p3.output_backend = "svg"
p4.output_backend = "svg"

export_svgs(p3, filename="TEST4.svg")
export_svgs(p4, filename="TEST5.svg")

bk.show(c1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8cd226fd-ed72-476e-8059-596be5f195c2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8cd226fd-ed72-476e-8059-596be5f195c2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8cd226fd-ed72-476e-8059-596be5f195c2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8cd226fd-ed72-476e-8059-596be5f195c2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ca1e3ba5-165a-4e0c-8e76-5f13908e1348":{"roots":{"references":[{"attributes":{"num_minor_ticks":10},"id":"9d08c255-3fac-4efd-b810-1154fe30f9bd","type":"LogTicker"},{"attributes":{"axis_label":"Phase [rad]","formatter":{"id":"cf7ca3f2-fe4c-4f90-9e4f-d947b4a4f8f2","type":"BasicTickFormatter"},"plot":{"id":"52750f2b-dfbd-41d2-81a8-b9bd53e9489e","subtype":"Figure","type":"Plot"},"ticker":{"id":"0417b2d8-231d-4bb1-ac79-71737719be02","type":"BasicTicker"}},"id":"e41d7127-5d91-49c1-bfd3-628829dbb578","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":
"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"bae1b421-c743-4e02-9b4d-033a8a54b037","type":"Line"},{"attributes":{"plot":null,"text":""},"id":"89fa7837-f6ae-439f-b0dd-3a84b0ac6dad","type":"Title"},{"attributes":{},"id":"c432cdaf-f9b9-4619-8e5f-c4e971debaab","type":"LogScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","t ...

# %%
## Generate a High Order System
num = [[[1]]]
den = [[[1,.5,1]]]
G = cn.tf(num,den)
t = np.linspace(0,130,1300)
y1, t1 = cn.step(G,t)
u = np.ones_like(y)
np.argmax(yreal), np.size(yreal)
GM = Area_Fit(y1,u,t)
yM1,tM1 = cn.step(GM,t)

## Generate a High Order System
num = [[[1]]]
den = [[[1,1.5,1]]]
G = cn.tf(num,den)
t = np.linspace(0,130,1300)
y2, t2 = cn.step(G,t)
u = np.ones_like(y2)
np.argmax(yreal), np.size(yreal)
GM = Area_Fit(y2,u,t2)
yM2,tM2 = cn.step(GM,t)

## Generate a High Order System
num = [[[1]]]
den = [[[1,10,1]]]
G = cn.tf(num,den)
t = np.linspace(0,130,1300)
y3, t3 = cn.step(G,t)
u = np.ones_like(y3)
np.argmax(yreal), np.size(yreal)
GM = Area_Fit(y3,u,t3)
yM3,tM3 = cn.step(GM,t3)
# Out:
# 1300
# 32
# 1.44394660057
# 1.44394660057
# 0.667262449091
# 0.830443161261
# 1.49770561035
# 1300
# 47
# 1.02834469168
# 1.02834469168
# 0.983750154171
# 0.647211076527
# 1.6309612307
# 1300
# 1299
# 0.999998000092
# 0.999998000092
# 9.74130391083
# 0.258437663845
# 9.99974157468

# %%
# Define the figure
p1 = bk.figure(x_range=(t[0],t[-1]), plot_width = 800, plot_height = 300)
#p1.grid.minor_grid_line_color = '#eeeeee'
# Define the Data
p1.line(tM1,yM1, line_color="navy", line_width = 2, legend="Underdamped Model")
p1.line(t1,y1, line_color="red", line_width = 2, line_dash = "dashed",legend="Underdamped System")

p1.line(tM2,yM2, line_color="navy", line_width = 2, legend="Damped Model")
p1.line(t2,y2, line_color="red", line_width = 2, line_dash = "dashed",legend="Damped System")


p1.line(tM3,yM3, line_color="navy", line_width = 2, legend="Overdamped Model")
p1.line(t3,y3, line_color="red", line_width = 2, line_dash = "dashed",legend="Overdamped System")


# Define the axis label
p1.xaxis.axis_label = "Time [min]"
p1.yaxis.axis_label = "Output"
p1.legend.visible = False
# Show and Export
p1.output_backend = "svg"
export_svgs(p1, filename="TEST6.svg")
bk.show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fbefc127-e65c-488b-adf2-669ce3102648"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fbefc127-e65c-488b-adf2-669ce3102648");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fbefc127-e65c-488b-adf2-669ce3102648");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fbefc127-e65c-488b-adf2-669ce3102648' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e875580b-dc1f-4146-bc23-a1c14f2696a4":{"roots":{"references":[{"attributes":{},"id":"f84f1e7e-42ea-4fde-831b-84a87cbf31be","type":"LinearScale"},{"attributes":{"plot":{"id":"e2744fe3-dc53-491e-96b5-78ab900754dc","subtype":"Figure","type":"Plot"},"ticker":{"id":"92ac7faa-70ac-4c3f-9a05-80771e736e53","type":"BasicTicker"}},"id":"ca466605-ad37-49ec-a2f7-22af537d1ef3","type":"Grid"},{"attributes":{"data_source":{"id":"e72005fc-efa6-4b4b-aee3-aced0b33b94d","type":"ColumnDataSource"},"glyph":{"id":"37f862f7-168c-4bea-befa-48ead573186d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"00b6b9a6-3289-416e-bb65-e196014674c0","type":"Line"},"selection_glyph":null},"id":"da47da8f-00c7-4934-b503-783c7354ba2a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1300]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1300]}}},"id":"e72005fc-efa6-4b4b-aee3-aced0b33b94d","type":"ColumnDataSource"},{"attributes":{"axis_label":"Time [min]","formatter":{"id":"b717fc89-ab3b-4da5-a94c-3842cb231825","type":"BasicTickFormatter"},"plot":{"id":"e2744fe3-dc53-491e-96b5-78ab900754dc","subtype":"Figure","type":"Plot"},"ticker":{"id":"92ac7faa-70ac-4c3f-9a05-80771e736e53","type":"BasicTicker"}},"id":"e81e2eb7-5629-4388-b894-a93bfdd48a7c","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"ea464b74-6729-4c74-afa9-765de912c3fc","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"52143404-84ae-4e9e-821a-52d83ce2693b","type":"Line"},{"attributes":{"plot":{"id":"e2744fe3-dc53-491e-96b5-78ab900754dc","subtype":"Figure","type":"Plot"}},"id":"2155fa77-fc69-40cb-b2e9-bf4658be1c71","type":"PanTool"},{"attributes":{"data_source":{"id":"efbd2661-442d-4f38-9898-b03e38a8c333","type":"ColumnDataSource"},"glyph":{"id":"754cb8bc-7729-49af-8e7a-3612a6d6acb9","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"15fe87cf-b35e-4298-891b-fc9a53f7985c","type":"Line"},"selection_glyph":null},"id":"bac3f7e9-8e1a-4ddb-a276-926d7555a6f3","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"24d1337c-de8d-465b-8fcd-a3a93e5df135","type":"Line"},{"attributes":{"axis_label":"Output","formatter":{"id":"d6a97b13-618d-48e3-b3ec-ba3d4421af6e","type":"BasicTickFormatter"},"plot":{"id":"e2744fe3-dc53-491e-96b5-78ab900754dc","subtype":"Figure","type":"Plot"},"ticker":{"id":"d863a928-fa68-4a7f-b7d6-221a0062465d","type":"BasicTicker"}},"id":"79a6a8dc-88ab-4bc1-9785-7b0fa37098aa","type":"LinearAxis"},{"attributes":{"line_color":{"value":"red"},"line_dash":[6],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"754cb8bc-7729-49af-8e7a-3612a6d6acb9","type":"Line"},{"attributes":{"plot":null,"text":""},"id":"780e1b17-7ed5-4d0b-a6ca-f6f5dc431d2d","type":"Title"},{"attributes":{},"id":"92ac7faa-70ac-4c3f-9a05-80771e736e53","type":"BasicTicker"},{"attributes":{"plot":{"id":"e2744fe3-dc53-491e-96b5-78ab900754dc","subtype":"Figure","type":"Plot"}},"id":"87b574b0-9813-4d4b-8d15-eae437523830","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"00b6b9a6-3289-416e-bb65-e196014674c0","type":"Line"},{"attributes":{"line_color":{"value":"navy"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"37f862f7-168c-4bea-befa-48ead573186d","type":"Line"},{"attributes":{"line_color":{"value":"navy"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"f31aebf3-a1e3-400d-aad6-099af0d483e4","type":"Line"},{"attributes":{},"id":"d863a928-fa68-4a ...
