# %%
# Import the needed Packages
# FMU Simulation
import MoBASimulator as mb
# Numpy
import numpy as np
# Bokeh for Plotting
import bokeh.plotting as bk
import bokeh.io as bi
#from bokeh.io import export_svgs
bi.output_notebook()
# Algorithms
import Algorithms as alg

# TUBS Rot, Gelb, Orange, Hellgrün, Grün, Dunkelgrün, Hellblau, Blau, Dunkelblau, Violett
TUBScolorscale=[(190,30,60,0.9),
               (255,200,42,0.9),
               (225,109,0,0.9),
               (172,193,58,0.9),
               (109,131,0,0.9),
               (0,83,74,0.9),
               (102,180,211,0.9),
               (0,112,155,0.9),
               (0,63,87,0.9),
               (138,48,127,0.9)]

# Model Parameter
#k = np.random.uniform(-10,10,(2,2))
#t = np.random.uniform(1,20,(2,2))
#l = np.random.uniform(10,20,(2,2))

# Rosenbrock
#k = [[1.,2./3.],[1.,1.]]
#t = [[1.,1./3.],[1.,1.]]
#l = [[1e-10,1e-10],[1e-10,1e-10]]

# Woodberry
k = [[12.8,-18.9],[6.6,-19.4]]
t = [[16.7,21.0],[10.9,14.4]]
l = [[1,3],[7,3]]


# The needed Parameter for FOTDs - to identify
K = np.zeros((2,2))
T = np.zeros((2,2))
L = np.zeros((2,2))

# Load a Model
sim = mb.Simulator()
sim.clear()
sim.loadModel("C:/Users/juliu/Documents/Thesis/Modelica/FMU/2_2/Masterthesis_Models_mimo_0processmodel.fmu")

# Show log window
sim.showLogWindow()

# Parameter Values
params = {}
# Loop over system size
for outputs in range(1,3):
    for inputs in range(1,3):
        # Process Parameter 
        # System Gain
        params.update({"fmu.num["+str(outputs)+","+str(inputs)+",1]": k[outputs-1][inputs-1]})
        # System Lag
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",1]": t[outputs-1][inputs-1]})
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",2]": 1})
        # System Delay
        params.update({"fmu.delay["+str(outputs)+","+str(inputs)+"]": l[outputs-1][inputs-1]})

# Set Parameter and show for checking
sim.set(params)
#sim.showParameterDialog()
#print(params)



# First run, Input 1 -> Output 1 & 2
sim.set({"fmu.u[1]": 1,"fmu.u[2]": 0})
# Set timestep = 1e-2, endtime = 100
sim.resetModelState()
res = sim.simulate(0.01, 150)

# Get the signals
y = res["fmu.y[1]"]
y2 = res["fmu.y[2]"]
u = res["fmu.u[1]"]
time = res["time"]

# Get TF from Input 1 to Output 1
K[0][0],T[0][0],L[0][0]=alg.Integral_Identification(y,u,time, graphics='on')
# Get TF from Input 1 to Output 2
K[1][0],T[1][0],L[1][0]=alg.Integral_Identification(y2,u,time, graphics = 'on')


# Second run, Input 2 -> Output 1 & 2
# Reload the Model to set everything to zero
sim.resetModelState()
sim.set({"fmu.u[1]":0, "fmu.u[2]":1})
# Set timestep = 1e-2, endtime = 100
res=sim.simulate(0.01, 150)

# Get the signals
y = res["fmu.y[1]"]
y2 = res["fmu.y[2]"]
u = res["fmu.u[2]"]
time = res["time"]

# Get TF from Input 2 to Output 1
K[0][1],T[0][1],L[0][1] = alg.Integral_Identification(y,u,time)
# Get TF from Input 2 to Output 2
K[1][1],T[1][1],L[1][1] = alg.Integral_Identification(y2,u,time)

# Make variable storage for step response of closed loop
y = []
u = []
time = []

# Loop over the methods for controller design
for methods in range(0,3):
    if methods == 0:
        # Make a decentralized controller
        KY,B,D = alg.Control_Decentral(K,T,L)
    elif methods == 1:
        # Make a decoupled controller with Astrom
        KY,B,D = alg.Control_Astrom(K,T,L,0.01*np.eye(2,2), graphics = 'on')
    else:
        # Make a decoupled controller with modified Astrom
        KY,B,D = alg.Control_Decoupled(K,T,L,0.01*np.eye(2,2))

    # Make zeros to 1e-10 for numerical stable process
    KY[KY==0] = 1e-10
    B[B==0] = 1e-10
    D[D==0] = 1e-10


    # Load the closed loop model
    sim.clear()
    sim.loadModel("C:/Users/juliu/Documents/Thesis/Modelica/FMU/2_2/Masterthesis_Models_mimo_0closedloop.fmu")
    # Parameter Valuess
    params = {}
    
    # Loop over system size
    for outputs in range(1,3):
        for inputs in range(1,3):
            # Controller Parameter 
            # Proportional Gain
            params.update({"fmu.kp["+str(outputs)+","+str(inputs)+"]": KY[outputs-1][inputs-1][0]})
             # Integral Gain
            params.update({"fmu.ki["+str(outputs)+","+str(inputs)+"]": KY[outputs-1][inputs-1][1]})
            # Decoupler
            params.update({"fmu.d["+str(outputs)+","+str(inputs)+"]": D[outputs-1][inputs-1]})
            # Set Point Weight
            params.update({"fmu.b["+str(outputs)+","+str(inputs)+"]": B[outputs-1][inputs-1]})
            # Process Parameter 
            # Process Parameter 
            # System Gain
            params.update({"fmu.num["+str(outputs)+","+str(inputs)+",1]": k[outputs-1][inputs-1]})
            # System Lag
            params.update({"fmu.den["+str(outputs)+","+str(inputs)+",1]": t[outputs-1][inputs-1]})
            params.update({"fmu.den["+str(outputs)+","+str(inputs)+",2]": 1})
            # System Delay
            params.update({"fmu.delay["+str(outputs)+","+str(inputs)+"]": l[outputs-1][inputs-1]})

    # Set Parameter Values
    sim.set(params)
    
    # First run, Input 1 -> Output 1 & 2
    sim.resetModelState()
    sim.set({"fmu.u[1]": 1.,"fmu.u[2]": 0.})
    res=sim.simulate(0.05, 150)
    # Second run, Input 2-> Output 1 & 2
    sim.set({"fmu.u[1]": 1.,"fmu.u[2]": 1})
    res=sim.simulate(0.05, 300)

    # Store the output
    y.append([res["fmu.y[1]"],res["fmu.y[2]"]])
    u.append([res["fmu.u[1]"],res["fmu.u[2]"]])
    time.append([res["time"],res["time"]])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ed5e0c1a-7dcf-4b96-94f4-b140a7c7317e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c0e2919d-ff43-4cde-bee9-b1a09fe64192"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("c0e2919d-ff43-4cde-bee9-b1a09fe64192");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c0e2919d-ff43-4cde-bee9-b1a09fe64192");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c0e2919d-ff43-4cde-bee9-b1a09fe64192' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"02967690-d247-47f1-9ceb-308df26c84fa":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"4b127c71-bebc-4c9e-879a-f4083f6a6547","subtype":"Figure","type":"Plot"},"ticker":{"id":"51aff106-210b-45f1-8d3c-6a9a3060a213","type":"BasicTicker"}},"id":"ea9c156e-3a37-4a15-97a9-6647a2809bcd","type":"Grid"},{"attributes":{"items":[{"id":"ad419444-6f71-46e8-8ccc-92664f86b689","type":"LegendItem"},{"id":"d45f8a65-70fd-4acf-ac76-63e0e150bcf7","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"4b127c71-bebc-4c9e-879a-f4083f6a6547","subtype":"Figure","type":"Plot"}},"id":"02001a95-236f-4786-9c53-f6c77e232789","type":"Legend"},{"attributes":{},"id":"11199991-a0fe-4f8d-94e9-2833f9978494","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"c83c5f11-b372-4beb-8a8a-69ca3e6bbf22","type":"BasicTickFormatter"},"plot":{"id":"4b127c71-bebc-4c9e-879a-f4083f6a6547","subtype":"Figure","type":"Plot"},"ticker":{"id":"51aff106-210b-45f1-8d3c-6a9a3060a213","type":"BasicTicker"}},"id":"5f5a6d4d-24ca-4dfc-a24f-8270277361f9","type":"LinearAxis"},{"attributes":{"source":{"id":"a02abb5b-9183-495d-aba2-54a7abb42186","type":"ColumnDataSource"}},"id":"68bd1edc-d94e-4d97-9342-833d0a7fbdfb","type":"CDSView"},{"attributes":{"formatter":{"id":"11199991-a0fe-4f8d-94e9-2833f9978494","type":"BasicTickFormatter"},
},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"e624726d-e1c2-4070-84e5-82526305fd34","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"89c13139-0fb2-4666-8661-fb225033be5d","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"082f8de5-9d6c-4486-9214-a3cc47b682f8","type":"LinearAxis"}],"left":[{"id":"7ba1315d-4eca-4d58-9cd9-510773f1ff10","type":"LinearAxis"}],"renderers":[{"id":"082f8de5-9d6c-4486-9214-a3cc47b682f8","type":"LinearAxis"},{"id":"64221394-234f-470f-aae5-5163937d14d7","type":"Grid"},{"id":"7ba1315d-4eca-4d58-9cd9-510773f1ff10","type":"LinearAxis"},{"id":"68df5ffd-723e-470e-856b-2cba7e77745b","type":"Grid"},{"id":"36bd1c8b-7393-42e3-a76c-43453e7165c3","type":"BoxAnnotation"},{"id":"baf5f3b8-5bfa-4d48-ac6a-8085e4e61fa2","type":"Legend"},{"id":"29fc7c24-71b1-48ca-bec4-1774c96ffa12","type":"GlyphRenderer"},{"id":"aa8f7575-5485-4500-9ca8-36766baaf816","type":"GlyphRenderer"},{"id":"0d939f3a-359e-4cb0-82ba-0bb854c357ba","type":"GlyphRenderer"},{"id":"bf6ddb1c-cdc2-40d4-a23d-7ece6d7a40e3","type":"GlyphRenderer"}],"title":{"id":"f811a503-d077-4066-ba2c-c8235354ee12","type":"Title"},"toolbar":{"id":"c78c96e0-df1f-4f1a-a12e-c9b8da0c466a","type":"Toolbar"},"x_range":{"id":"dd124a83-ec6a-45cb-9976-93adcae04f3a","type":"DataRange1d"},"x_scale":{"id":"dcdec330-2abb-4f25-981d-c5ed36bb44f5","type":"LinearScale"},"y_range":{"id":"15062633-79ae-4875-86d3-8290cb6513fe","type":"DataRange1d"},"y_scale":{"id":"681a77d5-37df-4a8e-b142-2e64b905f778","type":"LinearScale"}},"id":"111ce808-6a45-48a1-889e-f5221a89f248","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"rgba(102, 180, 211, 0.9)"},"x":{"field":"x"},"y":{"field":"y"}},"id":"05adf53c-6836-4ef2-8c30-8814d45e89f7","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"36bd1c8b-7393-42e3-a76c ...

# %%
# Make Aström Reference from Paper
KY = np.array([ [[1.1338, 0.19, 0], [0,0,0]], [[0,0,0], [0.7,0.123,0]] ])
B = np.array([[0,0],[0,0]])
D = np.linalg.inv(k)

# Make zeros to 1e-10 for numerical stable process
KY[KY==0] = 1e-10
B[B==0] = 1e-10
D[D==0] = 1e-10


# Load the closed loop model
sim.clear()
sim.loadModel("C:/Users/juliu/Documents/Thesis/Modelica/FMU/2_2/Masterthesis_Models_mimo_0closedloop.fmu")
sim.reloadModel()
# Parameter Values
params = {}
# Loop over system size
for outputs in range(1,3):
    for inputs in range(1,3):
        # Controller Parameter 
        # Proportional Gain
        params.update({"fmu.kp["+str(outputs)+","+str(inputs)+"]": KY[outputs-1][inputs-1][0]})
         # Integral Gain
        params.update({"fmu.ki["+str(outputs)+","+str(inputs)+"]": KY[outputs-1][inputs-1][1]})
        # Decoupler
        params.update({"fmu.d["+str(outputs)+","+str(inputs)+"]": D[outputs-1][inputs-1]})
        # Set Point Weight
        params.update({"fmu.b["+str(outputs)+","+str(inputs)+"]": B[outputs-1][inputs-1]})
        # Process Parameter 
        # System Gain
        params.update({"fmu.num["+str(outputs)+","+str(inputs)+",1]": k[outputs-1][inputs-1]})
        # System Lag
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",1]": t[outputs-1][inputs-1]})
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",2]": 1})
        # System Delay
        params.update({"fmu.delay["+str(outputs)+","+str(inputs)+"]": l[outputs-1][inputs-1]})
# Set Parameter Values
sim.set(params)
#sim.showParameterDialog()

# First run, t<40
sim.resetModelState()
sim.set({"fmu.u[1]": 1,"fmu.u[2]": 0})
res=sim.simulate(0.1, 150)
# t>=40
sim.set({"fmu.u[1]": 1,"fmu.u[2]": 1})
# Set timestep = 1e-2, endtime = 100
res=sim.simulate(0.1, 300)
# Out:
# [[ 0.15698333 -0.15293737]
#  [ 0.0534067  -0.10357663]]

# %%
from bokeh.layouts import gridplot, layout

# First figure, y1
p1 = bk.figure(title = "Wood-Berry's Binary Distillation Column",height= 300, width = 800, y_range = (0,1.5))
p1.line(res["time"],res["fmu.y[1]"], color = "grey", line_width = 1, line_dash = "dashed")
p1.line(time[0][0],y[0][0], color = TUBScolorscale[6], line_width = 2)
p1.line(time[1][0],y[1][0], color = TUBScolorscale[0], line_width = 2)
p1.line(time[2][0],y[2][0], color = TUBScolorscale[2], line_width = 2)

# Define the axis label
p1.yaxis.axis_label = "Output 1"

p2 = bk.figure( height= 300, width = 800, y_range = (-0.5, 1.5))
p2.line(res["time"],res["fmu.y[2]"], color = "grey", line_width = 1, line_dash = "dashed", legend = "Reference")
p2.line(time[0][1],y[0][1], color = TUBScolorscale[6], line_width = 2, legend="RGA")
p2.line(time[1][1],y[1][1], color = TUBScolorscale[0], line_width = 2, legend="Aström Decoupling")
p2.line(time[2][1],y[2][1], color = TUBScolorscale[2], line_width = 2, legend="Modified Aström Decoupling")

# Define the axis label
p2.xaxis.axis_label = "Time [s]"
p2.yaxis.axis_label = "Output 2"
p2.legend.location = "bottom_right"

p1.output_backend = "svg"
p2.output_backend = "svg"

p = layout([[p1],[p2]])
bk.show(p)

#from bokeh.io import export_svgs
#export_svgs(p,'Wood-Berry.svg')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="474509e2-6e11-4f52-bb9d-032b8c6a1989"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("474509e2-6e11-4f52-bb9d-032b8c6a1989");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("474509e2-6e11-4f52-bb9d-032b8c6a1989");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '474509e2-6e11-4f52-bb9d-032b8c6a1989' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bac3c84d-fae2-47ed-b416-40529c222ddb":{"roots":{"references":[{"attributes":{},"id":"ee9f6945-312f-400e-bb1c-384b7f727f40","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[3002]},"y":{"__ndarray__":"...","dtype":"float64","shape":[3002]}}},"id":"ba3ba583-9663-4fe6-aa51-d3389521c633","type":"ColumnDataSource"},{"attributes":{"source":{"id":"b36a841c-ce2e-45d0-b10b-9ced041b5cd2","type":"ColumnDataSource"}},"id":"d3ca41bf-729d-4c15-ac74-e000fd480d1a","type":"CDSView"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"f3a93c26-3182-4094-ba60-53a95c07fec9","type":"Line"},{"attributes":{"children":[{"id":"772c4d8f-1f8d-4b69-bcac-f7d5734af063","type":"Row"},{"id":"f54dcf44-8ea5-4123-9402-9e4f3d286054","type":"Row"}]},"id":"734f9a12-2d38-4727-b054-04c1977f2f6f","type":"Column"},{"attributes":{"items":[{"id":"03e7cb51-acac-4b35-acba-ba9c586130e8","type":"LegendItem"},{"id":"8ed37e5f-ba0e-4bf1-b508-2253b6fe29d5","type":"LegendItem"},{"id":"d26ed606-034f-4b15-87f0-7a20172b8193","type":"LegendItem"},{"id":"9191aaf0-bf2d-4a42-bb2d-a4e158eff5e8","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"88b0123a-7d6b-4221-b089-cbcf8b424378","subtype":"Figure","type":"Plot"}},"id":"410cd6f3-8ccf-4c47-a144-9aa49c7e33e3","type":"Legend"},{"attributes":{},"id":"84e07078-7f7f-4f7c-b045-bc323dc959cb","type":"HelpTool"},{"attributes":{"source":{"id":"db99440a-43a5-440d-b483-2b162c63fd06","type":"ColumnDataSource"}},"id":"93223e59-7e25-4170-8131-603cbc3e9305","type":"CDSView"},{"attributes":{},"id":"4ea4dc93-8257-4d5b-b9d6-a462ba0977da","type":"SaveTool"},{"attributes":{"data_source":{"id":"5c6aaf96-84e3-4d25-83b4-8e488a61d1ed","type":"ColumnDataSource"},"glyph":{"id":"55a8bb9f-b7dc-40a7-8199-e3e1a79bcf54","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d4b81f0a-2eb0-4480-8f6e-0875375d0a9a","type":"Line"},"selection_glyph":null,"view":{"id":"fc09ccd1-f2b3-4848-b038-b1d65d54b3cf","type":"CDSView"}},"id":"7401b532-6345-4f02-95f5-d9ab6024d193","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[6002]},"y":{"__ndarray__":"...","dtype":"float64","shape":[6002]}}},"id":"5c6aaf96-84e3-4d25-83b4-8e488a61d1ed","type":"ColumnDataSource"},{"attributes":{},"id":"cbd3716a-ac3f-41d9-9ef0-cb06eaf213c2","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"b70a924b-8b73-4106-8de4-a7353047500e","subtype":"Figure","type":"Plot"}]},"id":"772c4d8f-1f8d-4b69-bcac-f7d5734af063","type":"Row"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6],"x":{"field":"x"},"y":{"field":"y"}},"id":"a60f38da-76fa-4898-bbce-f134c0d545f3","type":"Line"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6f036f38-eaf3-4b2e-ab2a-92ff3a7e486b","type":"PanTool"},{"id":"571813df-0e1a-42ac-9d32-957c1887435a","type":"WheelZoomTool"},{"id":"64313933-1168-430b-84a4-af0f3bcb3d3c","type":"BoxZoomTool"},{"id":"4ea4dc93-8257-4d5b-b9d6-a462ba0977da","type":"SaveTool"},{"id":"4cf3a434-32c4-43ba-8d7a-fcca9847e10c","type":"ResetTool"},{"id":"ee9f6945-312f-400e-bb1c-384b7f727f40","type":"HelpTool"}]},"id":"2b40d25d-2c83-44e8-8eb0-29addd737b03","type":"Toolbar"},{"attributes":{"children":[{"id":"88b0123a-7d6b-4221-b089-cbcf8b424378","subtype":"Figure","type":"Plot"}]},"id":"f54dcf44-8ea5-4123-9402-9e4f3d286054","type":"Row"},{"attributes":{},"id":"7a0961f7-54f0-4005-98de-4df49c3649d5","type":"LinearScale"},{"attributes":{"axis_label":"Output 1","formatter":{"id":"cbd3716a-ac3f-41d9-9ef0-cb06eaf213c2","type":"BasicTickFormatter"},"plot":{"id":"b70a924b-8b73-4106-8de4-a7353047500e","subtype":"Figure","type":"Plot"},"ticker":{"id":"4a9f1439-0bb4-4507-b9b5-9138ef997a19 ...

# %%
# Calculate the difference for the identified system
dK = (1-K/k)*100
dT = (1-T/t)*100
dL = (1-L/l)*100
dK,dT,dL
# Out:
# (array([[ 0.01338251,  0.09140241],
#         [-0.00613756, -0.00140355]]), array([[ 0.29032391,  1.04746475],
#         [-0.01389984,  0.10415278]]), array([[-2.78520634, -2.7867184 ],
#         [-0.07631559, -0.39269152]]))
