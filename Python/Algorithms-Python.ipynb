# %%
import numpy as np

# %%
## Define the Area Fit Method
def Area_Fit(y,u,t):
    """Returns a FOTD Model from the given data.
    y - array of outputs
    u - array of inputs
    t - array of time values
    """
    # Truncate for Maximum
    i_end = abs(y).argmax(axis=0)
    yp = y[0:i_end+1]
    up = u[0:i_end+1]
    tp = t[0:i_end+1]
    # Get Gain
    KM = (yp[-1]-yp[0])/(up[-1])
    # Get the Residence Time
    Tar = 1/KM * np.trapz(yp[-1]-yp,tp)
    # Time Constant
    T = np.exp(1)/KM*np.trapz(yp[np.where(tp<=Tar)],tp[np.where(tp<=Tar)])
    # Delay
    L = Tar-T
    # Check if all arguments are valid
    if (T < 0):
        print("Error - Negative lag")
        return -1
    if (L < 0):
        if (L < 1e-2):
            L = 0
        else:    
            print("Error - Negative delay")
            return -1
    return KM,T,L

# %%
# Define the AMIGO Tuning
def AMIGO_Tune(K,T,L, structure = 'PI'):
    """Computes the PI(D) controller parameter based on AMIGO algorithm;
       Parameter are returned as parallel notation KP,KI,KD and set point;
       Needs first order time delay parameter as input
    """
    # Check for small delay
    if L < 1e-1:
        L = 1e-1
    # PI Controller
    if structure == 'PI':
        # Parameter as Defined in Aström et. al., Advanced PID Control,p.229 
        KP = 0.15/K + (0.35 - L*T /(L+T)**2)*T/(K*L)
        TI = 0.35*L+(13*L*T**2)/(T**2+12*L*T+7*L**2)
        TD = 0.0
        # Set Point Weight, as given on p.235
        if L/(T+L) > 0.5:
            b = 1
        else:
            b = 0.0
        
    elif structure == 'PID':
        KP = 1/K*(0.2+0.45*T/L)
        TI = (0.4*L + 0.8*T)/(L+0.1*T)*L
        TD = (0.5*L*T)/(0.3*L+T)
        # Set Point Weight, Derived from Fig. 7.2, p. 230
        if L/(T+L) < 0.2:
            b = 0.4
        elif L/(T+L) > 0.3:
            b = 1.0
        else:
            # Approximate as Linear Function
            b = 0.4 + (1.0 - 0.4)/(0.3-0.2)*L/(T+L)
    else:
        print("Undefined controller Structure")
        return np.NaN
    KI = KP/TI
    KD = KP*TD
    return [KP,KI,KD],b

# Define AMIGO Detuning
def AMIGO_DETUNE(K,T,L,params,KP, MS = 1.4, structure = 'PI'):
    """Detunes the AMIGO parameter according to Astrom"""
    # Check for small delay
    if L < 1e-1:
        L = 1e-1
    # Needed Parameter
    alpha_D = (MS-1)/MS # See p.255 Eq. 7.19
    beta_D = MS*(MS+np.sqrt(MS**2-1))/2# See p.257 Eq. 7.24
    
    # Define old set of parameter
    KP0 = params[0]
    KI0 = params[1]
    KD0 = params[2]
    
    if structure=='PI':
        # Needed constrain for switch case,See p. 258 Eq. 7.27
        c = KP*K - KP0*K*(L+T)/(beta_D*(alpha_D+KP*K)) - alpha_D
        if c < 0:
            KI = beta_D*(alpha_D+KP*K)**2/(K*(L+T))
        else:
            KI = KI0*(alpha_D+KP*K)/(alpha_D+KP0*K)
        return [KP,KP/KI,0.0]
    if structure == 'PID':
        print("Not implemented")
        return np.NaN
    else:
        print("Undefined controller Structure")
        return np.NaN

# %%
def RGA(K,T,L,w=0):
    """Takes a FOTD System and computes the RGA of the system"""
    if (K.shape != T.shape) or (K.shape != L.shape) or (L.shape != T.shape):
        print("Shapes of parameter array are not equal!")
    # Compute the System
    G = np.absolute(FOTD_IMAG(K,T,L,w))
    # Calculate the RGA
    RGA = np.multiply(G, np.transpose(np.linalg.inv(G)))
    return RGA

# %%
def FOTD_IMAG(K,T,L,w=0):
    """Creates a FOTD MIMO system from the parameter matrices and the current frequency"""
    # Check if all dimensions match
    if (K.shape != T.shape) or (K.shape != L.shape) or (L.shape != T.shape):
        print("Shapes of parameter array are not equal!")
        return np.NaN
    # System Dimension
    if K.ndim == 1:
        # Using system Identity by multiplying with the complex conjugate
        G = 1/(T**2 * w**2 +1)*(K-1j*T*w)*(np.cos(-L*w)+1j*np.sin(-L*w))
    else:
        outputs,inputs = K.shape
        # Create a system within the complex numbers
        G = np.zeros_like(K)
        for i in range(0,inputs):
            for o in range(0,outputs):
                # Using system Identity by multiplying with the complex conjugate
                G[o][i] = 1 /(T[o][i]**2 * w**2 +1) * ( K[o][i] - 1j*T[o][i]*w) *(np.cos(-L[o][i]*w)+1j*np.sin(-L[o][i]*w))
    return G

# %%
def Control_Decentral(K,T,L, w = 0, b=np.empty, structure = 'PI'):
    """ Computes decentralised controller with AMIGO algorithm based on RGA pairing"""
    # Compute SISO Case
    if K.ndim <= 1:
        # Using system Identity by multiplying with the complex conjugate
        params, b0 = AMIGO_Tune(K,T,L)
        # If b is not given, use b from AMIGO
        if b == np.empty:
            Kr = [b0*params[0], params[1], params[2]]
            Ky = params
        else:
            Kr = [b*params[0],params[1],params[2]]
            Ky = params
    # Compute general MIMO Case
    else:
        # Systems dimensions
        outputs,inputs = K.shape
        # Create an empty controller
        Ky = np.zeros([outputs,inputs,3])
        Kr = np.zeros([outputs,inputs,3])
        # Compute RGA -> Checks for Shape
        LG = RGA(K,T,L,w)
        # Get Pairing as an array for every column
        Pairing = np.argmax(LG, axis=0)
        # Iterate through the pairing
        for o in range(0,outputs):
            # Best Pairing
            i = Pairing[o]
            # Compute controller via recursion
            Ky[o][i],Kr[o][i] = Control_Decentral(K[o][i],T[o][i],L[o][i],b)
    return Ky, Kr

# %%
def Control_Astrom(K,T,L,H, MS= None, w = 0, b=np.empty, structure = 'PI'):
    """Computes a Decoupling Controller via Aström Algortihm based on FOTD"""
    # Check Input for Maximum Sensitivity
    if MS is None:
        MS = 1.4*np.eye(K.shape[0],K.shape[1])
    # Compute Determinant of Maximum Sensitivity
    ms = np.linalg.det(MS)
    # Compute SISO Case
    if K.ndim <= 1:
        return Control_Decentral(K,T,L,w,b,structure)
    # Compute General MIMO Case
    else:
        # Systems dimensions
        outputs,inputs = K.shape
        # Check dimensions
        if (K.shape != T.shape) or (K.shape != H.shape) or (K.shape != MS.shape) or (K.shape != L.shape) or (L.shape != T.shape):
            print("Shapes of parameter array are not equal!")
            return np.NaN
        
        # Create an empty controller
        Ky = np.empty([outputs,inputs,3])
        Kr = np.empty([outputs,inputs,3])
               
        # Get minimal Delay/ Time Constant for robust limit of crossover frequency, ignore zeros
        if (L[np.where(L>0)].size !=0) or (T[np.where(T>0)].size !=0):
            if (L[np.where(L>0)].size !=0):
                wc_min = np.min([np.min(L[np.nonzero(L)]),np.min(T[np.nonzero(T)])])
            else:
                wc_min = np.min(np.min(T[np.nonzero(T)]))
        else:
            # Use very high frequency
            wc_min = 1e10
        
        # Compute the decoupler
        D = np.linalg.inv(K)
        # Compute the interaction indeces
        # Since d/ds(Q*K) = d/ds(Q)*K = d/ds(G) we can write the Taylor coefficient
        Gamma = np.abs(np.dot(np.multiply(-K,T+L),D))
        # Set main diagonal to zero
        np.fill_diagonal(Gamma,0)
        # Get the maximum of each row
        GMax = np.argmax(Gamma,axis=0)
        # Iterate through the outputs 
        for o in range(0,outputs):
            # Estimate the new system parameter
            # Get the maximal gain
            l = np.max(L[o][:])
            # Add the systems gain -> scaled
            k = np.dot(K[o][:],D[:][o])
            # Get the system time constant
            t = np.sum(np.multiply(np.multiply(K[o][:],D[:][o]),T[o][:]+L[o][:]))/k - l
            
            # Design a controller based on estimated system
            ky,kr = Control_Decentral(k,t,l,w,b,structure)
            
            # Test for Interaction
            
            # Current maximum interaction
            gmax = Gamma[o][GMax[o]]
            # Check for set point weight, either given
            if b == np.empty:
                # Or computed from AMIGO_TUNE
                b = kr[0]/ky[0]
            # Check for structure
            if structure == 'PI':
                # Set counter for while
                counter=0
                # Set shrinking rate in accordance with golden ratio
                shrink_rate = 0.618
                while (np.abs(H[o][o]/(ms*gmax)) - np.sqrt( (b*ky[0]/wc_min)**2 + ky[1]**2 ) < 0):
                    if counter > 10:
                        #print('Maximal Iteration for detuning reached! Abort')
                        break
                    # Detune the controller with the shrinking rate    
                    ky = AMIGO_DETUNE(k,t,l,ky,shrink_rate*ky[0])
                    # Increment counter
                    counter += 1
                # Get the controller parameter
                Ky[o][o][:] = ky
                Kr[o][o][:] = [b*ky[0], ky[1], ky[2]]
        # Rescale controller for real system
        for c in range(0,2):
            Ky[:][:][c] = np.dot(D,Ky[:][:][c])
            Kr[:][:][c] = np.dot(D,Kr[:][:][c])
        return Ky,Kr

# %% [markdown]
# # Test Area
# ### Testing the Algorithm on robustness etc

# %%
# Import the needed packages
# python control for LTI systems
import control as cn
# Import bokeh for Ploting
import bokeh.plotting as bk
import bokeh.io as bi
bi.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="648dbad3-c477-4a70-becb-fe07aacc9258">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### SISO Test
# Testing Identification / AMIGO Tuning / AMIGO Detuning

# %%
# Test Identification
# Make a system
num = [1,0,20]
den = [50,10,1]
G = cn.tf(num,den)
G = G*G
# Step response
t = np.linspace(0,100,500)
y,t = cn.matlab.step(G,t)
# Add noise
y = y +np.random.normal(0,0.3,np.size(y))
u = np.ones_like(y)
# Parameter
K,T,L = Area_Fit(y,u,t)
num,den = cn.pade(L,15)
GM = cn.tf([K],[T,1])*cn.tf(num,den)
yM,tM = cn.matlab.step(GM, t)
# Plot
p1 = bk.figure()
p1.line(t,y, line_color= "tomato")
p1.line(tM,yM)
p1.circle(t[abs(y).argmax(axis=0)],y[abs(y).argmax(axis=0)], fill_color='orange', size=10)
bk.show(p1)

# Calculate the controller
params, b = AMIGO_Tune(K,T,L)
ky = cn.tf([params[0]],[1])+cn.tf([params[1]],[1,0])
kr = cn.tf([params[1]],[1,0])
cl =cn.feedback(G,ky)*kr
yc,tc = cn.step(cl)
# Plot
p2 = bk.figure()
p2.line(tc,yc, line_color= "tomato")
bk.show(p2)

# Find the Maximum Sensitivity
# Compute sensitivity
S = 1/(1+G*ky)
# compute the gain of the sensitivity
w = np.logspace(-5,5,1000)
mag, phase, freq = cn.matlab.bode(S,w)
MS = np.max(mag)

# Make a plot
p3= bk.figure(x_axis_type="log")
p3.line(freq,mag)
bk.show(p3)

#Detune the controller -> DOES NOT WORK!!! WHY!?
params = AMIGO_DETUNE(K,T,L,params, params[0])
ky2 = cn.tf([params[0]],[1])+cn.tf([params[1]],[1,0])
kr2 = cn.tf([params[1]],[1,0])
cl2 =cn.feedback(G,ky2)*kr2
yc2,tc2 = cn.step(cl2)
# Plot
p4 = bk.figure()
p4.line(tc,yc)
p4.line(tc2,yc2, line_color= "tomato")
bk.show(p4)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e32ea6c9-7a16-48dd-9c46-f50a1b76e491"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e32ea6c9-7a16-48dd-9c46-f50a1b76e491");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e32ea6c9-7a16-48dd-9c46-f50a1b76e491");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e32ea6c9-7a16-48dd-9c46-f50a1b76e491' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dd10c42a-fc34-4975-a365-156fe0e87d85":{"roots":{"references":[{"attributes":{},"id":"f5f8139c-0b30-4f87-9a59-d7ee5d3e4a50","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[500]},"y":{"__ndarray__":"...","dtype":"float64","shape":[500]}}},"id":"33af0fff-5582-4379-8b04-2a9d608c4968","type":"ColumnDataSource"},{"attributes":{},"id":"7566d970-0f07-4f76-afa0-7ba470ba1588","type":"LinearScale"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6fa3577f-0866-4efe-8b70-a9a9fcaabdea","type":"Line"},{"attributes":{},"id":"b5a94893-104a-4c4a-aef0-7b983b74392b","type":"LinearScale"},{"attributes":{"plot":{"id":"ce503cb3-5e66-4bb0-b8be-100add049252","subtype":"Figure","type":"Plot"}},"id":"cb046cb3-317e-4ff4-b4bf-f96bf7c74816","type":"PanTool"},{"attributes":{},"id":"1564858e-15e8-46b5-937e-f39051323ac8","type":"BasicTicker"},{"attributes":{"data_source":{"id":"33af0fff-5582-4379-8b04-2a9d608c4968","type":"ColumnDataSource"},"glyph":{"id":"1a273bc0-6c0b-4788-a155-5a5b4b24a0e8","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"46c1315b-3a31-4a84-bc22-433131ced428","type":"Line"},"selection_glyph":null},"id":"bc39d366-9009-48e4-931d-81e8137e535c","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"ce503cb3-5e66-4bb0-b8be-100add049252","subtype":"Figure","type":"Plot"}},"id":"f7ba74a4-f4a1-4e09-8862-93bc56dbc339","type":"ResetTool"},{"attributes":{"data_source":{"id":"b0fa2582-0a77-4e45-84a4-b24972d7b3c6","type":"ColumnDataSource"},"glyph":{"id":"a717ee64-5e2b-407d-96c4-a08d19a69a03","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"98aad406-cebf-4290-9185-cb126af252e8","type":"Circle"},"selection_glyph":null},"id":"68010789-b2c9-4414-a99f-92f51393f817","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"orange"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"value":45.69138276553107},"y":{"value":425.60433422120826}},"id":"a717ee64-5e2b-407d-96c4-a08d19a69a03","type":"Circle"},{"attributes":{"line_color":{"value":"tomato"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a273bc0-6c0b-4788-a155-5a5b4b24a0e8","type":"Line"},{"attributes":{"plot":{"id":"ce503cb3-5e66-4bb0-b8be-100add049252","subtype":"Figure","type":"Plot"}},"id":"e87d2e7f-a27a-4ff7-906c-b747ed059611","type":"SaveTool"},{"attributes":{"plot":{"id":"ce503cb3-5e66-4bb0-b8be-100add049252","subtype":"Figure","type":"Plot"}},"id":"bd635355-d920-40f9-bd2b-af6421b1188d","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"36338c55-9f77-4508-89db-f0b7df93f048","type":"BasicTickFormatter"},"plot":{"id":"ce503cb3-5e66-4bb0-b8be-100add049252","subtype":"Figure","type":"Plot"},"ticker":{"id":"f5f8139c-0b30-4f87-9a59-d7ee5d3e4a50","type":"BasicTicker"}},"id":"caae6980-94d5-432c-8978-6b6d5b1a7beb","type":"LinearAxis"},{"attributes":{"data_source":{"id":"797d1d3d-6af1-42b2-b9be-2b42b0190f3a","type":"ColumnDataSource"},"glyph":{"id":"ba2b0e72-2f10-4c6e-afeb-791b14f22363","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6fa3577f-0866-4efe-8b70-a9a9fcaabdea","type":"Line"},"selection_glyph":null},"id":"74f4b31a-a74e-4bc5-98e9-46ba9195a231","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"fb433ddd-1648-430a-a8e0-6fd780488e4c","type":"BoxAnnotation"},"plot":{"id":"ce503cb3-5e66-4bb0-b8be-100add049252","subtype":"Figure","type":"Plot"}},"id":"9522de17-5ead-49ca-919e-30ddf7eaa8e7","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"607d5ee5-97fe-455f-85aa-33bb0bfa3e56","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"cb046cb3-317e-4ff4-b4bf-f96bf7c74816","type":"PanTool"},{"id":"bd635355-d920-40f9-bd2b-af6421b1188d","type":"WheelZoomTool"},{"id":"9522de17-5ead-49ca-919e-30ddf7e ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ba831f7f-f128-44a8-bc0e-fe807656d9b5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ba831f7f-f128-44a8-bc0e-fe807656d9b5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ba831f7f-f128-44a8-bc0e-fe807656d9b5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ba831f7f-f128-44a8-bc0e-fe807656d9b5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f7576b33-19c2-48fd-b5f4-814b92a5ccad":{"roots":{"references":[{"attributes":{},"id":"82617549-46c9-4810-b171-705368c60f99","type":"LinearScale"},{"attributes":{},"id":"b1160cf4-e9c2-4f13-9ccf-53a553b3c75d","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"fa656773-64f6-4866-89d8-4cbb9af26566","subtype":"Figure","type":"Plot"},"ticker":{"id":"8d530ef4-a3c7-4b13-9a73-b02bc5c0aee6","type":"BasicTicker"}},"id":"c3051eef-b3d3-4a30-9704-a38620746ab7","type":"Grid"},{"attributes":{"plot":{"id":"fa656773-64f6-4866-89d8-4cbb9af26566","subtype":"Figure","type":"Plot"},"ticker":{"id":"a359d704-af53-465f-9b33-1edb93ea024d","type":"BasicTicker"}},"id":"64eae909-42ec-48c3-884a-383022c43216","type":"Grid"},{"attributes":{"plot":{"id":"fa656773-64f6-4866-89d8-4cbb9af26566","subtype":"Figure","type":"Plot"}},"id":"320150de-884a-44c8-89c9-5f051b52240b","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f9770d87-4129-42fc-81aa-73e435500ba8","type":"Line"},{"attributes":{"plot":{"id":"fa656773-64f6-4866-89d8-4cbb9af26566","subtype":"Figure","type":"Plot"}},"id":"14f5d202-4411-4c76-9317-f1ec03588dd0","type":"PanTool"},{"attributes":{"data_source":{"id":"aed2eeb8-75d4-448d-8302-933bc172e3b3","type":"ColumnDataSource"},"glyph":{"id":"0c359785-2727-451f-84fe-92d052096c43","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f9770d87-4129-42fc-81aa-73e435500ba8","type":"Line"},"selection_glyph":null},"id":"0f0b2817-b253-4c7b-b48b-27be2d52cf14","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"fa656773-64f6-4866-89d8-4cbb9af26566","subtype":"Figure","type":"Plot"}},"id":"d4994ca6-95f4-40b3-9be3-bfe2f054bfed","type":"HelpTool"},{"attributes":{"overlay":{"id":"06ef6456-2b8e-439c-a89e-1df30bd1358a","type":"BoxAnnotation"},"plot":{"id":"fa656773-64f6-4866-89d8-4cbb9af26566","subtype":"Figure","type":"Plot"}},"id":"76474466-75fb-4551-81d0-fd43c8f94ccb","type":"BoxZoomTool"},{"attributes":{},"id":"4d4a8729-9ba5-4bf9-b6e7-65c5ed9a0ea1","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"14f5d202-4411-4c76-9317-f1ec03588dd0","type":"PanTool"},{"id":"320150de-884a-44c8-89c9-5f051b52240b","type":"WheelZoomTool"},{"id":"76474466-75fb-4551-81d0-fd43c8f94ccb","type":"BoxZoomTool"},{"id":"701c1ec3-3af3-44b3-b596-4a8cd0ad8e5a","type":"SaveTool"},{"id":"c71aae59-6971-44a2-8a25-cebae31cd378","type":"ResetTool"},{"id":"d4994ca6-95f4-40b3-9be3-bfe2f054bfed","type":"HelpTool"}]},"id":"da8cea10-9ec8-4661-849d-d897232867dc","type":"Toolbar"},{"attributes":{"callback":null},"id":"a7e50767-a604-42a5-aa4e-3453e0c44921","type":"DataRange1d"},{"attributes":{},"id":"a359d704-af53-465f-9b33-1edb93ea024d","type":"BasicTicker"},{"attributes":{},"id":"8d530ef4-a3c7-4b13-9a73-b02bc5c0aee6","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"bdf3aa3f-5ce6-4aac-9409-02439dba8814","type":"Title"},{"attributes":{"formatter":{"id":"e39d7fe9-7a79-4dd3-a026-b79e54833051","type":"BasicTickFormatter"},"plot":{"id":"fa656773-64f6-4866-89d8-4cbb9af26566","subtype":"Figure","type":"Plot"},"ticker":{"id":"a359d704-af53-465f-9b33-1edb93ea024d","type":"BasicTicker"}},"id":"1e1499f7-594d-4048-8cf4-fb551a49a66c","type":"LinearAxis"},{"attributes":{"below":[{"id":"1e1499f7-594d-4048-8cf4-fb551a49a66c","type":"LinearAxis"}],"left":[{"id":"d76cbcbf-a538-4c00-9278-eaa353c01a08","type":"LinearAxis"}],"renderers":[{"id":"1e1499f7-594d-4048-8cf4-fb551a49a66c","type":"LinearAxis"},{"id":"64eae909-42ec-48c3-884a-383022c43216","type":"Grid"},{"id":"d76cbcbf-a538-4c00-9278-eaa353c01a08","type":"LinearAxis"},{"id":"c3051eef-b3d3-4a30-9704-a38620746ab7","type":"Grid"},{"id":"06ef6456-2b8e-439c-a89e-1df30bd1358a","type":"BoxAnnotation"},{"id":"0f0b2817-b253-4c7b-b48b-27be2d52cf14","type":"GlyphRenderer"}],"title":{"id":"bdf3aa3f-5ce6-4aac-9409 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d1663928-d6a5-44f4-ac1a-2975e8fcfdd9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d1663928-d6a5-44f4-ac1a-2975e8fcfdd9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d1663928-d6a5-44f4-ac1a-2975e8fcfdd9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd1663928-d6a5-44f4-ac1a-2975e8fcfdd9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"85120de3-2e22-413f-b9bb-066ff1ec5b73":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6f7108a6-edfc-4208-8e0c-c68512aaeea4","type":"Line"},{"attributes":{"num_minor_ticks":10},"id":"d1a84c80-f226-44d0-91ff-ae58183d4647","type":"LogTicker"},{"attributes":{},"id":"b795958b-763c-44be-87fa-b315367becb0","type":"BasicTicker"},{"attributes":{"formatter":{"id":"de276627-4792-4488-99a9-1adfae228c37","type":"BasicTickFormatter"},"plot":{"id":"41724204-2248-40b7-9a44-944d57827fcb","subtype":"Figure","type":"Plot"},"ticker":{"id":"b795958b-763c-44be-87fa-b315367becb0","type":"BasicTicker"}},"id":"846f32a4-d1c4-4b23-af74-c67760c15dee","type":"LinearAxis"},{"attributes":{},"id":"17cd0490-c079-41c9-a3cc-1774afe3b1d6","type":"LinearScale"},{"attributes":{"data_source":{"id":"a1b8a752-b499-490c-befb-ed5f58bd9e59","type":"ColumnDataSource"},"glyph":{"id":"6f7108a6-edfc-4208-8e0c-c68512aaeea4","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d4111258-186d-45b9-9dc2-dd27c49af48e","type":"Line"},"selection_glyph":null},"id":"08997f17-dcc2-4f2d-9d30-714e606af0d6","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2c26aaf8-f5d1-4cfd-8c5b-2555287cb589","type":"PanTool"},{"id":"d2ae4eba-3983-4e2f-b683-d1782f4a3f88","type":"WheelZoomTool"},{"id":"645ff968-22e5-409d-914a-5d954dd520de","type":"BoxZoomTool"},{"id":"a3d052c9-89ab-4423-8dd7-a18f3513e4da","type":"SaveTool"},{"id":"44de0bdd-cb24-4ea7-9a1a-b4b3cf9a3362","type":"ResetTool"},{"id":"630c1bd8-5592-42e2-be05-da973df5086d","type":"HelpTool"}]},"id":"cfc4e2c1-bd5b-4d31-a8ad-794fb385bdea","type":"Toolbar"},{"attributes":{"plot":{"id":"41724204-2248-40b7-9a44-944d57827fcb","subtype":"Figure","type":"Plot"}},"id":"44de0bdd-cb24-4ea7-9a1a-b4b3cf9a3362","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"41724204-2248-40b7-9a44-944d57827fcb","subtype":"Figure","type":"Plot"},"ticker":{"id":"b795958b-763c-44be-87fa-b315367becb0","type":"BasicTicker"}},"id":"56c81cdc-4f75-4932-beb9-521472eb84f9","type":"Grid"},{"attributes":{"callback":null},"id":"04b86dfa-ab50-4103-9f81-1abbecb5d2ca","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"a1b8a752-b499-490c-befb-ed5f58bd9e59","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d4111258-186d-45b9-9dc2-dd27c49af48e","type":"Line"},{"attributes":{"formatter":{"id":"e87d183b-e25f-488d-a851-e642c0bbf5c8","type":"LogTickFormatter"},"plot":{"id":"41724204-2248-40b7-9a44-944d57827fcb","subtype":"Figure","type":"Plot"},"ticker":{"id":"d1a84c80-f226-44d0-91ff-ae58183d4647","type":"LogTicker"}},"id":"1ef317e0-0abd-4f51-bc22-67ef54b0c7a1","type":"LogAxis"},{"attributes":{"plot":{"id":"41724204-2248-40b7-9a44-944d57827fcb","subtype":"Figure","type":"Plot"}},"id":"2c26aaf8-f5d1-4cfd-8c5b-2555287cb589","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b9ebd3ea-dc61-4e19-b599-a1094d544f36","type":"BoxAnnotation"},{"attributes":{"ticker":null},"id":"e87d183b-e25f-488d-a851-e642c0bbf5c8","type":"LogTickFormatter"},{"attributes":{},"id":"2efcbb8b-ab8c-485e-962b-f645be348aee","type":"ToolEvents"},{"attributes":{"plot":{"id":"41724204-2248-40b7-9a44-944d57827fcb","subtype":"Figure","type":"Plot"}},"id":"630c1bd8-5592-42e2-be05-da973df5086d","type":"HelpTool"},{"attributes":{},"id":"de276627-4792-4488-99a9-1adfae228c3 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f332088a-3823-4ecb-8603-e814a6fbffbb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f332088a-3823-4ecb-8603-e814a6fbffbb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f332088a-3823-4ecb-8603-e814a6fbffbb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f332088a-3823-4ecb-8603-e814a6fbffbb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"72fffc8a-a630-491b-ae41-3f233d29853c":{"roots":{"references":[{"attributes":{"formatter":{"id":"6afcac03-7df9-4559-8025-fe0a7e5cf89e","type":"BasicTickFormatter"},"plot":{"id":"0704c726-7fba-4722-aea1-ec1be6fcffa3","subtype":"Figure","type":"Plot"},"ticker":{"id":"75280ec9-f8f9-40bc-83ea-3deb6aeee1a6","type":"BasicTicker"}},"id":"6f0e3593-3667-4791-a577-3753115340c8","type":"LinearAxis"},{"attributes":{"below":[{"id":"c631f41d-02e9-44bf-a449-d003136da88f","type":"LinearAxis"}],"left":[{"id":"6f0e3593-3667-4791-a577-3753115340c8","type":"LinearAxis"}],"renderers":[{"id":"c631f41d-02e9-44bf-a449-d003136da88f","type":"LinearAxis"},{"id":"aca1cc68-2f1f-4218-bfcd-bb87e50d23d5","type":"Grid"},{"id":"6f0e3593-3667-4791-a577-3753115340c8","type":"LinearAxis"},{"id":"1f24ddd7-bd8b-4870-82c4-e71e9a445547","type":"Grid"},{"id":"a51faa08-8560-474d-a2b7-edb15df045ac","type":"BoxAnnotation"},{"id":"d5db932c-01b7-411a-80d0-59351ae0cf5e","type":"GlyphRenderer"},{"id":"a94262d2-bbe5-411a-9c46-3622a929cc47","type":"GlyphRenderer"}],"title":{"id":"28ea4406-8414-4e7c-87c4-8f1700e24931","type":"Title"},"tool_events":{"id":"46f9c359-00e3-4b0f-afb6-0a33389c8243","type":"ToolEvents"},"toolbar":{"id":"854d8988-ce10-4460-a67c-0c03dc75a726","type":"Toolbar"},"x_range":{"id":"ed75d6d9-6605-4802-9e34-03400c7d232f","type":"DataRange1d"},"x_scale":{"id":"fbac9ce3-57cc-42af-ba64-574393c97b6a","type":"LinearScale"},"y_range":{"id":"103b3c90-8a6c-41aa-8151-f081355bc222","type":"DataRange1d"},"y_scale":{"id":"f208fd93-a647-4c2d-a90f-b89ba8a41120","type":"LinearScale"}},"id":"0704c726-7fba-4722-aea1-ec1be6fcffa3","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"ed75d6d9-6605-4802-9e34-03400c7d232f","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"924ba8a5-0ede-4669-9660-51611bea44b4","type":"Line"},{"attributes":{"plot":{"id":"0704c726-7fba-4722-aea1-ec1be6fcffa3","subtype":"Figure","type":"Plot"}},"id":"18120e89-bc7c-40b0-9427-6026b2128b38","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"60af037c-cd9e-436d-9eaf-e8d3d0d6f5c7","type":"Line"},{"attributes":{},"id":"ae68af29-14e8-404c-8ffa-cde4d4814a4b","type":"BasicTicker"},{"attributes":{"formatter":{"id":"e758d2ab-7896-43e2-8fc7-7eb8686567a4","type":"BasicTickFormatter"},"plot":{"id":"0704c726-7fba-4722-aea1-ec1be6fcffa3","subtype":"Figure","type":"Plot"},"ticker":{"id":"ae68af29-14e8-404c-8ffa-cde4d4814a4b","type":"BasicTicker"}},"id":"c631f41d-02e9-44bf-a449-d003136da88f","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"0704c726-7fba-4722-aea1-ec1be6fcffa3","subtype":"Figure","type":"Plot"},"ticker":{"id":"75280ec9-f8f9-40bc-83ea-3deb6aeee1a6","type":"BasicTicker"}},"id":"1f24ddd7-bd8b-4870-82c4-e71e9a445547","type":"Grid"},{"attributes":{"plot":{"id":"0704c726-7fba-4722-aea1-ec1be6fcffa3","subtype":"Figure","type":"Plot"}},"id":"38081e0a-63f9-400e-9717-999d795ccc2e","type":"ResetTool"},{"attributes":{"plot":{"id":"0704c726-7fba-4722-aea1-ec1be6fcffa3","subtype":"Figure","type":"Plot"}},"id":"6b32093f-3718-4fd3-90eb-998e743f10d0","type":"PanTool"},{"attributes":{"data_source":{"id":"a97d7e04-e2f6-4605-9e71-7c98f9e13aca","type":"ColumnDataSource"},"glyph":{"id":"dd4c993b-b881-422e-bc9b-360707b16331","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"60af037c-cd9e-436d-9eaf-e8d3d0d6f5c7","type":"Line"},"selection_glyph":null},"id":"d5db932c-01b7-411a-80d0-59351ae0cf5e","type":"GlyphRenderer"},{"attributes":{},"id":"6afcac03-7df9-4559-8025-fe0a7e5cf89e","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd4c993b-b881-422e-bc9b-360707b16331","type":"Line"},{"attributes":{},"id":"f208fd93-a647-4c2d-a90f-b89ba8a41120","type":"LinearScale"},{"attributes":{"overlay":{"id": ...

# %% [markdown]
# ### TEST MIMO System

# %%
# Make a system
num = [[[3],[10]], [[5],[1]]]
den = [[[10,1],[50,1]],[[20,1],[30,1]]]
#G = cn.tf(num,den)

# Time array
t = np.linspace(0,300,600)
# Store the output
y = np.empty([2,2,t.size])
# Input Array
u = np.ones_like(t)

# Define Parameter
K = np.empty([2,2])
T = np.empty([2,2])
L = np.empty([2,2])
G = [[0 for x in range(2)] for y in range(2)] 

# Identify from step response
for ins in range(0,2):
    for out in range(0,2):
        G[out][ins] = cn.tf(num[out][ins],den[out][ins])
        y[out][ins][:],t = cn.step(G[out][ins],t)
        K[out][ins],T[out][ins],L[out][ins] = Area_Fit(y[out][ins][:],u,t)
    
# Compute the decentralized controller
Ky1,Kr1 = Control_Decentral(K,T,L)
Ky2,Kr2 = Control_Astrom(K,T,L, 0.2*np.eye(2))

#g = G[0][0]
#ky = Ky1[0][0]
#kr = Kr1[0][0]
#ky = cn.tf([ky[0]],[1])+cn.tf([ky[1]],[1,0])
#kr = cn.tf([kr[1]],[1,0])
#cl =cn.feedback(g,ky)*kr
#yc,tc = cn.step(cl)
# Plot
#p4 = bk.figure()
#p4.line(tc,yc)
#bk.show(p4)
#g
# Out:
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:18: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
# Test Identification
# Make a system
num = [5,10]
den = [10,20,1]
G = cn.tf(num,den)
# Step response
t = np.linspace(0,100,500)
y,t = cn.matlab.step(G,t)

# Plot
p1 = bk.figure()
p1.line(t,y, line_color= "tomato")
bk.show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="12446ddb-d492-4527-b421-5c9a8bf29aa1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("12446ddb-d492-4527-b421-5c9a8bf29aa1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("12446ddb-d492-4527-b421-5c9a8bf29aa1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '12446ddb-d492-4527-b421-5c9a8bf29aa1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"deddfe47-7324-40d6-bb1d-ce9d13507997":{"roots":{"references":[{"attributes":{},"id":"f2e75a12-ec95-495c-8373-542b0311c17c","type":"BasicTicker"},{"attributes":{"formatter":{"id":"0005bff3-f95c-42a2-9fc1-743198f87ed0","type":"BasicTickFormatter"},"plot":{"id":"a576e0e6-6c9d-46ae-987a-7e977771b538","subtype":"Figure","type":"Plot"},"ticker":{"id":"a04e057e-96bf-448e-92f5-372bf4960bf9","type":"BasicTicker"}},"id":"4f04781a-2fe7-4572-9bd7-84d3882571fb","type":"LinearAxis"},{"attributes":{"callback":null},"id":"65d916d1-90d6-4107-988b-30199e929168","type":"DataRange1d"},{"attributes":{"callback":null},"id":"42c369c4-9558-4b04-8025-dd593575b10a","type":"DataRange1d"},{"attributes":{"plot":{"id":"a576e0e6-6c9d-46ae-987a-7e977771b538","subtype":"Figure","type":"Plot"}},"id":"25ca3c70-58a0-4ae3-b168-956531f638df","type":"PanTool"},{"attributes":{"formatter":{"id":"c9785525-8943-45e8-a4f8-9bcb969810ac","type":"BasicTickFormatter"},"plot":{"id":"a576e0e6-6c9d-46ae-987a-7e977771b538","subtype":"Figure","type":"Plot"},"ticker":{"id":"f2e75a12-ec95-495c-8373-542b0311c17c","type":"BasicTicker"}},"id":"eccdc581-7356-4280-8bef-81ae899c94b8","type":"LinearAxis"},{"attributes":{"plot":{"id":"a576e0e6-6c9d-46ae-987a-7e977771b538","subtype":"Figure","type":"Plot"}},"id":"5f5f4348-9e31-4c87-9d96-c174695cc935","type":"ResetTool"},{"attributes":{"overlay":{"id":"a87a2863-20d5-4f25-ab82-0a24f30ddc58","type":"BoxAnnotation"},"plot":{"id":"a576e0e6-6c9d-46ae-987a-7e977771b538","subtype":"Figure","type":"Plot"}},"id":"2e1c58ec-c05f-441b-bd5d-01f8a091257f","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a87a2863-20d5-4f25-ab82-0a24f30ddc58","type":"BoxAnnotation"},{"attributes":{},"id":"c9785525-8943-45e8-a4f8-9bcb969810ac","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"25ca3c70-58a0-4ae3-b168-956531f638df","type":"PanTool"},{"id":"1c6e0ec2-5b03-474b-98f2-c2d5b535d762","type":"WheelZoomTool"},{"id":"2e1c58ec-c05f-441b-bd5d-01f8a091257f","type":"BoxZoomTool"},{"id":"fb7c733c-a311-40c9-98ca-eb73bc34809c","type":"SaveTool"},{"id":"5f5f4348-9e31-4c87-9d96-c174695cc935","type":"ResetTool"},{"id":"059a8718-d042-4749-b491-f8712cee7270","type":"HelpTool"}]},"id":"b8b769f3-e9e7-4632-a1c5-7c734d38bf91","type":"Toolbar"},{"attributes":{},"id":"98f52a94-d443-462b-bfcb-c5d9cc006b06","type":"LinearScale"},{"attributes":{"plot":{"id":"a576e0e6-6c9d-46ae-987a-7e977771b538","subtype":"Figure","type":"Plot"}},"id":"fb7c733c-a311-40c9-98ca-eb73bc34809c","type":"SaveTool"},{"attributes":{},"id":"0005bff3-f95c-42a2-9fc1-743198f87ed0","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"a576e0e6-6c9d-46ae-987a-7e977771b538","subtype":"Figure","type":"Plot"}},"id":"059a8718-d042-4749-b491-f8712cee7270","type":"HelpTool"},{"attributes":{"plot":{"id":"a576e0e6-6c9d-46ae-987a-7e977771b538","subtype":"Figure","type":"Plot"}},"id":"1c6e0ec2-5b03-474b-98f2-c2d5b535d762","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"ebe35fc9-613a-4a1f-8146-4b9a0ef34f7f","type":"ColumnDataSource"},"glyph":{"id":"a8e63680-4107-4cc5-a794-c31304d6b7ab","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"760582cc-d27e-40ae-a7a1-e9d48c66153b","type":"Line"},"selection_glyph":null},"id":"28286e3d-45fd-45b9-8c8e-600e8c818254","type":"GlyphRenderer"},{"attributes":{},"id":"45771f82-6e81-4199-add6-5ab88006270f","type":"LinearScale"},{"attributes":{"plot":null,"text":""},"id":"38525e72-5f64-4ba5-ac5c-bf7914709f07","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"a576e0e6-6c9d-46ae-987a-7e977771b538","subtype":"Figure","type":"Plot"}, ...

# %%
# Modified Detuning
def Control_Decoupled(K,T,L,H, MS= None, w = 0, b=np.empty, structure = 'PI'):
    # Check Input for Maximum Sensitivity
    if MS is None:
        MS = 1.4*np.eye(K.shape[0],K.shape[1])
    
    # Compute Determinant of Maximum Sensitivity
    ms = np.linalg.det(MS)

    # Compute SISO Case
    if K.ndim <= 1:
        return Control_Decentral(K,T,L,w,b,structure)
    
    # Compute General MIMO Case
    else:

        # Compute a decentralized control structure based on RGA
        Ky, Kr = Control_Decentral(K,T,L, w , b, structure)
        
        # Get minimal Delay/ Time Constant for robust limit of crossover frequency, ignore zeros
        # Important note: wc_min is actually 1/w_c !!!
        if (L[np.where(L>0)].size !=0) or (T[np.where(T>0)].size !=0):
            if (L[np.where(L>0)].size !=0):
                wc_min = np.min([np.min(L[np.nonzero(L)]),np.min(T[np.nonzero(T)])])
            else:
                wc_min = np.min(np.min(T[np.nonzero(T)]))
        else:
            # Use very high frequency
            wc_min = 1e10
        
        # Calculate the Pairing
        # Compute RGA -> Checks for Shape
        LG = RGA(K,T,L,w)
        # Get Pairing as an array for every column
        Pairing = np.argmax(LG, axis=0)
        
        # Compute the Taylor Series 
        Gamma =  np.multiply(-K,T+L)

        # Initialize 
        KD = np.zeros_like(Gamma)
        GD = np.zeros_like(Gamma)
        
        # Get the Diagonal entries for decoupling
        for outputs in range(0,K.shape[0]):
            inputs = Pairing[outputs]
            KD[outputs][inputs] = K[outputs][inputs]
            GD[outputs][inputs] = Gamma[outputs][inputs]
    
        # Get the Antidiagonal
        KA = K-KD
        GA = Gamma-GD
        
        # Define the splitter
        S = -np.dot(np.linalg.inv(KD),KA)

        # Get the interaction
        GammaA = np.abs(GA + np.dot(GD,S))
        print(GammaA)
        # Get the maximum of each row 
        GMax = np.argmax(GammaA,axis=0)
        print(GMax)
        #Iterate through the outputs
        for outputs in range(0,K.shape[0]):
            inputs = Pairing[outputs]
            
            # Test the current controller for interaction
            # Every controller has the dimension 3 for kp, ki, kd
            ky = Ky[outputs][inputs]
            kr = Kr[outputs][inputs]
            
            # Get the current parameter
            k = K[outputs][inputs]
            t = T[outputs][inputs]
            l = L[outputs][inputs]
            
            # Check for set point weight, either given
            if b == np.empty:
                # Or computed from AMIGO_TUNE
                b = kr[0]/ky[0]
            print(b)
            gmax = GammaA[outputs][GMax[outputs]]
            print(gmax)
            # Check for PI Structure
            if structure == 'PI':
                # Define the counter
                counter = 0
                # Set shrinking rate 
                shrink_rate = 0.9
                
                print(np.abs(H[outputs][outputs]/(ms*gmax)) - np.sqrt( (b*ky[0]/wc_min)**2 + ky[1]**2 ))
                while (np.abs(H[outputs][outputs]/(ms*gmax)) - np.sqrt( (b*ky[0]/wc_min)**2 + ky[1]**2 ) < 0):
                    if counter > 1e5:
                        #print('Maximal Iteration for detuning reached! Abort')
                        break
                    # Detune the controller with the shrinking rate    
                    ky = AMIGO_DETUNE(k,t,l,ky,shrink_rate*ky[0])
                    # Increment counter
                    counter += 1
                print(counter)
                # Get the controller parameter
                Ky[outputs][inputs][:] = ky
                Kr[outputs][inputs][:] = [b*ky[0], ky[1], ky[2]]

        return Ky,Kr

# %%
import Algorithms as alg
import numpy as np
K = np.array([[10,1],[2,11]])
T = np.array([[31,10],[10,51]])
L = np.array([[0,0],[0,0]])
H = np.diag([0.01,0.01])
#Ky,Kr = Control_Decoupled(K,T,L,H)
Ky2,Kr2 = alg.Control_Decoupled(K,T,L,H)

# %%
alg.RGA(K,T,L,100)
# Out:
# array([[-0.28211547,  1.28211547],
#        [ 1.28211547, -0.28211547]])

# %%
a= np.random.uniform(0,1,(1,1,9))
a
# Out:
# array([[[ 0.45686713,  0.22132972,  0.89035245,  0.655564  ,  0.67510215,
#           0.06877948,  0.86643841,  0.41978976,  0.11611283]]])

# %%
a[0][0][:4]
# Out:
# array([ 0.45686713,  0.22132972,  0.89035245,  0.655564  ])
