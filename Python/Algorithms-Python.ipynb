# %%
import numpy as np

# %%
## Define the Area Fit Method
def Area_Fit(y,u,t):
    """Returns a FOTD Model from the given data.
    y - array of outputs
    u - array of inputs
    t - array of time values
    """
    # Truncate for Maximum
    i_end = y.argmax(axis=0)
    yp = y[0:i_end+1]
    up = u[0:i_end+1]
    tp = t[0:i_end+1]
    # Get Gain
    KM = (yp[-1]-yp[0])/(up[-1])
    # Get the Residence Time
    Tar = 1/KM * np.trapz(yp[-1]-yp,tp)
    # Time Constant
    T = np.exp(1)/KM*np.trapz(yp[np.where(tp<=Tar)],tp[np.where(tp<=Tar)])
    # Delay
    L = Tar-T
    # Check if all arguments are valid
    if (T < 0):
        print("Error - Negative lag")
        return -1
    if (L < 0):
        if (L < 1e-2):
            L = 0
        else:    
            print("Error - Negative delay")
            return -1
    return KM,T,L

# %%
# Define the AMIGO Tuning
def AMIGO_Tune(K,T,L, structure = 'PI'):
    """Computes the PI(D) controller parameter based on AMIGO algorithm;
       Parameter are returned as parallel notation KP,KI,KD and set point;
       Needs first order time delay parameter as input
    """
    # Check for small delay
    if L < 1e-1:
        L = 1e-1
    # PI Controller
    if structure == 'PI':
        # Parameter as Defined in Aström et. al., Advanced PID Control,p.229 
        KP = 0.15/K + (0.35 - L*T /(L+T)**2)*T/(K*L)
        TI = 0.35*L+(13*L*T**2)/(T**2+12*L*T+7*L**2)
        TD = 0.0
        # Set Point Weight, as given on p.235
        if L/(T+L) > 0.5:
            b = 1
        else:
            b = 0.0
        
    elif structure == 'PID':
        KP = 1/K*(0.2+0.45*T/L)
        TI = (0.4*L + 0.8*T)/(L+0.1*T)*L
        TD = (0.5*L*T)/(0.3*L+T)
        # Set Point Weight, Derived from Fig. 7.2, p. 230
        if L/(T+L) < 0.2:
            b = 0.4
        elif L/(T+L) > 0.3:
            b = 1.0
        else:
            # Approximate as Linear Function
            b = 0.4 + (1.0 - 0.4)/(0.3-0.2)*L/(T+L)
    else:
        print("Undefined controller Structure")
        return np.NaN
    KI = KP/TI
    KD = KP*TD
    return [KP,KI,KD],b

# Define AMIGO Detuning
def AMIGO_DETUNE(K,T,L,params,KP, MS = 1.4, structure = 'PI'):
    """Detunes the AMIGO parameter according to Astrom"""
    # Check for small delay
    if L < 1e-1:
        L = 1e-1
    # Needed Parameter
    alpha_D = (MS-1)/MS # See p.255 Eq. 7.19
    beta_D = MS*(MS+np.sqrt(MS**2-1))/2# See p.257 Eq. 7.24
    
    # Define old set of parameter
    KP0 = params[0]
    KI0 = params[1]
    KD0 = params[2]
    
    if structure=='PI':
        # Needed constrain for switch case,See p. 258 Eq. 7.27
        c = KP*K - KP0*K*(L+T)/(beta_D*(alpha_D+KP*K)) - alpha_D
        if c < 0:
            KI = beta_D*(alpha_D+KP*K)**2/(K*(L+T))
        else:
            KI = KI0*(alpha_D+KP*K)/(alpha_D+KP0*K)
        return [KP,KP/KI,0.0]
    if structure == 'PID':
        print("Not implemented")
        return np.NaN
    else:
        print("Undefined controller Structure")
        return np.NaN

# %%
def RGA(K,T,L,w=0):
    """Takes a FOTD System and computes the RGA of the system"""
    if (K.shape != T.shape) or (K.shape != L.shape) or (L.shape != T.shape):
        print("Shapes of parameter array are not equal!")
    # Compute the System
    G = np.absolute(FOTD_IMAG(K,T,L,w))
    # Calculate the RGA
    RGA = np.multiply(G, np.transpose(np.linalg.inv(G)))
    return RGA

# %%
def FOTD_IMAG(K,T,L,w=0):
    """Creates a FOTD MIMO system from the parameter matrices and the current frequency"""
    # Check if all dimensions match
    if (K.shape != T.shape) or (K.shape != L.shape) or (L.shape != T.shape):
        print("Shapes of parameter array are not equal!")
        return np.NaN
    # System Dimension
    if K.ndim == 1:
        # Using system Identity by multiplying with the complex conjugate
        G = 1/(T**2 * w**2 +1)*(K-1j*T*w)*(np.cos(-L*w)+1j*np.sin(-L*w))
    else:
        outputs,inputs = K.shape
        # Create a system within the complex numbers
        G = np.zeros_like(K)
        for i in range(0,inputs):
            for o in range(0,outputs):
                # Using system Identity by multiplying with the complex conjugate
                G[o][i] = 1 /(T[o][i]**2 * w**2 +1) * ( K[o][i] - 1j*T[o][i]*w) *(np.cos(-L[o][i]*w)+1j*np.sin(-L[o][i]*w))
    return G

# %%
def Control_Decentral(K,T,L, w = 0, b=np.empty, structure = 'PI'):
    """ Computes decentralised controller with AMIGO algorithm based on RGA pairing"""
    # Compute SISO Case
    if K.ndim <= 1:
        # Using system Identity by multiplying with the complex conjugate
        params, b0 = AMIGO_Tune(K,T,L)
        # If b is not given, use b from AMIGO
        if b == np.empty:
            Kr = [b0*params[0], params[1], params[2]]
            Ky = params
        else:
            Kr = [b*params[0],params[1],params[2]]
            Ky = params
    # Compute general MIMO Case
    else:
        # Systems dimensions
        outputs,inputs = K.shape
        # Create an empty controller
        Ky = np.empty([outputs,inputs,3])
        Kr = np.empty([outputs,inputs,3])
        # Compute RGA -> Checks for Shape
        LG = RGA(K,T,L,w)
        # Get Pairing as an array for every column
        Pairing = np.argmax(LG, axis=0)
        # Iterate through the pairing
        for o in range(0,outputs):
            # Best Pairing
            i = Pairing[o]
            # Compute controller via recursion
            Ky[o][i],Kr[o][i] = Control_Decentral(K[o][i],T[o][i],L[o][i],b)
    return Ky, Kr

def Control_Astrom(K,T,L,H, MS= 1.4*np.ones_like(K), w = 0, b=np.empty, structure = 'PI'):
    """Computes a Decoupling Controller via Aström Algortihm based on FOTD"""
    # Compute SISO Case
    if K.ndim <= 1:
        return Control_Decentral(K,T,L,w,b,structure)
    # Compute General MIMO Case
    else:
        
        # Systems dimensions
        outputs,inputs = K.shape
        # Check dimensions
        if (K.shape != T.shape) or (K.shape != H.shape) or (K.shape != MS.shape) or (K.shape != L.shape) or (L.shape != T.shape):
            print("Shapes of parameter array are not equal!")
            return np.NaN
        
        # Create an empty controller
        Ky = np.empty([outputs,inputs,3])
        Kr = np.empty([outputs,inputs,3])
        
        # Compute Determinant of Maximum Sensitivity
        ms = np.linalg.det(MS)
        
        # Get minimal Delay/ Time Constant for robust limit of crossover frequency, ignore zeros
        if (L[np.where(L>0)].size !=0) or (T[np.where(T>0)].size !=0):
            if (L[np.where(L>0)].size !=0):
                wc_min = np.min([np.min(L[np.nonzero(L)]),np.min(T[np.nonzero(T)])])
            else:
                wc_min = np.min(np.min(T[np.nonzero(T)]))
        else:
            # Use very high frequency
            wc_min = 1e10
        
        # Compute the decoupler
        D = np.linalg.inv(K)
        # Compute the interaction indeces
        # Since d/ds(Q*K) = d/ds(Q)*K = d/ds(G) we can write the Taylor coefficient
        Gamma = np.abs(np.dot(np.multiply(-K,T+L),D))
        # Set main diagonal to zero
        np.fill_diagonal(Gamma,0)
        # Get the maximum of each row
        GMax = np.argmax(Gamma,axis=0)
        # Iterate through the outputs 
        for o in range(0,outputs):
            # Estimate the new system parameter
            # Get the maximal gain
            l = np.max(L[o][:])
            # Add the systems gain -> scaled
            k = np.dot(K[o][:],D[:][o])
            # Get the system time constant
            t = np.sum(np.multiply(np.multiply(K[o][:],D[:][o]),T[o][:]+L[o][:]))/k - l
            
            # Design a controller based on estimated system
            ky,kr = Control_Decentral(k,t,l,w,b,structure)
            
            # Test for Interaction
            
            # Current maximum interaction
            gmax = Gamma[o][GMax[o]]
            # Check for set point weight, either given
            if b == np.empty:
                # Or computed from AMIGO_TUNE
                b = kr[0]/ky[0]
            # Check for structure
            if structure == 'PI':
                # Set counter for while
                counter=0
                # Set shrinking rate in accordance with golden ratio
                shrink_rate = 0.618
                while (np.abs(H[o][o]/(ms*gmax)) - np.sqrt( (b*ky[0]/wc_min)**2 + ky[1]**2 ) < 0):
                    if counter > 10:
                        #print('Maximal Iteration for detuning reached! Abort')
                        break
                    # Detune the controller with the shrinking rate    
                    ky = AMIGO_DETUNE(k,t,l,ky,shrink_rate*ky[0])
                    # Increment counter
                    counter += 1
                # Get the controller parameter
                Ky[o][o][:] = ky
                Kr[o][o][:] = [b*ky[0], ky[1], ky[2]]
        # Rescale controller for real system
        for c in range(0,2):
            Ky[:][:][c] = np.dot(D,Ky[:][:][c])
            Kr[:][:][c] = np.dot(D,Kr[:][:][c])
        return Ky,Kr

# %%
K = np.array([[10.0,20],[40,13]], dtype = 'double')
T = np.array([[100,300],[1000,50]], dtype = 'double')
L = 10*np.ones_like(K)

A,B = Control_Astrom(K,T,L,np.ones_like(K),1.4*np.eye(2))
C,D = Control_Decentral(K,T,L)
# Out:
# C:\Users\juliu\Anaconda3\lib\site-packages\ipykernel\__main__.py:18: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
### Test
# python control
import control as cn
# Import bokeh
import bokeh.plotting as bk
import bokeh.io as bi
bi.output_notebook()

# Transfer Function Parameter
K = np.array([[10,0],[0,10]], dtype = 'double')
T = np.array([[100,0],[0,50]], dtype = 'double')
L = np.array([[5,0],[0,10]], dtype = 'double')

# Design a controller
Ky1,Kr1 = Control_Decentral(K,T,L)
Ky2,Kr2 = Control_Astrom(K,T,L,0.1*np.eye(2))

# Difference
(Ky1-Ky2)+(Kr1-Kr2)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2f3afb43-4fe5-4b02-a928-7b6a657072b1">Loading BokehJS ...</span>
#     </div>
# C:\Users\juliu\Anaconda3\lib\site-packages\ipykernel\__main__.py:18: ComplexWarning: Casting complex values to real discards the imaginary part
# C:\Users\juliu\Anaconda3\lib\site-packages\ipykernel\__main__.py:101: RuntimeWarning: divide by zero encountered in double_scalars
# array([[[ -1.11022302e-16,   0.00000000e+00,   0.00000000e+00],
#         [  2.42513741e+06,  -9.78921569e+07,   1.75621188e+09]],
#
#        [[  9.99746451e-01,   2.65825381e+02,   3.37946023e+04],
#         [  1.38777878e-17,   8.67361738e-19,   0.00000000e+00]]])

# %%
# Transfer Function Parameter
K = np.array([[10,0],[0,10]], dtype = 'double')
T = np.array([[100,0],[0,50]], dtype = 'double')
L = np.array([[5,0],[0,10]], dtype = 'double')

# Design a controller
Ky1,Kr1 = Control_Decentral(K,T,L)
Ky2,Kr2 = Control_Astrom(K,T,L,0.1*np.eye(2))

# Difference
((Ky1-Ky2)+(Kr1-Kr2))
# Out:
# (array([[[ 0.62429705,  0.01488709,  0.        ],
#          [ 0.        ,  0.        ,  0.        ]],
#
#         [[ 0.        ,  0.        ,  0.        ],
#          [ 0.12055556,  0.00310501,  0.        ]]]),
#  array([[[  6.24297052e-01,   1.48870880e-02,   0.00000000e+00],
#          [  0.00000000e+00,   4.16666667e-06,   0.00000000e+00]],
#
#         [[  0.00000000e+00,   6.25000000e-07,   0.00000000e+00],
#          [  1.20555556e-01,   3.10501431e-03,   0.00000000e+00]]]))

# %%
# Test Identification
# Make a system
num = [10,50,10]
den = [50,10,1]
G = cn.tf(num,den)
# Step response
t = np.linspace(0,100,500)
y,t = cn.matlab.step(G,t)
# Add noise
y = y +np.random.normal(0,3,np.size(y))
u = np.ones_like(y)
# Parameter
K,T,L = Area_Fit(y,u,t)
num,den = cn.pade(L,15)
GM = cn.tf([K],[T,1])*cn.tf(num,den)
yM,tM = cn.matlab.step(GM, t)
# Plot
p1 = bk.figure()
p1.line(t,y, line_color= "tomato")
p1.line(tM,yM)
bk.show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bd300f62-8dc5-4332-8fc4-389f0e004d6e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bd300f62-8dc5-4332-8fc4-389f0e004d6e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bd300f62-8dc5-4332-8fc4-389f0e004d6e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bd300f62-8dc5-4332-8fc4-389f0e004d6e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9b47e330-8f8c-4e43-9a11-04c38b22368a":{"roots":{"references":[{"attributes":{},"id":"ffa2665e-099f-42ab-bde9-d6caae43dfb3","type":"LinearScale"},{"attributes":{"callback":null},"id":"7a39f15f-f983-4279-bea9-fb8f97b26f7c","type":"DataRange1d"},{"attributes":{"plot":{"id":"b938f76a-6f08-4ab3-9ac0-9431db33d2d2","subtype":"Figure","type":"Plot"}},"id":"b14e7b11-e9d8-48e3-aecc-4ca257d5d8e9","type":"HelpTool"},{"attributes":{"callback":null},"id":"1291c4d5-d28c-4327-92aa-96fcde27b9e3","type":"DataRange1d"},{"attributes":{"below":[{"id":"71711e89-da89-4031-b6c0-2b418935b095","type":"LinearAxis"}],"left":[{"id":"55cbf6f4-acb9-4476-8c52-b8b67ed50ec0","type":"LinearAxis"}],"renderers":[{"id":"71711e89-da89-4031-b6c0-2b418935b095","type":"LinearAxis"},{"id":"088d7df1-a31b-4ebc-8fc1-dfb3564ffee6","type":"Grid"},{"id":"55cbf6f4-acb9-4476-8c52-b8b67ed50ec0","type":"LinearAxis"},{"id":"27f21690-3fd3-4607-a310-0aee2f588cc7","type":"Grid"},{"id":"8900e135-09a5-4130-982e-5b73ee9d29b9","type":"BoxAnnotation"},{"id":"0ef8c450-9258-4759-ad09-49ad273d54ae","type":"GlyphRenderer"},{"id":"9f09fabc-888c-4229-b89e-443405a6e93d","type":"GlyphRenderer"}],"title":{"id":"e0fd6b49-6f58-4c1f-abc9-d92cf626671c","type":"Title"},"tool_events":{"id":"80f5943d-03ee-4b44-aef7-3760f2770b11","type":"ToolEvents"},"toolbar":{"id":"e8870423-b93c-4a58-b219-11da1ac1e8a3","type":"Toolbar"},"x_range":{"id":"7a39f15f-f983-4279-bea9-fb8f97b26f7c","type":"DataRange1d"},"x_scale":{"id":"7defed96-5bf5-4203-a7c1-73530154c8ff","type":"LinearScale"},"y_range":{"id":"1291c4d5-d28c-4327-92aa-96fcde27b9e3","type":"DataRange1d"},"y_scale":{"id":"ffa2665e-099f-42ab-bde9-d6caae43dfb3","type":"LinearScale"}},"id":"b938f76a-6f08-4ab3-9ac0-9431db33d2d2","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"577069a8-7bc9-4d04-937d-b1061a591684","type":"BasicTickFormatter"},{"attributes":{},"id":"80f5943d-03ee-4b44-aef7-3760f2770b11","type":"ToolEvents"},{"attributes":{"line_color":{"value":"tomato"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3b702b5d-8abe-4758-aa04-fc077c022c8c","type":"Line"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"28119712-de3e-4c60-b140-4eee460f7c0a","type":"PanTool"},{"id":"1ed43d2b-3da2-4341-afef-ec1796fb39a2","type":"WheelZoomTool"},{"id":"fd266ffd-1e6d-4585-a757-878d2c12071f","type":"BoxZoomTool"},{"id":"1abb44c7-2d92-4b73-8abf-79a7e4469e33","type":"SaveTool"},{"id":"a8f9b425-7b13-468d-9d93-14675f2b1e57","type":"ResetTool"},{"id":"b14e7b11-e9d8-48e3-aecc-4ca257d5d8e9","type":"HelpTool"}]},"id":"e8870423-b93c-4a58-b219-11da1ac1e8a3","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[500]},"y":{"__ndarray__":"...","dtype":"float64","shape":[500]}}},"id":"60a86558-fa6c-4c47-940f-a2681fd24137","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"577069a8-7bc9-4d04-937d-b1061a591684","type":"BasicTickFormatter"},"plot":{"id":"b938f76a-6f08-4ab3-9ac0-9431db33d2d2","subtype":"Figure","type":"Plot"},"ticker":{"id":"86e068b6-be31-461e-b991-66ee170014d3","type":"BasicTicker"}},"id":"71711e89-da89-4031-b6c0-2b418935b095","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"e0fd6b49-6f58-4c1f-abc9-d92cf626671c","type":"Title"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f89a6b0c-ff9a-4297-b732-b5f4c0e603e1","type":"Line"},{"attributes":{"formatter":{"id":"65a1eb8e-9ddc-4cd5-9be8-8b6f6f24a75a","type":"BasicTickFormatter"},"plot":{"id":"b938f76a-6f08-4ab3-9ac0-9431db33d2d2","subtype":"Figure","type":"Plot"},"ticker":{"id":"14697893-e0ff-4342-a59d-7b0cd26dfdc7","type":"BasicTicker"}},"id":"55cbf6f4-acb9-4476-8c52-b8b67ed50ec0","type":"LinearAxis"},{"attributes":{"overlay":{"id":"8900e135-09a5-4130-982e-5b73ee9d29b9","type":"BoxAnnotation"},"plot":{"id":"b938f76a-6f08-4ab3-9ac0-9431db33d2d2","subtype":"Figure","type":"Plot"}} ...

# %%
# Compute a Controller
params, b = AMIGO_Tune(K,T,L)
ky = cn.tf([params[0]],[1])+cn.tf([params[1]],[1,0])
kr = cn.tf([params[1]],[1,0])
closed =cn.feedback(G,ky)*kr
yc,tc = cn.step(closed)
# Plot
p2 = bk.figure()
p2.line(tc,yc, line_color= "tomato")
bk.show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="095f0a9b-07df-40b1-8d10-18c2f561f81d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("095f0a9b-07df-40b1-8d10-18c2f561f81d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("095f0a9b-07df-40b1-8d10-18c2f561f81d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '095f0a9b-07df-40b1-8d10-18c2f561f81d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4390c833-75be-4384-87d3-f77777d1469e":{"roots":{"references":[{"attributes":{},"id":"e6f1da94-6390-4f8b-b5db-b18118dd7529","type":"LinearScale"},{"attributes":{"formatter":{"id":"268ed35a-6319-4bef-93df-2bbb81b33e9d","type":"BasicTickFormatter"},"plot":{"id":"79122db2-c2f4-4e5e-a891-eb3d6814f356","subtype":"Figure","type":"Plot"},"ticker":{"id":"53f27358-44e4-4599-85fe-6291fe7932c4","type":"BasicTicker"}},"id":"330b869c-31eb-457d-9e89-9486e4fd3e58","type":"LinearAxis"},{"attributes":{},"id":"268ed35a-6319-4bef-93df-2bbb81b33e9d","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"af443013-0ab6-4980-ad81-1a90e4d84728","type":"Line"},{"attributes":{"plot":{"id":"79122db2-c2f4-4e5e-a891-eb3d6814f356","subtype":"Figure","type":"Plot"}},"id":"284ae442-ba5a-4a33-8862-ab51e89a8fdc","type":"ResetTool"},{"attributes":{"plot":{"id":"79122db2-c2f4-4e5e-a891-eb3d6814f356","subtype":"Figure","type":"Plot"},"ticker":{"id":"cf7c0311-4dee-4b66-a536-e733e8d070b1","type":"BasicTicker"}},"id":"634570a0-1830-4628-ac1b-8290aec47045","type":"Grid"},{"attributes":{"plot":{"id":"79122db2-c2f4-4e5e-a891-eb3d6814f356","subtype":"Figure","type":"Plot"}},"id":"9ce5e6df-4608-4918-8e66-871c89965414","type":"SaveTool"},{"attributes":{"line_color":{"value":"tomato"},"x":{"field":"x"},"y":{"field":"y"}},"id":"55e13472-5ba4-4af5-912e-d986f59da181","type":"Line"},{"attributes":{},"id":"d9921aa2-e1c4-4e4a-9508-516a5d8985d9","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a695cc65-2e34-4f53-864e-a5e3a1fe1d01","type":"PanTool"},{"id":"eee98bc2-30ba-45aa-9242-370214558dbd","type":"WheelZoomTool"},{"id":"6d2ffadb-e110-48b7-9887-adc9cad3fbe7","type":"BoxZoomTool"},{"id":"9ce5e6df-4608-4918-8e66-871c89965414","type":"SaveTool"},{"id":"284ae442-ba5a-4a33-8862-ab51e89a8fdc","type":"ResetTool"},{"id":"400d123c-42b6-4a31-9371-3fd4fa3b7317","type":"HelpTool"}]},"id":"79ce5d64-7375-4386-99d9-a7ebcaa36a8e","type":"Toolbar"},{"attributes":{"formatter":{"id":"d9921aa2-e1c4-4e4a-9508-516a5d8985d9","type":"BasicTickFormatter"},"plot":{"id":"79122db2-c2f4-4e5e-a891-eb3d6814f356","subtype":"Figure","type":"Plot"},"ticker":{"id":"cf7c0311-4dee-4b66-a536-e733e8d070b1","type":"BasicTicker"}},"id":"8d0f947c-1a2c-42dd-927c-2f1393571e10","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"79122db2-c2f4-4e5e-a891-eb3d6814f356","subtype":"Figure","type":"Plot"},"ticker":{"id":"53f27358-44e4-4599-85fe-6291fe7932c4","type":"BasicTicker"}},"id":"66409e8f-99a4-4708-9df1-136377a21714","type":"Grid"},{"attributes":{"plot":{"id":"79122db2-c2f4-4e5e-a891-eb3d6814f356","subtype":"Figure","type":"Plot"}},"id":"a695cc65-2e34-4f53-864e-a5e3a1fe1d01","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"6ae658cd-b43e-4429-a02d-e6f48bc42d33","type":"Title"},{"attributes":{"below":[{"id":"8d0f947c-1a2c-42dd-927c-2f1393571e10","type":"LinearAxis"}],"left":[{"id":"330b869c-31eb-457d-9e89-9486e4fd3e58","type":"LinearAxis"}],"renderers":[{"id":"8d0f947c-1a2c-42dd-927c-2f1393571e10","type":"LinearAxis"},{"id":"634570a0-1830-4628-ac1b-8290aec47045","type":"Grid"},{"id":"330b869c-31eb-457d-9e89-9486e4fd3e58","type":"LinearAxis"},{"id":"66409e8f-99a4-4708-9df1-136377a21714","type":"Grid"},{"id":"c5e98bc7-290f-4583-ad7e-ba73d8fdcf3d","type":"BoxAnnotation"},{"id":"f86e6dae-3673-48d5-9c07-fc1c08790fbc","type":"GlyphRenderer"}],"title":{"id":"6ae658cd-b43e-4429-a02d-e6f48bc42d33","type":"Title"},"tool_events":{"id":"f0cc122b-8834-43d4-a187-7ab6bce7d952","type":"ToolEvents"},"toolbar":{"id":"79ce5d64-7375-4386-99d9-a7ebcaa36a8e","type":"Toolbar"},"x_range":{"id":"7c226733-5b1f-4135-aa92-f42b6bdf246e","type":"DataRange1d"},"x_scale":{"id":"e6f1da94-6390-4f8b-b5db-b18118dd7529","type":"LinearScale"},"y_range":{"id":"caefa568-d61d-47ab-b9db-69359325e832","type":"DataRange1d"}," ...

# %%
b
# Out:
# 0.0
