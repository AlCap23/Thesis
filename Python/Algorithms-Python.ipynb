# %%
import numpy as np

# %%
## Define the Area Fit Method
def Area_Fit(y,u,t):
    """Returns a FOTD Model from the given data.
    y - array of outputs
    u - array of inputs
    t - array of time values
    """
    # Truncate for Maximum
    i_end = abs(y).argmax(axis=0)
    yp = y[0:i_end+1]
    up = u[0:i_end+1]
    tp = t[0:i_end+1]
    # Get Gain
    KM = (yp[-1]-yp[0])/(up[-1])
    # Get the Residence Time
    Tar = 1/KM * np.trapz(yp[-1]-yp,tp)
    # Time Constant
    T = np.exp(1)/KM*np.trapz(yp[np.where(tp<=Tar)],tp[np.where(tp<=Tar)])
    # Delay
    L = Tar-T
    # Check if all arguments are valid
    if (T < 0):
        print("Error - Negative lag")
        return -1
    if (L < 0):
        if (L < 1e-2):
            L = 0
        else:    
            print("Error - Negative delay")
            return -1
    return KM,T,L

# %%
# Define the AMIGO Tuning
def AMIGO_Tune(K,T,L, structure = 'PI'):
    """Computes the PI(D) controller parameter based on AMIGO algorithm;
       Parameter are returned as parallel notation KP,KI,KD and set point;
       Needs first order time delay parameter as input
    """
    # Check for small delay
    if L < 1e-1:
        L = 1e-1
    # PI Controller
    if structure == 'PI':
        # Parameter as Defined in Aström et. al., Advanced PID Control,p.229 
        KP = 0.15/K + (0.35 - L*T /(L+T)**2)*T/(K*L)
        TI = 0.35*L+(13*L*T**2)/(T**2+12*L*T+7*L**2)
        TD = 0.0
        # Set Point Weight, as given on p.235
        if L/(T+L) > 0.5:
            b = 1
        else:
            b = 0.0
        
    elif structure == 'PID':
        KP = 1/K*(0.2+0.45*T/L)
        TI = (0.4*L + 0.8*T)/(L+0.1*T)*L
        TD = (0.5*L*T)/(0.3*L+T)
        # Set Point Weight, Derived from Fig. 7.2, p. 230
        if L/(T+L) < 0.2:
            b = 0.4
        elif L/(T+L) > 0.3:
            b = 1.0
        else:
            # Approximate as Linear Function
            b = 0.4 + (1.0 - 0.4)/(0.3-0.2)*L/(T+L)
    else:
        print("Undefined controller Structure")
        return np.NaN
    KI = KP/TI
    KD = KP*TD
    return [KP,KI,KD],b

# Define AMIGO Detuning
def AMIGO_DETUNE(K,T,L,params,KP, MS = 1.4, structure = 'PI'):
    """Detunes the AMIGO parameter according to Astrom"""
    # Check for small delay
    if L < 1e-1:
        L = 1e-1
    # Needed Parameter
    alpha_D = (MS-1)/MS # See p.255 Eq. 7.19
    beta_D = MS*(MS+np.sqrt(MS**2-1))/2# See p.257 Eq. 7.24
    
    # Define old set of parameter
    KP0 = params[0]
    KI0 = params[1]
    KD0 = params[2]
    
    if structure=='PI':
        # Needed constrain for switch case,See p. 258 Eq. 7.27
        c = KP*K - KP0*K*(L+T)/(beta_D*(alpha_D+KP*K)) - alpha_D
        if c < 0:
            KI = beta_D*(alpha_D+KP*K)**2/(K*(L+T))
        else:
            KI = KI0*(alpha_D+KP*K)/(alpha_D+KP0*K)
        return [KP,KP/KI,0.0]
    if structure == 'PID':
        print("Not implemented")
        return np.NaN
    else:
        print("Undefined controller Structure")
        return np.NaN

# %%
def RGA(K,T,L,w=0):
    """Takes a FOTD System and computes the RGA of the system"""
    if (K.shape != T.shape) or (K.shape != L.shape) or (L.shape != T.shape):
        print("Shapes of parameter array are not equal!")
    # Compute the System
    G = np.absolute(FOTD_IMAG(K,T,L,w))
    # Calculate the RGA
    RGA = np.multiply(G, np.transpose(np.linalg.inv(G)))
    return RGA

# %%
def FOTD_IMAG(K,T,L,w=0):
    """Creates a FOTD MIMO system from the parameter matrices and the current frequency"""
    # Check if all dimensions match
    if (K.shape != T.shape) or (K.shape != L.shape) or (L.shape != T.shape):
        print("Shapes of parameter array are not equal!")
        return np.NaN
    # System Dimension
    if K.ndim == 1:
        # Using system Identity by multiplying with the complex conjugate
        G = 1/(T**2 * w**2 +1)*(K-1j*T*w)*(np.cos(-L*w)+1j*np.sin(-L*w))
    else:
        outputs,inputs = K.shape
        # Create a system within the complex numbers
        G = np.zeros_like(K)
        for i in range(0,inputs):
            for o in range(0,outputs):
                # Using system Identity by multiplying with the complex conjugate
                G[o][i] = 1 /(T[o][i]**2 * w**2 +1) * ( K[o][i] - 1j*T[o][i]*w) *(np.cos(-L[o][i]*w)+1j*np.sin(-L[o][i]*w))
    return G

# %%
def Control_Decentral(K,T,L, w = 0, b=np.empty, structure = 'PI'):
    """ Computes decentralised controller with AMIGO algorithm based on RGA pairing"""
    # Compute SISO Case
    if K.ndim <= 1:
        # Using system Identity by multiplying with the complex conjugate
        params, b0 = AMIGO_Tune(K,T,L)
        # If b is not given, use b from AMIGO
        if b == np.empty:
            Kr = [b0*params[0], params[1], params[2]]
            Ky = params
        else:
            Kr = [b*params[0],params[1],params[2]]
            Ky = params
    # Compute general MIMO Case
    else:
        # Systems dimensions
        outputs,inputs = K.shape
        # Create an empty controller
        Ky = np.empty([outputs,inputs,3])
        Kr = np.empty([outputs,inputs,3])
        # Compute RGA -> Checks for Shape
        LG = RGA(K,T,L,w)
        # Get Pairing as an array for every column
        Pairing = np.argmax(LG, axis=0)
        # Iterate through the pairing
        for o in range(0,outputs):
            # Best Pairing
            i = Pairing[o]
            # Compute controller via recursion
            Ky[o][i],Kr[o][i] = Control_Decentral(K[o][i],T[o][i],L[o][i],b)
    return Ky, Kr

def Control_Astrom(K,T,L,H, MS= None, w = 0, b=np.empty, structure = 'PI'):
    """Computes a Decoupling Controller via Aström Algortihm based on FOTD"""
    # Check Input for Maximum Sensitivity
    if MS is None:
        MS = 1.4*np.eye(K.shape[0],K.shape[1])
    # Compute Determinant of Maximum Sensitivity
    ms = np.linalg.det(MS)
    # Compute SISO Case
    if K.ndim <= 1:
        return Control_Decentral(K,T,L,w,b,structure)
    # Compute General MIMO Case
    else:
        
        # Systems dimensions
        outputs,inputs = K.shape
        # Check dimensions
        if (K.shape != T.shape) or (K.shape != H.shape) or (K.shape != MS.shape) or (K.shape != L.shape) or (L.shape != T.shape):
            print("Shapes of parameter array are not equal!")
            return np.NaN
        
        # Create an empty controller
        Ky = np.empty([outputs,inputs,3])
        Kr = np.empty([outputs,inputs,3])
               
        # Get minimal Delay/ Time Constant for robust limit of crossover frequency, ignore zeros
        if (L[np.where(L>0)].size !=0) or (T[np.where(T>0)].size !=0):
            if (L[np.where(L>0)].size !=0):
                wc_min = np.min([np.min(L[np.nonzero(L)]),np.min(T[np.nonzero(T)])])
            else:
                wc_min = np.min(np.min(T[np.nonzero(T)]))
        else:
            # Use very high frequency
            wc_min = 1e10
        
        # Compute the decoupler
        D = np.linalg.inv(K)
        # Compute the interaction indeces
        # Since d/ds(Q*K) = d/ds(Q)*K = d/ds(G) we can write the Taylor coefficient
        Gamma = np.abs(np.dot(np.multiply(-K,T+L),D))
        # Set main diagonal to zero
        np.fill_diagonal(Gamma,0)
        # Get the maximum of each row
        GMax = np.argmax(Gamma,axis=0)
        # Iterate through the outputs 
        for o in range(0,outputs):
            # Estimate the new system parameter
            # Get the maximal gain
            l = np.max(L[o][:])
            # Add the systems gain -> scaled
            k = np.dot(K[o][:],D[:][o])
            # Get the system time constant
            t = np.sum(np.multiply(np.multiply(K[o][:],D[:][o]),T[o][:]+L[o][:]))/k - l
            
            # Design a controller based on estimated system
            ky,kr = Control_Decentral(k,t,l,w,b,structure)
            
            # Test for Interaction
            
            # Current maximum interaction
            gmax = Gamma[o][GMax[o]]
            # Check for set point weight, either given
            if b == np.empty:
                # Or computed from AMIGO_TUNE
                b = kr[0]/ky[0]
            # Check for structure
            if structure == 'PI':
                # Set counter for while
                counter=0
                # Set shrinking rate in accordance with golden ratio
                shrink_rate = 0.618
                while (np.abs(H[o][o]/(ms*gmax)) - np.sqrt( (b*ky[0]/wc_min)**2 + ky[1]**2 ) < 0):
                    if counter > 10:
                        #print('Maximal Iteration for detuning reached! Abort')
                        break
                    # Detune the controller with the shrinking rate    
                    ky = AMIGO_DETUNE(k,t,l,ky,shrink_rate*ky[0])
                    # Increment counter
                    counter += 1
                # Get the controller parameter
                Ky[o][o][:] = ky
                Kr[o][o][:] = [b*ky[0], ky[1], ky[2]]
        # Rescale controller for real system
        for c in range(0,2):
            Ky[:][:][c] = np.dot(D,Ky[:][:][c])
            Kr[:][:][c] = np.dot(D,Kr[:][:][c])
        return Ky,Kr

# %% [markdown]
# # Test Area
# ### Testing the Algorithm on robustness etc

# %%
# Import the needed packages
# python control for LTI systems
import control as cn
# Import bokeh for Ploting
import bokeh.plotting as bk
import bokeh.io as bi
bi.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eca9ae7c-b3d2-4e48-b46f-0a54a3c8a437">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### SISO Test
# Testing Identification / AMIGO Tuning / AMIGO Detuning

# %%
# Test Identification
# Make a system
num = [1,0,20]
den = [50,10,1]
G = cn.tf(num,den)
G = G*G
# Step response
t = np.linspace(0,100,500)
y,t = cn.matlab.step(G,t)
# Add noise
y = y +np.random.normal(0,0.3,np.size(y))
u = np.ones_like(y)
# Parameter
K,T,L = Area_Fit(y,u,t)
num,den = cn.pade(L,15)
GM = cn.tf([K],[T,1])*cn.tf(num,den)
yM,tM = cn.matlab.step(GM, t)
# Plot
p1 = bk.figure()
p1.line(t,y, line_color= "tomato")
p1.line(tM,yM)
p1.circle(t[abs(y).argmax(axis=0)],y[abs(y).argmax(axis=0)], fill_color='orange', size=10)
bk.show(p1)

# Calculate the controller
params, b = AMIGO_Tune(K,T,L)
ky = cn.tf([params[0]],[1])+cn.tf([params[1]],[1,0])
kr = cn.tf([params[1]],[1,0])
cl =cn.feedback(G,ky)*kr
yc,tc = cn.step(cl)
# Plot
p2 = bk.figure()
p2.line(tc,yc, line_color= "tomato")
bk.show(p2)

# Find the Maximum Sensitivity
# Compute sensitivity
S = 1/(1+G*ky)
# compute the gain of the sensitivity
w = np.logspace(-5,5,1000)
mag, phase, freq = cn.matlab.bode(S,w)
MS = np.max(mag)

# Make a plot
p3= bk.figure(x_axis_type="log")
p3.line(freq,mag)
bk.show(p3)

#Detune the controller -> DOES NOT WORK!!! WHY!?
params = AMIGO_DETUNE(K,T,L,params, params[0])
ky2 = cn.tf([params[0]],[1])+cn.tf([params[1]],[1,0])
kr2 = cn.tf([params[1]],[1,0])
cl2 =cn.feedback(G,ky2)*kr2
yc2,tc2 = cn.step(cl2)
# Plot
p4 = bk.figure()
p4.line(tc,yc)
p4.line(tc2,yc2, line_color= "tomato")
bk.show(p4)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5a19f5af-64a5-4f92-831e-bd08b439c69f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5a19f5af-64a5-4f92-831e-bd08b439c69f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5a19f5af-64a5-4f92-831e-bd08b439c69f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5a19f5af-64a5-4f92-831e-bd08b439c69f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c35ff709-637f-4a79-b3cf-708674ad761b":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2f5b9ebc-5528-4ac1-be91-fffd43858639","type":"Line"},{"attributes":{},"id":"3edeee13-9273-4257-8ac3-6afd0b3dcd13","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"558d5804-bedd-419f-9ca6-e40ad5903998","type":"DataRange1d"},{"attributes":{"callback":null},"id":"c28a9b62-f46a-4e19-9c66-50d63cf51275","type":"DataRange1d"},{"attributes":{},"id":"b7387ba0-e57b-4a72-b340-acb8a69ad047","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0d9f4a46-c584-48d1-ac90-cfd405eb151d","type":"PanTool"},{"id":"293976af-0da0-422b-b035-f99be063abb6","type":"WheelZoomTool"},{"id":"195a3cab-9792-4e6e-b5e7-196973740f62","type":"BoxZoomTool"},{"id":"75644962-7dc1-433d-a412-01169b995574","type":"SaveTool"},{"id":"3e18d8a6-9321-4e15-a786-73005e012056","type":"ResetTool"},{"id":"2d73aac4-5645-43e1-b048-4da27a031385","type":"HelpTool"}]},"id":"4f207c2b-580f-4ce0-b9cb-524bc3b12014","type":"Toolbar"},{"attributes":{"plot":{"id":"2b83966b-c7e7-448c-8ab9-e1f9093fb737","subtype":"Figure","type":"Plot"},"ticker":{"id":"af48e4c8-b2ec-45a8-af24-5f91b7ea74e4","type":"BasicTicker"}},"id":"8c813589-6066-4603-a837-58e7f61e3e08","type":"Grid"},{"attributes":{"formatter":{"id":"3edeee13-9273-4257-8ac3-6afd0b3dcd13","type":"BasicTickFormatter"},"plot":{"id":"2b83966b-c7e7-448c-8ab9-e1f9093fb737","subtype":"Figure","type":"Plot"},"ticker":{"id":"af48e4c8-b2ec-45a8-af24-5f91b7ea74e4","type":"BasicTicker"}},"id":"47dcc4e2-78cb-4b7c-98bb-b7e19ec2d1ef","type":"LinearAxis"},{"attributes":{},"id":"cf09babb-096e-4b65-a706-63f4bddc4c38","type":"LinearScale"},{"attributes":{},"id":"af48e4c8-b2ec-45a8-af24-5f91b7ea74e4","type":"BasicTicker"},{"attributes":{},"id":"bc1bc5c9-aab9-40fc-a2e8-90b6abd4d445","type":"LinearScale"},{"attributes":{"formatter":{"id":"c3f49266-3df7-4faa-a712-7a44c648d9ba","type":"BasicTickFormatter"},"plot":{"id":"2b83966b-c7e7-448c-8ab9-e1f9093fb737","subtype":"Figure","type":"Plot"},"ticker":{"id":"57adc6e1-e7bd-4693-8943-989df9900801","type":"BasicTicker"}},"id":"48f467e9-e25e-41a2-8fb6-f837fd0928ae","type":"LinearAxis"},{"attributes":{},"id":"57adc6e1-e7bd-4693-8943-989df9900801","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"2b83966b-c7e7-448c-8ab9-e1f9093fb737","subtype":"Figure","type":"Plot"},"ticker":{"id":"57adc6e1-e7bd-4693-8943-989df9900801","type":"BasicTicker"}},"id":"6fb61d71-2e93-429a-ab14-342e28682af9","type":"Grid"},{"attributes":{"line_color":{"value":"tomato"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8d4f28ce-4fd2-44bb-a24b-f6e5b207d29e","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[500]},"y":{"__ndarray__":"...","dtype":"float64","shape":[500]}}},"id":"8a8050f4-66dc-48e0-a6eb-0f820d774352","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[500]},"y":{"__ndarray__":"...","dtype":"float64","shape":[500]}}},"id":"f1a779f5-b995-4ad7-8483-c28f68d89933","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"47dcc4e2-78cb-4b7c-98bb-b7e19ec2d1ef","type":"LinearAxis"}],"left":[{"id":"48f467e9-e25e-41a2-8fb6-f837fd0928ae","type":"LinearAxis"}],"renderers":[{"id":"47dcc4e2-78cb-4b7c-98bb-b7e19ec2d1ef","type":"LinearAxis"},{"id":"8c813589-6066-4603-a837-58e7f61e3e08","type":"Grid"},{"id":"48f467e9-e25e-41a2-8fb6-f837fd0928ae","type":"LinearAxis"},{"id":"6fb61d71-2e93-429a-ab14-342e28682af9","type":"Grid"},{"id":"033496d7-a35f-4075-acc0-0da45e3ca999","type":"BoxAnnotation"},{"id":"41083606-6bee-496d-971f-005e7d0b1c6e","type":"GlyphRenderer"},{"id":"dc23bf87-4314-4ccc-8107-f35948a748b5","type":"GlyphRenderer"},{"id":"7ef569b3-82b5-4542-a080-defef ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="397a62fc-1282-4569-b243-33a996b52ea8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("397a62fc-1282-4569-b243-33a996b52ea8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("397a62fc-1282-4569-b243-33a996b52ea8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '397a62fc-1282-4569-b243-33a996b52ea8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7f8b8435-3532-4c77-850e-b38a7c8bc305":{"roots":{"references":[{"attributes":{"data_source":{"id":"ac1bbd1d-cdda-4126-8747-7c3329d772f2","type":"ColumnDataSource"},"glyph":{"id":"132e40df-da82-47e6-8c90-3365df88af01","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0237f1a2-eac1-4d1b-b5bc-c4b5d076a845","type":"Line"},"selection_glyph":null},"id":"bac46677-dd08-44d3-b7c8-9d60185b401a","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"8b07c3c4-397b-4dc6-8573-ced94c6e3a3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"87047443-343a-4759-a351-882f6ca92372","type":"BasicTicker"}},"id":"45e4e685-9db5-4899-be8c-269ef1de7de8","type":"Grid"},{"attributes":{"plot":{"id":"8b07c3c4-397b-4dc6-8573-ced94c6e3a3d","subtype":"Figure","type":"Plot"}},"id":"95683efb-65c1-4311-9bf4-8be5d143392d","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6c4b9411-d941-4310-a895-c049327bd103","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"ca9d6948-9a90-4bc3-a6bb-c21f5928240b","type":"BasicTickFormatter"},"plot":{"id":"8b07c3c4-397b-4dc6-8573-ced94c6e3a3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"87047443-343a-4759-a351-882f6ca92372","type":"BasicTicker"}},"id":"bb899c83-da14-4562-adad-118b0a2c5471","type":"LinearAxis"},{"attributes":{},"id":"3348f08b-3f3e-4ae6-8eae-d592e8301a03","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"8b07c3c4-397b-4dc6-8573-ced94c6e3a3d","subtype":"Figure","type":"Plot"}},"id":"1c94b983-0304-4ca4-a9ac-b268308ae379","type":"ResetTool"},{"attributes":{"plot":{"id":"8b07c3c4-397b-4dc6-8573-ced94c6e3a3d","subtype":"Figure","type":"Plot"}},"id":"0c0641c3-8a3f-492e-9875-0971308a11b2","type":"SaveTool"},{"attributes":{"overlay":{"id":"6c4b9411-d941-4310-a895-c049327bd103","type":"BoxAnnotation"},"plot":{"id":"8b07c3c4-397b-4dc6-8573-ced94c6e3a3d","subtype":"Figure","type":"Plot"}},"id":"a1898764-11ce-4761-abcf-d313581bb712","type":"BoxZoomTool"},{"attributes":{},"id":"87047443-343a-4759-a351-882f6ca92372","type":"BasicTicker"},{"attributes":{"plot":{"id":"8b07c3c4-397b-4dc6-8573-ced94c6e3a3d","subtype":"Figure","type":"Plot"}},"id":"a315f9fe-cc21-4a7d-a210-a3eb863f3cef","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0237f1a2-eac1-4d1b-b5bc-c4b5d076a845","type":"Line"},{"attributes":{"line_color":{"value":"tomato"},"x":{"field":"x"},"y":{"field":"y"}},"id":"132e40df-da82-47e6-8c90-3365df88af01","type":"Line"},{"attributes":{"plot":{"id":"8b07c3c4-397b-4dc6-8573-ced94c6e3a3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"4843212f-adc8-4306-9fba-0e69425ce776","type":"BasicTicker"}},"id":"9bfcf51d-b287-40b9-baa4-f95496f4d2e0","type":"Grid"},{"attributes":{},"id":"4705e01b-9f53-4fd9-bc95-075df520a621","type":"LinearScale"},{"attributes":{},"id":"ca9d6948-9a90-4bc3-a6bb-c21f5928240b","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"8b07c3c4-397b-4dc6-8573-ced94c6e3a3d","subtype":"Figure","type":"Plot"}},"id":"fbf35439-6ed0-4b9a-8b17-0454c0da7879","type":"HelpTool"},{"attributes":{"plot":null,"text":""},"id":"1dad2637-9c4a-4313-b4db-1ce6fb995fab","type":"Title"},{"attributes":{"formatter":{"id":"3348f08b-3f3e-4ae6-8eae-d592e8301a03","type":"BasicTickFormatter"},"plot":{"id":"8b07c3c4-397b-4dc6-8573-ced94c6e3a3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"4843212f-adc8-4306-9fba-0e69425ce776","type":"BasicTicker"}},"id":"961d67b9-3a0d-4a6f-bb06-ff23be8a6dc7","type":"LinearAxis"},{"attributes":{},"id":"d9ab6ead-5a7e-4f54-b8d7-2a015a72e3c8","type":"ToolEvents"},{"attributes":{"callback":null},"id":"696d922f-97c0-4ac3-839b-ca030aafbc0c","t ...
# C:\Users\juliu\Anaconda3\lib\site-packages\control\freqplot.py:153: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(True);
# C:\Users\juliu\Anaconda3\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\juliu\Anaconda3\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")
# C:\Users\juliu\Anaconda3\lib\site-packages\control\freqplot.py:163: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(True);
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="547040ce-15e8-4409-a3c0-4dc508e9194c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("547040ce-15e8-4409-a3c0-4dc508e9194c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("547040ce-15e8-4409-a3c0-4dc508e9194c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '547040ce-15e8-4409-a3c0-4dc508e9194c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"686eda1e-8185-4312-a567-b960a0e7dbf4":{"roots":{"references":[{"attributes":{"plot":{"id":"99599806-9a77-4c4d-b0e0-d0dcebddceb8","subtype":"Figure","type":"Plot"}},"id":"c18ecb58-e1b8-49a9-a414-daf6523654d5","type":"PanTool"},{"attributes":{"plot":{"id":"99599806-9a77-4c4d-b0e0-d0dcebddceb8","subtype":"Figure","type":"Plot"}},"id":"16d9ba60-953c-4a19-9d10-f3829ee0ba54","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"b5d707e8-0091-4db6-8278-da60d728afa6","type":"BoxAnnotation"},"plot":{"id":"99599806-9a77-4c4d-b0e0-d0dcebddceb8","subtype":"Figure","type":"Plot"}},"id":"14ffbabe-b040-4063-a6db-a90bf61352dd","type":"BoxZoomTool"},{"attributes":{"ticker":null},"id":"23e7f030-3b1c-4b39-b422-acb472281014","type":"LogTickFormatter"},{"attributes":{"plot":{"id":"99599806-9a77-4c4d-b0e0-d0dcebddceb8","subtype":"Figure","type":"Plot"}},"id":"20becd88-2b07-4e00-a054-8b02b2b5bab0","type":"SaveTool"},{"attributes":{"plot":{"id":"99599806-9a77-4c4d-b0e0-d0dcebddceb8","subtype":"Figure","type":"Plot"}},"id":"8d15d604-dc89-4dec-b99a-1992beecbc29","type":"ResetTool"},{"attributes":{"plot":{"id":"99599806-9a77-4c4d-b0e0-d0dcebddceb8","subtype":"Figure","type":"Plot"}},"id":"53c9511f-c11f-43e9-98d2-80045592947b","type":"HelpTool"},{"attributes":{"callback":null},"id":"1c816e93-7763-48f4-9c63-732fa96ec375","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"843462fc-e1b2-440d-9282-ce937227cda1","type":"Title"},{"attributes":{"num_minor_ticks":10},"id":"671281a9-2ad2-4034-bfb9-c3dfd4f7f1b1","type":"LogTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c18ecb58-e1b8-49a9-a414-daf6523654d5","type":"PanTool"},{"id":"16d9ba60-953c-4a19-9d10-f3829ee0ba54","type":"WheelZoomTool"},{"id":"14ffbabe-b040-4063-a6db-a90bf61352dd","type":"BoxZoomTool"},{"id":"20becd88-2b07-4e00-a054-8b02b2b5bab0","type":"SaveTool"},{"id":"8d15d604-dc89-4dec-b99a-1992beecbc29","type":"ResetTool"},{"id":"53c9511f-c11f-43e9-98d2-80045592947b","type":"HelpTool"}]},"id":"da7628c0-ef1e-48de-9a2b-95fcaa7a315b","type":"Toolbar"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"110a0849-a4ff-48a2-ae56-fde6972dc9c7","type":"Line"},{"attributes":{"callback":null},"id":"25ee6e98-c06b-4913-9718-fb0dd100edf8","type":"DataRange1d"},{"attributes":{},"id":"0db3dc35-2e80-4937-9646-0f7dc26110ca","type":"ToolEvents"},{"attributes":{"data_source":{"id":"3bf6f07c-2399-4c4d-a3f1-919bfbd74372","type":"ColumnDataSource"},"glyph":{"id":"110a0849-a4ff-48a2-ae56-fde6972dc9c7","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8432e47c-78c2-4526-9e4d-3e7b3d8c9eb2","type":"Line"},"selection_glyph":null},"id":"d5074629-da8c-4211-94cf-eb1c5cc40a1b","type":"GlyphRenderer"},{"attributes":{},"id":"39c7c172-ee5d-4eff-b11b-177cbc25306a","type":"LinearScale"},{"attributes":{},"id":"afe8bbfc-568b-42be-9c90-7a7059ad1b1c","type":"LogScale"},{"attributes":{"below":[{"id":"29a7aaef-73de-4bd9-b29e-5f66f768bfe4","type":"LogAxis"}],"left":[{"id":"f0aa9dab-e5c5-4a3d-8490-741114fa30f6","type":"LinearAxis"}],"renderers":[{"id":"29a7aaef-73de-4bd9-b29e-5f66f768bfe4","type":"LogAxis"},{"id":"0e1a5e27-512c-4c42-9c10-36e8744e7924","type":"Grid"},{"id":"f0aa9dab-e5c5-4a3d-8490-741114fa30f6","type":"LinearAxis"},{"id":"85197f12-6408-4077-b162-386b04ea93c7","type":"Grid"},{"id":"b5d707e8-0091-4db6-8278-da60d728afa6","type":"BoxAnnotation"},{"id":"d5074629-da8c-4211-94cf-eb1c5cc40a1b","type":"GlyphRenderer"}],"title":{"id":"843462fc-e1b2-440d-9282-ce937227cda1","type":"Title"},"tool_events":{"id":"0db3dc35-2e80-4937-9646-0f7dc26110ca","type":"ToolEvents"},"toolbar":{"id":"da7628c0-ef1e-48de-9a2b-95fcaa7a315b","type":"Toolbar"},"x_range":{"id":"25ee6e98-c06b-4913-9718-fb0dd100edf8","type":"DataRange1d"},"x_scale":{"id":"afe8bbfc-568b-42be-9c90-7a7059ad1b1c","type":"LogScale"},"y_range":{"id":"1c816e93-7763-48f4-9c63-732fa96ec375","type" ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4ef84467-bd7b-458a-ab56-43f8ab1441ee"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4ef84467-bd7b-458a-ab56-43f8ab1441ee");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4ef84467-bd7b-458a-ab56-43f8ab1441ee");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4ef84467-bd7b-458a-ab56-43f8ab1441ee' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a7a9c055-63cc-41e7-8adb-079ad8a469c4":{"roots":{"references":[{"attributes":{"data_source":{"id":"3fb9bb11-5579-4fa4-83ee-f7521f6eb1e8","type":"ColumnDataSource"},"glyph":{"id":"6da3b413-c09e-4977-836e-d527fc4d7039","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"28bde199-f7d8-42b8-836a-878a1f685d1b","type":"Line"},"selection_glyph":null},"id":"bbcff840-1a16-48e1-b75f-8c250429b3af","type":"GlyphRenderer"},{"attributes":{},"id":"d25215ea-4482-4bd0-a8e9-b9f921cf99ab","type":"ToolEvents"},{"attributes":{"plot":{"id":"3532122e-beff-4fa9-884b-fa1f47c0b403","subtype":"Figure","type":"Plot"}},"id":"ecdedd15-c7e9-40d0-9424-46469096bbc9","type":"HelpTool"},{"attributes":{"callback":null},"id":"fa928b59-e934-4c79-9024-da2ded747df8","type":"DataRange1d"},{"attributes":{"below":[{"id":"bf1a5976-e3c6-49fd-a74e-699246e1f037","type":"LinearAxis"}],"left":[{"id":"21f130a7-08e1-47ba-95ab-d44341d0d608","type":"LinearAxis"}],"renderers":[{"id":"bf1a5976-e3c6-49fd-a74e-699246e1f037","type":"LinearAxis"},{"id":"b15a2ac3-4850-4811-b57d-5ff610cae79e","type":"Grid"},{"id":"21f130a7-08e1-47ba-95ab-d44341d0d608","type":"LinearAxis"},{"id":"8de5945d-a09d-488a-8e65-2c095ad61348","type":"Grid"},{"id":"8a4fbeb3-07db-4beb-b654-4375b335db47","type":"BoxAnnotation"},{"id":"afd9d183-4524-47d8-a3d2-304f43bdac40","type":"GlyphRenderer"},{"id":"bbcff840-1a16-48e1-b75f-8c250429b3af","type":"GlyphRenderer"}],"title":{"id":"a5394ea0-18f4-4f2e-8421-0c2c7da2a5f2","type":"Title"},"tool_events":{"id":"d25215ea-4482-4bd0-a8e9-b9f921cf99ab","type":"ToolEvents"},"toolbar":{"id":"6019fbe3-f304-4cb8-aee0-f4c44f0096be","type":"Toolbar"},"x_range":{"id":"fa928b59-e934-4c79-9024-da2ded747df8","type":"DataRange1d"},"x_scale":{"id":"1ec3e353-0622-468e-b232-2daf165b8095","type":"LinearScale"},"y_range":{"id":"2adabef2-0801-445e-9191-1ae31a7c4f1c","type":"DataRange1d"},"y_scale":{"id":"e0035b7d-adeb-4c07-a975-948caa203c3d","type":"LinearScale"}},"id":"3532122e-beff-4fa9-884b-fa1f47c0b403","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2d898588-3520-43c8-b66b-f8ac9f78c9f5","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"4958f2bd-4703-42d7-ad97-a8ecd7cd8491","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"28bde199-f7d8-42b8-836a-878a1f685d1b","type":"Line"},{"attributes":{"formatter":{"id":"e16b32df-80ab-4b5c-a35c-80866f2edce1","type":"BasicTickFormatter"},"plot":{"id":"3532122e-beff-4fa9-884b-fa1f47c0b403","subtype":"Figure","type":"Plot"},"ticker":{"id":"febf1d83-5d4d-41ad-bdf1-d50aeb43462f","type":"BasicTicker"}},"id":"21f130a7-08e1-47ba-95ab-d44341d0d608","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ecb23fd1-dd0b-48a8-914f-6ab22f4587ba","type":"PanTool"},{"id":"899214d0-411c-41bd-98c2-82e253ba284a","type":"WheelZoomTool"},{"id":"5031d5c4-cfac-4ac7-931e-e92bdbd77f41","type":"BoxZoomTool"},{"id":"f177ebe3-7dca-4398-8a3e-be2c2d1ff03c","type":"SaveTool"},{"id":"c56ae80e-ce8b-4723-ac43-0465c2622df4","type":"ResetTool"},{"id":"ecdedd15-c7e9-40d0-9424-46469096bbc9","type":"HelpTool"}]},"id":"6019fbe3-f304-4cb8-aee0-f4c44f0096be","type":"Toolbar"},{"attributes":{"line_color":{"value":"tomato"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6da3b413-c09e-4977-836e-d527fc4d7039","type":"Line"},{"attributes":{"data_source":{"id":"4958f2bd-4703-42d7-ad97-a8ecd7cd8491","type":"ColumnDataSource"},"glyph":{"id":"2d898588-3520-43c8-b66b-f8ac9f78c9f5","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"74ee29b4-bfdb-4ce8-a01d-5f93e87f5d4a","type":"Line"},"selection_glyph":null},"id":"afd9d183- ...

# %% [markdown]
# ### TEST MIMO System

# %%
# Make a system
num = [[[3],[10]], [[5],[1]]]
den = [[[10,1],[50,1]],[[20,1],[30,1]]]
#G = cn.tf(num,den)

# Time array
t = np.linspace(0,300,600)
# Store the output
y = np.empty([2,2,t.size])
# Input Array
u = np.ones_like(t)

# Define Parameter
K = np.empty([2,2])
T = np.empty([2,2])
L = np.empty([2,2])
G = [[0 for x in range(2)] for y in range(2)] 

# Identify from step response
for ins in range(0,2):
    for out in range(0,2):
        G[out][ins] = cn.tf(num[out][ins],den[out][ins])
        y[out][ins][:],t = cn.step(G[out][ins],t)
        K[out][ins],T[out][ins],L[out][ins] = Area_Fit(y[out][ins][:],u,t)
    
# Compute the decentralized controller
Ky1,Kr1 = Control_Decentral(K,T,L)
Ky2,Kr2 = Control_Astrom(K,T,L, 0.2*np.eye(2))

g = G[0][0]
ky = Ky1[0][0]
kr = Kr1[0][0]
ky = cn.tf([ky[0]],[1])+cn.tf([ky[1]],[1,0])
kr = cn.tf([kr[1]],[1,0])
cl =cn.feedback(g,ky)*kr
yc,tc = cn.step(cl)
# Plot
p4 = bk.figure()
p4.line(tc,yc)
bk.show(p4)
g
# Out:
# C:\Users\juliu\Anaconda3\lib\site-packages\ipykernel\__main__.py:18: ComplexWarning: Casting complex values to real discards the imaginary part
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9d66949b-1b03-4579-9bf8-b18125992375"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9d66949b-1b03-4579-9bf8-b18125992375");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9d66949b-1b03-4579-9bf8-b18125992375");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9d66949b-1b03-4579-9bf8-b18125992375' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5a6860cb-1746-4733-ba11-4103b36e6331":{"roots":{"references":[{"attributes":{"below":[{"id":"89e24a23-5db6-4078-b840-d0ba8fbb0c35","type":"LinearAxis"}],"left":[{"id":"5cc4cb67-eaf0-412d-b62d-4f008697a5cb","type":"LinearAxis"}],"renderers":[{"id":"89e24a23-5db6-4078-b840-d0ba8fbb0c35","type":"LinearAxis"},{"id":"fdfe1941-a430-4e86-a608-7ee9c8308db1","type":"Grid"},{"id":"5cc4cb67-eaf0-412d-b62d-4f008697a5cb","type":"LinearAxis"},{"id":"7793274d-7e90-48db-a94b-d54b2c8236e0","type":"Grid"},{"id":"79e4725a-734f-468c-a173-a189693fec5f","type":"BoxAnnotation"},{"id":"b18df849-c972-494c-b70d-cc4f7190eb01","type":"GlyphRenderer"}],"title":{"id":"9119f4aa-e5e7-4c33-bac2-6dc2631e5b9a","type":"Title"},"tool_events":{"id":"1b9504da-18e5-4770-9cbb-27fb16ae0267","type":"ToolEvents"},"toolbar":{"id":"81f8cb63-e09e-42bc-aee3-f467f8819e8f","type":"Toolbar"},"x_range":{"id":"66e63584-5c3d-4327-b7ea-bb18707022cc","type":"DataRange1d"},"x_scale":{"id":"3e8c42ec-2b71-4586-b146-eaa64391a60c","type":"LinearScale"},"y_range":{"id":"5a3c22ee-d6f9-4f79-8845-130eb67640da","type":"DataRange1d"},"y_scale":{"id":"8dcab24f-223a-4dd8-90e8-0b443a3a9373","type":"LinearScale"}},"id":"f951b180-4b51-4e06-8dce-866a624a4f5a","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"f951b180-4b51-4e06-8dce-866a624a4f5a","subtype":"Figure","type":"Plot"},"ticker":{"id":"56a73c57-7588-47d5-b8f1-6d2e3a79e5c5","type":"BasicTicker"}},"id":"7793274d-7e90-48db-a94b-d54b2c8236e0","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"13b6fb27-a0e3-482f-907e-7cabec0cefdb","type":"PanTool"},{"id":"2e94a83f-6bc3-4b6a-8367-2743202c0d9f","type":"WheelZoomTool"},{"id":"a7054914-6a9f-4037-8fc2-4f0519a5885a","type":"BoxZoomTool"},{"id":"54cb3b60-fe08-4a23-ab37-eba241aa7dfd","type":"SaveTool"},{"id":"e6ca0792-c026-4706-8503-6ab04003e5c4","type":"ResetTool"},{"id":"ea45c3d2-cd7c-4758-a05f-3cf9913c09b2","type":"HelpTool"}]},"id":"81f8cb63-e09e-42bc-aee3-f467f8819e8f","type":"Toolbar"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"aae0736d-d0e3-4788-954f-c188b390b774","type":"Line"},{"attributes":{"overlay":{"id":"79e4725a-734f-468c-a173-a189693fec5f","type":"BoxAnnotation"},"plot":{"id":"f951b180-4b51-4e06-8dce-866a624a4f5a","subtype":"Figure","type":"Plot"}},"id":"a7054914-6a9f-4037-8fc2-4f0519a5885a","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"5a3c22ee-d6f9-4f79-8845-130eb67640da","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"9b24538c-8c05-4544-8c6a-ef8732e4ef19","type":"ColumnDataSource"},{"attributes":{},"id":"3e8c42ec-2b71-4586-b146-eaa64391a60c","type":"LinearScale"},{"attributes":{},"id":"7a195efa-874e-41bb-913e-a0336aecd3e5","type":"BasicTickFormatter"},{"attributes":{},"id":"8dcab24f-223a-4dd8-90e8-0b443a3a9373","type":"LinearScale"},{"attributes":{"plot":{"id":"f951b180-4b51-4e06-8dce-866a624a4f5a","subtype":"Figure","type":"Plot"}},"id":"13b6fb27-a0e3-482f-907e-7cabec0cefdb","type":"PanTool"},{"attributes":{"plot":{"id":"f951b180-4b51-4e06-8dce-866a624a4f5a","subtype":"Figure","type":"Plot"},"ticker":{"id":"6f694bf7-9629-4b5d-887b-1be75eda851c","type":"BasicTicker"}},"id":"fdfe1941-a430-4e86-a608-7ee9c8308db1","type":"Grid"},{"attributes":{"data_source":{"id":"9b24538c-8c05-4544-8c6a-ef8732e4ef19","type":"ColumnDataSource"},"glyph":{"id":"aae0736d-d0e3-4788-954f-c188b390b774","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2dab1b8c-bda5-4fa9-99b2-96ae44cff130","type":"Line"},"selection_glyph":null},"id":"b18df849-c972-494c-b70d-cc4f7190eb01","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"f951b180-4b51-4e06-8dce-866a624a4f5a","subtype":"Figure","type":"Plot"}},"id":"ea45c3d2-cd7c-4758-a05f ...
#     3
# --------
# 10 s + 1

# %%
from sacred import Experiment

# %%
ex = Experiment('jupyter_ex', interactive=True)

@ex.config
def my_config():
    a = '42'
    
@ex.main
def my_main(a):
    return a

# %%
r = ex.run()
# Out:
# WARNING - jupyter_ex - No observers have been added to this run
# INFO - jupyter_ex - Running command 'my_main'
# INFO - jupyter_ex - Started
# INFO - jupyter_ex - Result: 42
# INFO - jupyter_ex - Completed after 0:00:00

# %%
r.result
# Out:
# '42'
