# %%
# Import the needed Packages
# FMU Simulation
import MoBASimulator as mb
# Numpy
import numpy as np
# Bokeh for Plotting
import bokeh.plotting as bk
import bokeh.io as bi
#from bokeh.io import export_svgs
bi.output_notebook()
# Algorithms
import Algorithms as alg

# Model Parameter
#k = np.random.uniform(-10,10,(2,2))
#t = np.random.uniform(1,20,(2,2))
#l = np.random.uniform(10,20,(2,2))

# Rosenbrock
#k = [[1.,2./3.],[1.,1.]]
#t = [[1.,1./3.],[1.,1.]]
#l = [[1e-10,1e-10],[1e-10,1e-10]]

# Woodberry
#k = [[12.8,-18.9],[6.6,-19.4]]
#t = [[16.7,21.0],[10.9,14.4]]
#l = [[1,3],[7,3]]


# The needed Parameter
K = np.zeros((2,2))
T = np.zeros((2,2))
L = np.zeros((2,2))

# Load a Model
sim = mb.Simulator()
sim.clear()
sim.loadModel("C:/Users/juliu/Documents/Thesis/Modelica/FMU/2_2/Masterthesis_Models_mimo_0processmodel.fmu")

# Show log window
sim.showLogWindow()

# Parameter Values
params = {}
# Loop over system size
for outputs in range(1,3):
    for inputs in range(1,3):
        # Process Parameter 
        # System Gain
        params.update({"fmu.num["+str(outputs)+","+str(inputs)+",1]": k[outputs-1][inputs-1]})
        # System Lag
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",1]": t[outputs-1][inputs-1]})
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",2]": 1})
        # System Delay
        params.update({"fmu.delay["+str(outputs)+","+str(inputs)+"]": l[outputs-1][inputs-1]})

# Set Parameter and show for checking
sim.set(params)
#sim.showParameterDialog()
#print(params)



# First run, Input 1 -> Output 1 & 2
sim.set({"fmu.u[1]": 1,"fmu.u[2]": 0})
# Set timestep = 1e-2, endtime = 100
sim.resetModelState()
res=sim.simulate(0.01, 100)

# Get the signals
y = res["fmu.y[1]"]
y2 = res["fmu.y[2]"]
u = res["fmu.u[1]"]
time = res["time"]

# Get TF from Input 1 to Output 1
K[0][0],T[0][0],L[0][0]=alg.Integral_Identification(y,u,time)
# Get TF from Input 1 to Output 2
K[1][0],T[1][0],L[1][0]=alg.Integral_Identification(y2,u,time)


# Second run, Input 2 -> Output 1 & 2
# Reload the Model to set everything to zero
sim.resetModelState()
sim.set({"fmu.u[1]":0, "fmu.u[2]":1})
# Set timestep = 1e-2, endtime = 100
res=sim.simulate(0.01, 200)

# Get the signals
y = res["fmu.y[1]"]
y2 = res["fmu.y[2]"]
u = res["fmu.u[2]"]
time = res["time"]

# Get TF from Input 2 to Output 1
K[0][1],T[0][1],L[0][1] = alg.Integral_Identification(y,u,time)
# Get TF from Input 2 to Output 2
K[1][1],T[1][1],L[1][1] = alg.Integral_Identification(y2,u,time)

# Make a controller
KY,B,D = alg.Control_Decentral(K,T,L)
#KY,B,D = alg.Control_Astrom(K,T,L,0.01*np.eye(2,2))
#KY,B,D = alg.Control_Decoupled(K,T,L,0.01*np.eye(2,2))
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c769b32b-b519-4954-8655-759de35dcdbf">Loading BokehJS ...</span>
#     </div>

# %%
KY,B,D
# Out:
# (array([[[ 0.        ,  0.        ,  0.        ],
#          [ 0.03064051,  0.0019288 ,  0.        ]],
#
#         [[-0.13738107, -0.01675914, -0.        ],
#          [ 0.        ,  0.        ,  0.        ]]]), array([[ 0.,  1.],
#         [ 1.,  0.]]), array([[ 1.,  0.],
#         [ 0.,  1.]]))

# %%
KY,B,D = alg.Control_Decentral(K,T,L)
# Make zeros to 1e-10 for numerical stable process
KY[KY==0] = 1e-10
B[B==0] = 1e-10
D[D==0] = 1e-10


# Load the closed loop model
sim.clear()
sim.loadModel("C:/Users/juliu/Documents/Thesis/Modelica/FMU/2_2/Masterthesis_Models_mimo_0closedloop.fmu")
# Parameter Values
params = {}
# Loop over system size
for outputs in range(1,3):
    for inputs in range(1,3):
        # Controller Parameter 
        # Proportional Gain
        params.update({"fmu.kp["+str(outputs)+","+str(inputs)+"]": KY[outputs-1][inputs-1][0]})
         # Integral Gain
        params.update({"fmu.ki["+str(outputs)+","+str(inputs)+"]": KY[outputs-1][inputs-1][1]})
        # Decoupler
        params.update({"fmu.d["+str(outputs)+","+str(inputs)+"]": D[outputs-1][inputs-1]})
        # Set Point Weight
        params.update({"fmu.b["+str(outputs)+","+str(inputs)+"]": B[outputs-1][inputs-1]})
        # Process Parameter 
        # System Gain
        params.update({"fmu.num["+str(outputs)+","+str(inputs)+",1]": k[outputs-1][inputs-1]})
        # System Lag
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",1]": t[outputs-1][inputs-1]})
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",2]": 1})
        # System Delay
        params.update({"fmu.delay["+str(outputs)+","+str(inputs)+"]": l[outputs-1][inputs-1]})
# Set Parameter Values
sim.set(params)
#sim.showParameterDialog()

# First run, Input 1 -> Output 1 & 2
sim.resetModelState()
sim.set({"fmu.u[1]": -1,"fmu.u[2]": 1})
# Set timestep = 1e-2, endtime = 100
sim.resetModelState()
res=sim.simulate(0.01, 200)

p = bk.figure(title = "Test")
p.line(res["time"],res["fmu.y[1]"], color = "blue")
p.line(res["time"],res["fmu.y[2]"], color = "red")
bk.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0d93e8a7-1160-4d1e-b8b3-8b584553ff03"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0d93e8a7-1160-4d1e-b8b3-8b584553ff03");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0d93e8a7-1160-4d1e-b8b3-8b584553ff03");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0d93e8a7-1160-4d1e-b8b3-8b584553ff03' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6a668675-ead5-4a83-acc6-3936a90156c2":{"roots":{"references":[{"attributes":{"callback":null},"id":"f7fae4ed-5acd-433b-8d83-1d1699ae8c1b","type":"DataRange1d"},{"attributes":{"plot":{"id":"589a1b6f-11d8-4e3d-a751-eb50d70a58c9","subtype":"Figure","type":"Plot"}},"id":"d75c7a22-f502-4025-b354-4777eb149dff","type":"HelpTool"},{"attributes":{},"id":"f5a9ddc2-998f-4511-a7ef-6f3172e19308","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[20001]},"y":{"__ndarray__":"...","dtype":"float64","shape":[20001]}}},"id":"4db4b92f-c915-4f3d-ae24-4ac144aeb470","type":"ColumnDataSource"},{"attributes":{},"id":"f0b5dbaf-d61e-44da-b4b3-0721cb52a759","type":"ToolEvents"},{"attributes":{"callback":null},"id":"e86e5fa7-e11b-4529-aab2-8879d7bd212f","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"589a1b6f-11d8-4e3d-a751-eb50d70a58c9","subtype":"Figure","type":"Plot"},"ticker":{"id":"f3a8a48e-9bb3-4791-9b1f-164539d34e43","type":"BasicTicker"}},"id":"174f9e18-c020-4f6d-a746-7150582762fd","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[20001]},"y":{"__ndarray__":"...","dtype":"float64","shape":[20001]}}},"id":"d5d4f71e-8ead-4601-8099-e154fea11961","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"f5a9ddc2-998f-4511-a7ef-6f3172e19308","type":"BasicTickFormatter"},"plot":{"id":"589a1b6f-11d8-4e3d-a751-eb50d70a58c9","subtype":"Figure","type":"Plot"},"ticker":{"id":"12e1c9c6-7de0-4e9b-a050-02712d7bd1b5","type":"BasicTicker"}},"id":"70f90aec-185f-44f7-9e95-4cf64c6b5135","type":"LinearAxis"},{"attributes":{"plot":{"id":"589a1b6f-11d8-4e3d-a751-eb50d70a58c9","subtype":"Figure","type":"Plot"}},"id":"9e5d9b51-c3d1-4b07-97cf-9c3a7676a96b","type":"ResetTool"},{"attributes":{},"id":"a0f0323f-9ee2-45f4-b110-771a0d871ed7","type":"BasicTickFormatter"},{"attributes":{},"id":"f3a8a48e-9bb3-4791-9b1f-164539d34e43","type":"BasicTicker"},{"attributes":{"plot":{"id":"589a1b6f-11d8-4e3d-a751-eb50d70a58c9","subtype":"Figure","type":"Plot"}},"id":"bf04fd3b-afa7-4aaa-b5f3-61895e2a7076","type":"PanTool"},{"attributes":{"plot":{"id":"589a1b6f-11d8-4e3d-a751-eb50d70a58c9","subtype":"Figure","type":"Plot"},"ticker":{"id":"12e1c9c6-7de0-4e9b-a050-02712d7bd1b5","type":"BasicTicker"}},"id":"c44266be-04e5-4f0a-b189-0f5f5375c2f2","type":"Grid"},{"attributes":{"data_source":{"id":"4db4b92f-c915-4f3d-ae24-4ac144aeb470","type":"ColumnDataSource"},"glyph":{"id":"1a0ebaf4-4bed-4134-96df-f4efca87fb57","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5200c51f-99c6-49ed-8804-3506fdc618f8","type":"Line"},"selection_glyph":null},"id":"2e612c1d-4eec-4f6a-9fc2-531888609b6c","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bf04fd3b-afa7-4aaa-b5f3-61895e2a7076","type":"PanTool"},{"id":"f46b994c-71fc-47a6-861b-6db654e02be0","type":"WheelZoomTool"},{"id":"f1444467-82f6-4740-a1eb-22eb4a973f6e","type":"BoxZoomTool"},{"id":"1ee12b39-59b0-4266-aded-dec3bc37b5bc","type":"SaveTool"},{"id":"9e5d9b51-c3d1-4b07-97cf-9c3a7676a96b","type":"ResetTool"},{"id":"d75c7a22-f502-4025-b354-4777eb149dff","type":"HelpTool"}]},"id":"ffad641c-fec9-423c-ad9a-e43c10522d2f","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"513639ac-fc23-4477-a011-6d9a494d8233","type":"Line"},{"attributes":{},"id":"12e1c9c6-7de0-4e9b-a050-02712d7bd1b5","type":"BasicTicker"},{"attributes":{"data_source":{"id":"d5d4f71e-8ead-4601-8099-e154fea11961","type":"ColumnDataSource"},"glyph":{"id":"4ead2894-2e83-45a6-bcff-a88d99bbdb6d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"513639ac-fc23-4477-a011-6d9a494d8233","type":"Line"},"selection_glyph":null},"id":"59602fea-d91a-4fd3-98e0-886ece5dedc1","type": ...

# %%
k,t,l
# Out:
# (array([[-3.15951771,  5.75340915],
#         [ 6.18842009,  8.44723945]]), array([[ 17.98055082,  14.68057004],
#         [ 17.0310114 ,  14.71161503]]), array([[ 0.22726635,  4.96165292],
#         [ 3.02744476,  4.78402247]]))

# %%
KY,B,D = alg.Control_Decoupled(K,T,L,0.01*np.eye(2,2))

# %%
#KY,B,D = alg.Control_Decoupled(K,T,L,0.01*np.eye(2,2))
# Make zeros to 1e-10 for numerical stable process
KY[KY==0] = 1e-10
B[B==0] = 1e-10
D[D==0] = 1e-10


# Load the closed loop model
sim.clear()
sim.loadModel("C:/Users/juliu/Documents/Thesis/Modelica/FMU/2_2/Masterthesis_Models_mimo_0closedloop.fmu")
# Parameter Values
params = {}
# Loop over system size
for outputs in range(1,3):
    for inputs in range(1,3):
        # Controller Parameter 
        # Proportional Gain
        params.update({"fmu.kp["+str(outputs)+","+str(inputs)+"]": KY[outputs-1][inputs-1][0]})
         # Integral Gain
        params.update({"fmu.ki["+str(outputs)+","+str(inputs)+"]": KY[outputs-1][inputs-1][1]})
        # Decoupler
        params.update({"fmu.d["+str(outputs)+","+str(inputs)+"]": D[outputs-1][inputs-1]})
        # Set Point Weight
        params.update({"fmu.b["+str(outputs)+","+str(inputs)+"]": B[outputs-1][inputs-1]})
        # Process Parameter 
        # System Gain
        params.update({"fmu.num["+str(outputs)+","+str(inputs)+",1]": k[outputs-1][inputs-1]})
        # System Lag
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",1]": t[outputs-1][inputs-1]})
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",2]": 1})
        # System Delay
        params.update({"fmu.delay["+str(outputs)+","+str(inputs)+"]": l[outputs-1][inputs-1]})
# Set Parameter Values
sim.set(params)
#sim.showParameterDialog()

# First run, Input 1 -> Output 1 & 2
sim.resetModelState()
sim.set({"fmu.u[1]": -1,"fmu.u[2]": 1})
# Set timestep = 1e-2, endtime = 100
sim.resetModelState()
res=sim.simulate(0.01, 200)

p = bk.figure(title = "Test")
p.line(res["time"],res["fmu.y[1]"], color = "blue")
p.line(res["time"],res["fmu.y[2]"], color = "red")
bk.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d1b3f6f4-857c-490b-a1b1-b73ab10c72c8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d1b3f6f4-857c-490b-a1b1-b73ab10c72c8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d1b3f6f4-857c-490b-a1b1-b73ab10c72c8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd1b3f6f4-857c-490b-a1b1-b73ab10c72c8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"890abafe-fb4e-4113-bb30-f96f67e808db":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"538f8ec2-eac2-48ad-8b68-e6efed8e9be7","type":"PanTool"},{"id":"e3a10af1-b144-449d-9753-27304d70fd4b","type":"WheelZoomTool"},{"id":"d447280a-a65c-413e-9ac8-4a824466c53a","type":"BoxZoomTool"},{"id":"d237d45e-9595-4bee-970a-ac5a6a8e711c","type":"SaveTool"},{"id":"bfee3510-7d82-419f-b625-983fbf811931","type":"ResetTool"},{"id":"65f5099b-0342-42c4-a5ae-43665c1cdc34","type":"HelpTool"}]},"id":"7d6ef182-f2cb-46e7-889a-31d6076496c9","type":"Toolbar"},{"attributes":{"plot":{"id":"59a76ade-c838-4404-9a18-001f1df2955e","subtype":"Figure","type":"Plot"}},"id":"d237d45e-9595-4bee-970a-ac5a6a8e711c","type":"SaveTool"},{"attributes":{"callback":null},"id":"aa553674-9fb4-4cac-841e-c02f50cdf2bc","type":"DataRange1d"},{"attributes":{"data_source":{"id":"61a679d1-539d-4995-9422-916976779b83","type":"ColumnDataSource"},"glyph":{"id":"c07de27a-9fd9-4aa0-a130-070e905eae29","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"290785f7-4692-4eb9-b759-e15a55593640","type":"Line"},"selection_glyph":null},"id":"14081ab8-715e-4a27-a10f-076d8d38fa2b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[20001]},"y":{"__ndarray__":"...","dtype":"float64","shape":[20001]}}},"id":"61a679d1-539d-4995-9422-916976779b83","type":"ColumnDataSource"},{"attributes":{},"id":"0e5563e3-4c45-4484-9868-60dde7ba3788","type":"ToolEvents"},{"attributes":{"plot":{"id":"59a76ade-c838-4404-9a18-001f1df2955e","subtype":"Figure","type":"Plot"}},"id":"bfee3510-7d82-419f-b625-983fbf811931","type":"ResetTool"},{"attributes":{"plot":{"id":"59a76ade-c838-4404-9a18-001f1df2955e","subtype":"Figure","type":"Plot"}},"id":"538f8ec2-eac2-48ad-8b68-e6efed8e9be7","type":"PanTool"},{"attributes":{"plot":{"id":"59a76ade-c838-4404-9a18-001f1df2955e","subtype":"Figure","type":"Plot"}},"id":"e3a10af1-b144-449d-9753-27304d70fd4b","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"59a76ade-c838-4404-9a18-001f1df2955e","subtype":"Figure","type":"Plot"},"ticker":{"id":"53b9de9d-a712-4f28-b213-f7bce457a994","type":"BasicTicker"}},"id":"ae3d803b-8d58-43a9-aec8-88ec049a7329","type":"Grid"},{"attributes":{"plot":null,"text":"Test"},"id":"95f47b73-ff71-4290-a487-cb5d36fda20c","type":"Title"},{"attributes":{"below":[{"id":"4a43b443-cc76-45c3-99f3-f278e281cd56","type":"LinearAxis"}],"left":[{"id":"d250cffc-0259-4a95-80ac-c3f1979fb4da","type":"LinearAxis"}],"renderers":[{"id":"4a43b443-cc76-45c3-99f3-f278e281cd56","type":"LinearAxis"},{"id":"3414e8d1-c384-4d06-ac33-83f23c88b3ce","type":"Grid"},{"id":"d250cffc-0259-4a95-80ac-c3f1979fb4da","type":"LinearAxis"},{"id":"ae3d803b-8d58-43a9-aec8-88ec049a7329","type":"Grid"},{"id":"be4d599e-ea74-4855-b3c7-982a30dda70e","type":"BoxAnnotation"},{"id":"14081ab8-715e-4a27-a10f-076d8d38fa2b","type":"GlyphRenderer"},{"id":"7f82f29d-0647-4d79-9a74-057815d742a0","type":"GlyphRenderer"}],"title":{"id":"95f47b73-ff71-4290-a487-cb5d36fda20c","type":"Title"},"tool_events":{"id":"0e5563e3-4c45-4484-9868-60dde7ba3788","type":"ToolEvents"},"toolbar":{"id":"7d6ef182-f2cb-46e7-889a-31d6076496c9","type":"Toolbar"},"x_range":{"id":"0105151b-dadb-4230-b7e6-bafd1d6bf11c","type":"DataRange1d"},"y_range":{"id":"aa553674-9fb4-4cac-841e-c02f50cdf2bc","type":"DataRange1d"}},"id":"59a76ade-c838-4404-9a18-001f1df2955e","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"859238c3-e22a-4477-b79a-b64de5b4014a","type":"BasicTickFormatter"},{"attributes":{},"id":"53b9de9d-a712-4f28-b213-f7bce457a994","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0b399d6f-4aa3-4ba9-9fc2-06231e23c397","type":"Line"},{"attributes":{"overlay":{"id":"be4d599e-ea74-4855-b3c7-982a30dda70e","type":"BoxAnnotation ...
