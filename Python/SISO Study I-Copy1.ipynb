# %%
# Import Pandas
import pandas as pd
# Import Numpy
import numpy as np
# Import Bokeh
import bokeh.plotting as bk
import bokeh.io as bi
from bokeh.io import export_svgs
bi.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7467e3c7-96d1-44f4-8177-c9d75cf05bef">Loading BokehJS ...</span>
#     </div>

# %%
# Read the Data
Data = pd.read_csv('./Experiments/SISO/SISO_23082017_3.csv', sep=';')
# Give the Columns
Data.columns
# Out:
# Index(['Unnamed: 0', 'Sample No.', 'Order', 'K', 'TSum', 'KM', 'TM', 'LM',
#        'MS Real', 'MS Ideal', 'Tr_RSW', 'Mp_RSW', 'Ts_RSW', 'Ys_RSW', 'Tr_R',
#        'Mp_R', 'Ts_R', 'Ys_R', 'Tr_ISW', 'Mp_ISW', 'Ts_ISW', 'Ys_ISW', 'Tr_I',
#        'Mp_I', 'Ts_I', 'Ys_I'],
#       dtype='object')

# %%
# Look at Errors in Step response
error_data = Data[['Ys_RSW','Ys_R','Ys_ISW','Ys_I']]
step_error = error_data.isnull().sum()

# Sample Count
msreal_sample = Data['MS Real']
msreal_sample = msreal_sample.notnull().sum()

# Get Data above 2
msreal_unstable = Data[Data['MS Real']>2.0]
msreal_unstable = msreal_unstable['MS Real'].notnull().sum()

# %% [markdown]
# # Plot the Evaluation

# %%
# select a palette
from bokeh.palettes import Plasma9  as palette
# itertools handles the cycling
import itertools  
from bokeh.models import Range1d, Label

# create a color iterator
colors = itertools.cycle(palette)
# count higher then MS > 5
mscount_real = 0
mscount_iden = 0
x = []
y = []
order=[]
x2 = []
y2 = []

p2 = bk.figure(plot_width = 800, plot_height = 800, x_range=(0.9, 2), y_range=(0.9, 2), x_axis_label='Maximum Sensitivity Real System', y_axis_label='Maximum Sensitivity Identified System')
for i, color in zip(range(10,1,-1), colors):
    # Load the Data
    ms_id = Data[((Data['Order'] == i))]['MS Ideal']
    ms_re = Data[((Data['Order'] == i))]['MS Real']
    x.append(np.mean(ms_id))
    x2.append(np.var(ms_id))
    y.append(np.mean(ms_re))
    y2.append(np.var(ms_re))
    order.append(i)
    p2.scatter(ms_re,ms_id, color = color, alpha = 1, legend='Order '+str(i-1))

# Get the legend horizontal    
p2.legend.orientation='horizontal'
# Make a copy for later plot
p3 = p2

# Add annotation
label1 = Label(x=1.4, y=1.0, text='No. of samples: '+str(msreal_sample))
label2 = Label(x=1.4, y=0.975, text='Critical Systems: '+str(msreal_unstable))
p2.add_layout(label1)
p2.add_layout(label2)
# Show and Export
p2.output_backend = "svg"
export_svgs(p2, filename="SISO_Robustness.svg")

bk.show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a8abe3fd-6dac-4cd4-8607-fa47f9317622"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a8abe3fd-6dac-4cd4-8607-fa47f9317622");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a8abe3fd-6dac-4cd4-8607-fa47f9317622");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a8abe3fd-6dac-4cd4-8607-fa47f9317622' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"939a8f8c-7b42-462e-ac23-d920362de7e1":{"roots":{"references":[{"attributes":{},"id":"4d8c4774-71eb-4632-8ce4-884fda905ca3","type":"LinearScale"},{"attributes":{"data_source":{"id":"94f9ecfe-b740-4727-87d5-56f6daa264cd","type":"ColumnDataSource"},"glyph":{"id":"d76c369c-639d-4703-8afe-6cff2e844722","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4a48225b-3a3d-49a5-93dc-89786aae6973","type":"Circle"},"selection_glyph":null},"id":"ff2a6dbd-2108-4fd4-84dd-e28208222539","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"6e3d69cc-df7c-4340-bd5a-80340b69c9de","subtype":"Figure","type":"Plot"}},"id":"396b1a18-95ef-46ad-ae6d-5d3896043ce1","type":"HelpTool"},{"attributes":{"data_source":{"id":"1557a651-d955-4b19-8580-de952f00cf8d","type":"ColumnDataSource"},"glyph":{"id":"053667fb-0da6-4ab1-bb2e-3de37413a2b7","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7f13dc85-b038-4213-ab6d-ee69c280348a","type":"Circle"},"selection_glyph":null},"id":"9a36b349-b15a-4176-abab-cc0059e631cf","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#E56B5C"},"line_color":{"value":"#E56B5C"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2fe9c9bd-a496-489a-9433-e3ad491c2a00","type":"Circle"},{"attributes":{"callback":null,"end":2,"start":0.9},"id":"9917fafa-775d-4e63-89f7-f323d02e483c","type":"Range1d"},{"attributes":{"data_source":{"id":"67d432e0-397d-4935-8303-6871604a3006","type":"ColumnDataSource"},"glyph":{"id":"1f77db72-84d3-4f20-befb-c2dfbec7e681","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a0c8cf3e-ddbb-45a1-acab-52d8c4150c61","type":"Circle"},"selection_glyph":null},"id":"3bfb722a-93e3-491b-adf3-5c28c5aa8210","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Order 1"},"renderers":[{"id":"ff2a6dbd-2108-4fd4-84dd-e28208222539","type":"GlyphRenderer"}]},"id":"f2fff031-7098-4d44-87f2-f9af618b9d56","type":"LegendItem"},{"attributes":{"fill_color":{"value":"#FDC328"},"line_color":{"value":"#FDC328"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1c1c2ebb-bf04-4dd1-ba39-7c83c461af21","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7f13dc85-b038-4213-ab6d-ee69c280348a","type":"Circle"},{"attributes":{"plot":{"id":"6e3d69cc-df7c-4340-bd5a-80340b69c9de","subtype":"Figure","type":"Plot"}},"id":"5e9fb8da-7582-49ac-9c3c-0a765c56c9b1","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[3000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[3000]}}},"id":"6a4f2d1b-bee1-4e27-bc85-9533136d625a","type":"ColumnDataSource"},{"attributes":{"axis_label":"Maximum Sensitivity Real System","formatter":{"id":"50a600b3-ef44-487c-8584-1d5b742d4d53","type":"BasicTickFormatter"},"plot":{"id":"6e3d69cc-df7c-4340-bd5a-80340b69c9de","subtype":"Figure","type":"Plot"},"ticker":{"id":"58e3d7fe-a2e3-4e59-a047-dcc811b95031","type":"BasicTicker"}},"id":"bfdd9910-f107-4741-a4dd-4da78c97bb0d","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[3000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[3000]}}},"id":"5865f871-6564-4b52-bd19-c10a8d1fc724","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a6455dc5-5d93-4bbd-b3aa-bd4ba68a2321","type":"ColumnDataSource"},"glyph":{"id":"2fe9c9bd-a496-489a-9433-e3ad491c2a00","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0e36e8bc-1f84-4bfc-8d7a-80978592d365","type":"Circle"},"selection_glyph":null},"id":"cb5e12de-0568-48f8-911a-170c72552d34","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Order 7"},"renderers":[{"id":"72234454-9b3f-4ad2-adc0-0086366d5b57","type":"GlyphRenderer"}]},"id":"797226d2-d381-47f2-9da1-44e998508602", ...

# %%
# select a palette
from bokeh.palettes import Plasma9  as palette
# itertools handles the cycling
import itertools  
from bokeh.models import Range1d, Label

# create a color iterator
colors = itertools.cycle(palette)
# count higher then MS > 5
mscount_real = 0
mscount_iden = 0
x = []
y = []
order=[]
x2 = []
y2 = []

p2 = bk.figure(plot_width = 800, plot_height = 800,x_range=(0,150),y_range=(0,150), x_axis_label='TSum', y_axis_label='TRise')
for i, color in zip(range(10,1,-1), colors):
    # Load the Data
    ms_id = Data[((Data['Order'] == i))]['Tr_RSW']
    ms_re = Data[((Data['Order'] == i))]['TSum']
    p2.scatter(ms_re,ms_id, color = color, alpha = 1, legend='Order '+str(i-1))

# Get the legend horizontal    
p2.legend.orientation='horizontal'
# Make a copy for later plot
p3 = p2

# Add annotation
#label1 = Label(x=1.4, y=1.0, text='No. of samples: '+str(msreal_sample))
#label2 = Label(x=1.4, y=0.975, text='Critical Systems: '+str(msreal_unstable))
#p2.add_layout(label1)
#p2.add_layout(label2)
# Show and Export
#p2.output_backend = "svg"
#export_svgs(p2, filename="SISO_Robustness.svg")

bk.show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6fa59948-136b-455f-bbf9-c70c4d97ad2d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6fa59948-136b-455f-bbf9-c70c4d97ad2d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6fa59948-136b-455f-bbf9-c70c4d97ad2d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6fa59948-136b-455f-bbf9-c70c4d97ad2d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4eb8e06f-344d-495b-9e24-edd1911d2ff9":{"roots":{"references":[{"attributes":{},"id":"4bb92ac8-e439-4ab3-8872-c6c336ada529","type":"BasicTickFormatter"},{"attributes":{"items":[{"id":"ac0b81d1-81bd-4708-8a99-7f242b8d1da0","type":"LegendItem"},{"id":"42856a65-d8ce-428d-8485-f8edfe147a4e","type":"LegendItem"},{"id":"93333faa-f3ec-4b3d-9940-842040271146","type":"LegendItem"},{"id":"8cb0f959-3b46-477e-84f0-eec188e21091","type":"LegendItem"},{"id":"b76546ac-cf96-4637-946c-ed2ef6f2fc76","type":"LegendItem"},{"id":"e31a0bb2-2c35-4024-a4e1-961a39efc7f9","type":"LegendItem"},{"id":"177e5893-d910-4523-8b78-55283a21aad9","type":"LegendItem"},{"id":"2e780d29-29cf-4f98-99fd-ecd25b5f9c22","type":"LegendItem"},{"id":"c0c307df-eb14-4287-9955-a4a5a771e5a0","type":"LegendItem"}],"orientation":"horizontal","plot":{"id":"0d72d539-1686-4b57-88e3-175174312281","subtype":"Figure","type":"Plot"}},"id":"87a4fcca-8c62-4066-9a0f-5f0ad3e9babb","type":"Legend"},{"attributes":{"data_source":{"id":"280de1d8-d977-40a0-9933-8ccb22769418","type":"ColumnDataSource"},"glyph":{"id":"dd1e192d-a459-45ac-bd0e-cf9c41a0b271","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"05cb33fc-e6c9-49df-9e93-a8d6b961ea1a","type":"Circle"},"selection_glyph":null},"id":"712617e5-33a7-4e48-8ca5-d9f708654e8d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"05cb33fc-e6c9-49df-9e93-a8d6b961ea1a","type":"Circle"},{"attributes":{},"id":"a31067dc-a9eb-4d36-b273-284fda1e9522","type":"BasicTicker"},{"attributes":{"overlay":{"id":"c2da52c2-457b-451b-86a2-2bb3be664df3","type":"BoxAnnotation"},"plot":{"id":"0d72d539-1686-4b57-88e3-175174312281","subtype":"Figure","type":"Plot"}},"id":"5aa47c82-3f5e-498c-9ce6-dc36dcf583c2","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"0d72d539-1686-4b57-88e3-175174312281","subtype":"Figure","type":"Plot"},"ticker":{"id":"a31067dc-a9eb-4d36-b273-284fda1e9522","type":"BasicTicker"}},"id":"8f4be5ac-ea78-4e99-a16a-0e8bdb759194","type":"Grid"},{"attributes":{"callback":null,"end":150},"id":"005fcaff-49cb-4c18-80e7-d82cfc733964","type":"Range1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[3000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[3000]}}},"id":"280de1d8-d977-40a0-9933-8ccb22769418","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#7C02A7"},"line_color":{"value":"#7C02A7"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7ca14100-725e-41aa-941b-bcd99923824d","type":"Circle"},{"attributes":{"data_source":{"id":"3bc5b0e2-2d58-4948-a1dd-004324e23d31","type":"ColumnDataSource"},"glyph":{"id":"78b319e4-7305-4e34-91c2-ad7755434e89","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a2319a56-f06e-4ac8-904c-b46cae78dfe3","type":"Circle"},"selection_glyph":null},"id":"b2a2b7ce-0659-4ebf-9f11-cfe1c0993046","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#FDC328"},"line_color":{"value":"#FDC328"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9983cb78-fd15-4277-b2a9-3a57d7ebc980","type":"Circle"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[3000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[3000]}}},"id":"1825f1a2-0c7c-43a0-847d-9f53723df26d","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#EFF821"},"line_color":{"value":"#EFF821"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd1e192d-a459-45ac-bd0e-cf9c41a0b271","type":"Circle"},{"attributes":{"axis_label":"TSum","formatter":{"id":"21f4ba98-5ee1-4577-bdbf-b97927d869fd","type":"BasicTickFormatter"},"plot":{"id":"0d72d539-1686-4b57-88e3-175174312281","subtype":"Figure","type":"Plot"},"ticker":{"id":"aa10e33a-9d47-42f7-83f3-917b2c428bb7","type":"BasicTicker"}},"id":"4 ...

# %%
# select a palette
from bokeh.palettes import Plasma9  as palette
# itertools handles the cycling
import itertools  
from bokeh.models import Range1d, Label

# create a color iterator
colors = itertools.cycle(palette)
# count higher then MS > 5
mscount_real = 0
mscount_iden = 0
x = []
y = []
order=[]
x2 = []
y2 = []

p2 = bk.figure(plot_width = 800, plot_height = 800, x_axis_label='TSum', y_axis_label='TRise')
for i, color in zip(range(10,1,-1), colors):
    # Load the Data
    ms_id = Data[((Data['Order'] == i))]['Tr_RSW']
    ms_id2 = Data[((Data['Order'] == i))]['Ts_RSW']
    ms_re = Data[((Data['Order'] == i))]['TSum']
    order.append(i-1)
    p2.scatter(ms_id2/ms_re,ms_id/ms_re, color = color, alpha = 1, legend='Order '+str(i-1))

# Get the legend horizontal    
p2.legend.orientation='horizontal'
# Make a copy for later plot
p3 = p2

# Add annotation
#label1 = Label(x=1.4, y=1.0, text='No. of samples: '+str(msreal_sample))
#label2 = Label(x=1.4, y=0.975, text='Critical Systems: '+str(msreal_unstable))
#p2.add_layout(label1)
#p2.add_layout(label2)
# Show and Export
#p2.output_backend = "svg"
#export_svgs(p2, filename="SISO_Robustness.svg")

bk.show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="008eec18-fce2-4ad9-a807-ea2e627572cc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("008eec18-fce2-4ad9-a807-ea2e627572cc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("008eec18-fce2-4ad9-a807-ea2e627572cc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '008eec18-fce2-4ad9-a807-ea2e627572cc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1f7db63b-690e-48cd-9be2-dd98194d9311":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"79474b18-1bdc-48bb-921d-983a0e4b4104","type":"Circle"},{"attributes":{"label":{"value":"Order 9"},"renderers":[{"id":"145388fd-3447-4af8-a95d-e262e75edcd8","type":"GlyphRenderer"}]},"id":"fe341d10-d15b-4fba-bfe3-7c2526a49d5e","type":"LegendItem"},{"attributes":{"fill_color":{"value":"#7C02A7"},"line_color":{"value":"#7C02A7"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2a1b9738-6a27-40dc-892d-99154a77e317","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6d41e9da-522e-4f63-84fb-fdad7ace89c3","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b350eae-f327-433d-9a6c-92b4393b4876","type":"Circle"},{"attributes":{"label":{"value":"Order 1"},"renderers":[{"id":"bbc96c0e-986e-4b00-a6a5-34aaa3675312","type":"GlyphRenderer"}]},"id":"a265e119-3da2-4281-8663-e15b06116b46","type":"LegendItem"},{"attributes":{"overlay":{"id":"859aefb7-9cec-42f1-9882-3e30dded42b2","type":"BoxAnnotation"},"plot":{"id":"e894e999-3162-4cc1-bb8f-43e29e568c62","subtype":"Figure","type":"Plot"}},"id":"0849e706-fd63-47af-aad4-bd2be457c692","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"5cf7ff78-5ecc-45d6-8df7-9ca3370e57e7","type":"DataRange1d"},{"attributes":{"data_source":{"id":"460526ee-22b2-40a5-a89f-968b1aae4e91","type":"ColumnDataSource"},"glyph":{"id":"2a1b9738-6a27-40dc-892d-99154a77e317","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"49aa4f2c-703d-43c3-a5f1-d2e92fba8bf6","type":"Circle"},"selection_glyph":null},"id":"462ac7a3-b38e-49a5-b403-f815e52789a8","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[3000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[3000]}}},"id":"a2dab6d0-969a-4f32-83c9-4593b3a470f3","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"e894e999-3162-4cc1-bb8f-43e29e568c62","subtype":"Figure","type":"Plot"}},"id":"17dd6cb7-2dbd-4768-804a-012c1ee41fc4","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[3000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[3000]}}},"id":"e77f07e0-3dde-4477-a192-ecc8bd4bcc43","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d8184036-fe14-41f2-be5c-8d34215659d5","type":"Circle"},{"attributes":{"plot":{"id":"e894e999-3162-4cc1-bb8f-43e29e568c62","subtype":"Figure","type":"Plot"}},"id":"14b02422-285f-47cb-92ab-724aae6fee24","type":"PanTool"},{"attributes":{},"id":"53bc3dbe-5fbe-40ca-b1d8-a119b4906357","type":"LinearScale"},{"attributes":{"fill_color":{"value":"#FDC328"},"line_color":{"value":"#FDC328"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ae5768d2-db16-4156-87d0-ad5a005bee96","type":"Circle"},{"attributes":{"fill_color":{"value":"#CA4678"},"line_color":{"value":"#CA4678"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0b768d65-6396-4427-bf3e-0e0ca0ddaff5","type":"Circle"},{"attributes":{"fill_color":{"value":"#4A02A0"},"line_color":{"value":"#4A02A0"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b9c4b4ea-bfde-41db-ad48-5f11762f0170","type":"Circle"},{"attributes":{"below":[{"id":"072c267a-0afc-4d4f-8cde-f37209597f24","type":"LinearAxis"}],"left":[{"id":"e62bef44-6aa7-44ae-88ad-1ae9b08eed65","type":"LinearAxis"}],"plot_height":800,"plot_width":800,"renderers":[{"id":"072 ...

# %%
from bokeh.models import Band

p5 = bk.figure(plot_width = 800, plot_height = 300, x_axis_label='Model Order', y_axis_label='Normalized Time')

# Empty dicts for storage
ymean = []
ymax = []
ymin = []
order = []

# Data iteration
for i, color in zip(range(10,1,-1), colors):
    x = Data[((Data['Order'] == i))]['Order']
    y = Data[((Data['Order'] == i))]['LM']/(Data[((Data['Order'] == i))]['TM']+Data[((Data['Order'] == i))]['LM'])
    order.append(i)
    ymean.append((np.mean(y)))
    ymax.append(np.max(y))
    ymin.append(np.min(y))
    p5.scatter(x,y, color = color, legend='Order '+str(i-1))

# Get the legend horizontal    
p5.legend.orientation='horizontal'

# Add the Band
band = Band(x=order, upper=ymax, lower = ymin, level='underlay',
            fill_alpha=1.0, line_width=1, line_color='black')
p5.add_layout(band)
#p5.line(order,ymean, line_dash='dashed', color='black')
# Show and Export
#p5.output_backend = "svg"
#export_svgs(p5, filename="SISO_NormalizedTime.svg")

bk.show(p5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-ccc9aa714ead> in <module>()
#      24 # Add the Band
#      25 band = Band(x=order, upper=ymax, lower = ymin, level='underlay',
# ---> 26             fill_alpha=1.0, line_width=1, line_color='black')
#      27 p5.add_layout(band)
#      28 #p5.line(order,ymean, line_dash='dashed', color='black')
#
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/bokeh/model.py in __init__(self, **kwargs)
#     225         self._id = kwargs.pop("id", make_id())
#     226         self._document = None
# --> 227         super(Model, self).__init__(**kwargs)
#     228         default_theme.apply_to_model(self)
#     229
#
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/bokeh/core/has_props.py in __init__(self, **properties)
#     244
#     245         for name, value in properties.items():
# --> 246             setattr(self, name, value)
#     247
#     248     def __setattr__(self, name, value):
#
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/bokeh/core/has_props.py in __setattr__(self, name, value)
#     272
#     273         if name in props or name in deprecated:
# --> 274             super(HasProps, self).__setattr__(name, value)
#     275         else:
#     276             matches, text = difflib.get_close_matches(name.lower(), props), "similar"
#
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/bokeh/core/property/descriptors.py in __set__(self, obj, value, setter)
#     970         '''
#     971         value = self._extract_units(obj, value)
# --> 972         super(UnitsSpecPropertyDescriptor, self).__set__(obj, value, setter)
#     973
#     974     def set_from_json(self, obj, json, models=None, setter=None):
#
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/bokeh/core/property/descriptors.py in __set__(self, obj, value, setter)
#     493             raise RuntimeError("%s.%s is a readonly property" % (obj.__class__.__name__, self.name))
#     494
# --> 495         self._internal_set(obj, value, setter)
#     496
#     497     def __delete__(self, obj):
#
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/bokeh/core/property/descriptors.py in _internal_set(self, obj, value, setter)
#     711
#     712         '''
# --> 713         value = self.property.prepare_value(obj, self.name, value)
#     714
#     715         old = self.__get__(obj, obj.__class__)
#
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/bokeh/core/properties.py in prepare_value(self, cls, name, value)
#    1661         except TypeError:
#    1662             pass
# -> 1663         return super(DistanceSpec, self).prepare_value(cls, name, value)
#    1664
#    1665 class ScreenDistanceSpec(NumberSpec):
#
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/bokeh/core/property/bases.py in prepare_value(self, obj_or_cls, name, value)
#     288                     break
#     289             else:
# --> 290                 raise e
#     291         else:
#     292             value = self.transform(value)
#
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/bokeh/core/property/bases.py in prepare_value(self, obj_or_cls, name, value)
#     281     def prepare_value(self, obj_or_cls, name, value):
#     282         try:
# --> 283             self.validate(value)
#     284         except ValueError as e:
#     285             for tp, converter in self.alternatives:
#
# /home/alcapitan/anaconda3/lib/python3.5/site-packages/bokeh/core/properties.py in validate(self, value)
#     674
#     675         if not (value is None or any(param.is_valid(value) for param in self.type_params)):
# --> 676             raise ValueError("expected an element of either %s, got %r" % (nice_join(self.type_params), value))
#     677
#     678     # TODO (bev) implement this
#
# ValueError: expected an element of either String, Dict(Enum('field', 'value', 'transform', 'units'), Either(String, Instance(Transform), Float)) or Float, got [0.029811251098300129, 0.32366385328311664, 0.46213764937767282, 0.55504810442996722, 0.62907774174020659, 0.68913173039194264, 0.73365430931689746, 0.77168165369875397, 0.80101740372202523]

# %%
p2 = bk.figure(plot_width = 800, plot_height = 300)
for i, color in zip(range(1,10), colors):
    ideal = Data[((Data['Order'] == i))]['Ts_RSW']
    real = Data[((Data['Order'] == i))]['Ts_R']
    p2.scatter(real,ideal, color = color)
bk.show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="806005fe-93db-4aec-b76b-12be94346a15"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("806005fe-93db-4aec-b76b-12be94346a15");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("806005fe-93db-4aec-b76b-12be94346a15");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '806005fe-93db-4aec-b76b-12be94346a15' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5e48fd04-c965-4c0a-877a-56b6cc1e0fa5":{"roots":{"references":[{"attributes":{},"id":"7f2acc8d-38d5-4673-a03a-ab09ff276a88","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8a45e316-e7cc-4366-aee0-98846124dbcf","type":"PanTool"},{"id":"9407c5bc-92f0-459d-b977-08580187405f","type":"WheelZoomTool"},{"id":"55459e1d-3113-4c7c-a15f-31e49f4e2452","type":"BoxZoomTool"},{"id":"390f5491-052e-4716-80fc-a964822c15d1","type":"SaveTool"},{"id":"abddc2ec-65a6-4fd3-8e6c-d705a519dd0c","type":"ResetTool"},{"id":"5b7a7e75-1ee1-449e-96b0-8ec7f80c5dc9","type":"HelpTool"}]},"id":"ee53828b-6206-4512-8273-3ee183e5a1ed","type":"Toolbar"},{"attributes":{"data_source":{"id":"acb43add-93f0-4e2e-8039-2852626f43c9","type":"ColumnDataSource"},"glyph":{"id":"59dacf1b-7d23-4931-a213-a2d4748b5770","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9b6563b7-1c57-4a6f-bfab-fe948ff74ed9","type":"Circle"},"selection_glyph":null},"id":"e3cb14dd-30ae-41fd-8c25-f0f8fb6ed00a","type":"GlyphRenderer"},{"attributes":{},"id":"d1749ead-c6b2-48e8-bbde-c236d76eccf9","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[2000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[2000]}}},"id":"acb43add-93f0-4e2e-8039-2852626f43c9","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#0C0786"},"line_color":{"value":"#0C0786"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a36b42d9-bb79-4317-8eab-6e1f5abe9ccb","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"85b63d16-cba9-40df-a9e9-0017e02e7a31","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7548b118-6ec1-4251-944b-9bec4c0cd5be","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a03088eb-2def-4cc7-a6b9-f4c1ac44b11b","type":"Circle"},{"attributes":{"fill_color":{"value":"#EFF821"},"line_color":{"value":"#EFF821"},"x":{"field":"x"},"y":{"field":"y"}},"id":"68c07bf9-998c-46dd-9de8-66ddcc59ca96","type":"Circle"},{"attributes":{},"id":"7e208e8d-0063-4b1c-a864-c0eafbb38051","type":"LinearScale"},{"attributes":{"fill_color":{"value":"#A82296"},"line_color":{"value":"#A82296"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1b7e0166-049c-4164-bafb-f2197711bd10","type":"Circle"},{"attributes":{"below":[{"id":"02160100-a041-48bb-a878-6325955390f9","type":"LinearAxis"}],"left":[{"id":"a61e37af-dc55-4854-a219-964d74ae4f31","type":"LinearAxis"}],"plot_height":300,"plot_width":800,"renderers":[{"id":"02160100-a041-48bb-a878-6325955390f9","type":"LinearAxis"},{"id":"aeb1cc67-21bb-4cac-96a7-dcf87d332566","type":"Grid"},{"id":"a61e37af-dc55-4854-a219-964d74ae4f31","type":"LinearAxis"},{"id":"02ebbfdf-41cb-4217-8a20-9388a9a20dea","type":"Grid"},{"id":"e7bf2df3-f896-466c-a710-ecb2165985ce","type":"BoxAnnotation"},{"id":"e34051dc-7c71-4531-89b9-5ba7359bc6dd","type":"GlyphRenderer"},{"id":"97da8d94-b925-4d65-a93b-a93056329756","type":"GlyphRenderer"},{"id":"84ecf7f1-24fc-4fef-9aef-964466904d0c","type":"GlyphRenderer"},{"id":"7b8458a2-e784-43bb-92a2-bbdfa74c60d8","type":"GlyphRenderer"},{"id":"21de6e48-aa01-46a1-96a3-efaeea7a72a0","type":"GlyphRenderer"},{"id":"7f99d3a4-5dd9-4b3f-bc0e-2dfc39f2e1b6","type":"GlyphRenderer"},{"id":"691c8052-1680-4acd-9848-d97184178c5d","type":"GlyphRenderer"},{"id":"e3cb14dd-30ae-41fd-8c25-f0f8fb6ed00a","type":"GlyphRenderer"},{"id":"93c1dd3c-a808-4ab6-baa6-c9c0979cad6a","type":"GlyphRenderer"}],"title":{"id":"42a10d0e-9ffc-4c70-a2e9-390b71ae3543","type": ...

# %%
import bokeh
p = BoxPlot(Data, values='vals', label='cyl',
 legend='bottom_right')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-bb2beb9909c7> in <module>()
#       1 import bokeh
# ----> 2 p = BoxPlot(Data, values='vals', label='cyl',
#       3  legend='bottom_right')
#
# NameError: name 'BoxPlot' is not defined

# %%
p1 = bk.figure(plot_width = 800, plot_height = 800, x_range=(0.8,2.0))
p2 = bk.figure(plot_width = 800, plot_height = 800, x_range=(0.8,2.0))

for i, color in zip(range(1,10), colors):
    # Load the Data
    ms_id = Data[((Data['Order'] == i))]['MS Ideal']
    ms_re = Data[((Data['Order'] == i))]['MS Real']
    
    hist1, edges1 = np.histogram(ms_id, density=True, bins=50)
    hist2, edges2 = np.histogram(ms_re, density=True, bins=50)
    
    p1.quad(top=hist1, bottom=0, left=edges1[:-1], right=edges1[1:],
        fill_color=color, line_color=color, legend='Order '+str(i))
    p2.quad(top=hist2, bottom=0, left=edges2[:-1], right=edges2[1:],
        fill_color=color, line_color=color, legend='Order '+str(i))
    
    
p1.legend.orientation='horizontal'
p2.legend.orientation='horizontal'
bk.show(p1)
bk.show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="674174b8-c61d-4b33-894f-8df7ac78cfab"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("674174b8-c61d-4b33-894f-8df7ac78cfab");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("674174b8-c61d-4b33-894f-8df7ac78cfab");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '674174b8-c61d-4b33-894f-8df7ac78cfab' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cbb38f89-0b26-49ba-a4c7-8ba8ac0bcc09":{"roots":{"references":[{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"bc5cf6bd-b806-4ccf-9cc1-46aa1c8f522d","type":"Quad"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#F79341"},"left":{"field":"left"},"line_color":{"value":"#F79341"},"right":{"field":"right"},"top":{"field":"top"}},"id":"36ea744e-3d65-416a-8f27-b462fb687768","type":"Quad"},{"attributes":{"label":{"value":"Order 6"},"renderers":[{"id":"cc28caa9-77cf-47df-a5d5-8da46a7574e4","type":"GlyphRenderer"}]},"id":"bb4e6319-666f-400d-8881-0b7b3e948cc9","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["right","left","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"494bacfa-c31b-47f1-abea-58d969a462f2","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#CA4678"},"left":{"field":"left"},"line_color":{"value":"#CA4678"},"right":{"field":"right"},"top":{"field":"top"}},"id":"f5871cef-40b9-485f-a133-712b7122df9d","type":"Quad"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#4A02A0"},"left":{"field":"left"},"line_color":{"value":"#4A02A0"},"right":{"field":"right"},"top":{"field":"top"}},"id":"8fa743d5-60e7-429f-9eca-93074312a69a","type":"Quad"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#EFF821"},"left":{"field":"left"},"line_color":{"value":"#EFF821"},"right":{"field":"right"},"top":{"field":"top"}},"id":"db6569df-bd1a-4433-95eb-a38d699f1daf","type":"Quad"},{"attributes":{"plot":{"id":"f41fd143-9eea-4b62-aceb-e0bc04c71600","subtype":"Figure","type":"Plot"}},"id":"29f90b71-b7f4-489a-9445-f6c1c57a9df7","type":"HelpTool"},{"attributes":{"formatter":{"id":"40b29887-82fc-44f8-9805-587a690b999c","type":"BasicTickFormatter"},"plot":{"id":"f41fd143-9eea-4b62-aceb-e0bc04c71600","subtype":"Figure","type":"Plot"},"ticker":{"id":"80b08806-86c9-49d5-8b8a-9a58030a170c","type":"BasicTicker"}},"id":"0f8dfb7e-37de-414f-aed7-c5f10b4ce63b","type":"LinearAxis"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"a9760161-fe7d-4016-8d0a-ad61e1a8f698","type":"Quad"},{"attributes":{"callback":null,"column_names":["right","left","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"c503b19b-1331-4496-b681-ce6615cad9bb","type":"ColumnDataSource"},{"attributes":{},"id":"40b29887-82fc-44f8-9805-587a690b999c","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["right","left","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"733a7926-4d7a-4cae-a17c-8b87886da707","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"43e5b4e7-0f41-4de5-bc98-2976182ebd40","type":"ColumnDataSource"},"glyph":{"id":"36ea744e-3d65-416a-8f27-b462fb687768","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"09cd4b3c-2b6b-473d-9038-889eb70e8c46","type":"Quad"},"selection_glyph":null},"id":"bb1dfbfb-2c34-4c50-8fa0-5486787c5d35","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"733a7926-4d7a-4cae-a17c-8b87886da707","type":"ColumnDataSource"},"glyph":{"id":"de9a3841-420e-45af-b462-d4027100ac0b","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"09dda810-1746-4 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="06df980c-3f16-47ce-8492-b4b3c6bcde35"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("06df980c-3f16-47ce-8492-b4b3c6bcde35");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("06df980c-3f16-47ce-8492-b4b3c6bcde35");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '06df980c-3f16-47ce-8492-b4b3c6bcde35' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6990ce3b-e8d7-4cbf-a730-e965b13481c7":{"roots":{"references":[{"attributes":{},"id":"8b1fea8c-33cf-48ff-8838-736b4360522f","type":"BasicTickFormatter"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#CA4678"},"left":{"field":"left"},"line_color":{"value":"#CA4678"},"right":{"field":"right"},"top":{"field":"top"}},"id":"62ff95d6-6629-46aa-9d7d-816481b808e6","type":"Quad"},{"attributes":{"label":{"value":"Order 9"},"renderers":[{"id":"0cc8de69-c2cd-40ec-98a1-d39845b64a09","type":"GlyphRenderer"}]},"id":"e7e1e80d-5b77-48d7-bddf-b5ab72a4bb93","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["right","left","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"42140d6a-69db-4422-b307-7f6fed82e23c","type":"ColumnDataSource"},{"attributes":{},"id":"160bc824-6420-44b8-9b21-9f29f1ea38aa","type":"BasicTicker"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"6401a6bb-2846-46bb-90fa-93647d0d9d42","type":"Quad"},{"attributes":{"callback":null,"end":2.0,"start":0.8},"id":"d37f717c-62ab-489b-955d-0467ac477527","type":"Range1d"},{"attributes":{"label":{"value":"Order 7"},"renderers":[{"id":"9ff8efed-b6c4-47a2-8e50-8a3d9ecb6455","type":"GlyphRenderer"}]},"id":"e2920332-2180-45da-9bfe-974fc2ed70a9","type":"LegendItem"},{"attributes":{},"id":"90938c57-e526-4127-ae35-577f977871df","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["right","left","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"9cf59a46-c5b8-48df-b288-b27f10f203b6","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d2bfa2a1-1e02-4f3a-b5a7-bed52ef3560a","type":"ColumnDataSource"},"glyph":{"id":"62ff95d6-6629-46aa-9d7d-816481b808e6","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"38f470d1-57b1-4475-b5d4-e72d4cfeeadb","type":"Quad"},"selection_glyph":null},"id":"9ff8efed-b6c4-47a2-8e50-8a3d9ecb6455","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"9ef096d7-73df-4deb-b837-4cba004fc8cc","subtype":"Figure","type":"Plot"},"ticker":{"id":"160bc824-6420-44b8-9b21-9f29f1ea38aa","type":"BasicTicker"}},"id":"d6974f4b-05e3-4aba-98e2-08fe6bf57fdd","type":"Grid"},{"attributes":{"callback":null,"column_names":["right","left","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"6a4e292e-a438-4c48-ba66-ceb35f13173a","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["right","left","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"5eb771aa-073e-465c-b1b0-1b39e7050557","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#F79341"},"left":{"field":"left"},"line_color":{"value":"#F79341"},"right":{"field":"right"},"top":{"field":"top"}},"id":"bc27c1f3-2a48-4eab-b002-6d917898827a","type":"Quad"},{"attributes":{"data_source":{"id":"e04cad3c-c865-45dc-8c88-7c389242f29c","type":"ColumnDataSource"},"glyph":{"id":"14328269-35fb-44c2-86c2-7f11a6e6568e","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6401a6bb-2846-46bb-90fa-93647d0d9d42","type":"Quad"},"selection_glyph":null},"id":"143d819b-22c3-4318-9fd0-903b86dabd80","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["right","left","to ...
