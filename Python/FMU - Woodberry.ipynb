# %%
# Import the needed Packages
# FMU Simulation
import MoBASimulator as mb
# Numpy
import numpy as np
# Bokeh for Plotting
import bokeh.plotting as bk
import bokeh.io as bi
#from bokeh.io import export_svgs
bi.output_notebook()
# Algorithms
import Algorithms as alg

# Model Parameter
#k = np.random.uniform(-10,10,(2,2))
#t = np.random.uniform(1,20,(2,2))
#l = np.random.uniform(10,20,(2,2))

# Rosenbrock
#k = [[1.,2./3.],[1.,1.]]
#t = [[1.,1./3.],[1.,1.]]
#l = [[1e-10,1e-10],[1e-10,1e-10]]

# Woodberry
k = [[12.8,-18.9],[6.6,-19.4]]
t = [[16.7,21.0],[10.9,14.4]]
l = [[1,3],[7,3]]


# The needed Parameter
K = np.zeros((2,2))
T = np.zeros((2,2))
L = np.zeros((2,2))

# Load a Model
sim = mb.Simulator()
sim.clear()
sim.loadModel("C:/Users/juliu/Documents/Thesis/Modelica/FMU/2_2/Masterthesis_Models_mimo_0processmodel.fmu")

# Show log window
sim.showLogWindow()

# Parameter Values
params = {}
# Loop over system size
for outputs in range(1,3):
    for inputs in range(1,3):
        # Process Parameter 
        # System Gain
        params.update({"fmu.num["+str(outputs)+","+str(inputs)+",1]": k[outputs-1][inputs-1]})
        # System Lag
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",1]": t[outputs-1][inputs-1]})
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",2]": 1})
        # System Delay
        params.update({"fmu.delay["+str(outputs)+","+str(inputs)+"]": l[outputs-1][inputs-1]})

# Set Parameter and show for checking
sim.set(params)
#sim.showParameterDialog()
#print(params)



# First run, Input 1 -> Output 1 & 2
sim.set({"fmu.u[1]": 1,"fmu.u[2]": 0})
# Set timestep = 1e-2, endtime = 100
sim.resetModelState()
res = sim.simulate(0.01, 150)

# Get the signals
y = res["fmu.y[1]"]
y2 = res["fmu.y[2]"]
u = res["fmu.u[1]"]
time = res["time"]

# Get TF from Input 1 to Output 1
K[0][0],T[0][0],L[0][0]=alg.Integral_Identification(y,u,time)
# Get TF from Input 1 to Output 2
K[1][0],T[1][0],L[1][0]=alg.Integral_Identification(y2,u,time)


# Second run, Input 2 -> Output 1 & 2
# Reload the Model to set everything to zero
sim.resetModelState()
sim.set({"fmu.u[1]":0, "fmu.u[2]":1})
# Set timestep = 1e-2, endtime = 100
res=sim.simulate(0.01, 150)

# Get the signals
y = res["fmu.y[1]"]
y2 = res["fmu.y[2]"]
u = res["fmu.u[2]"]
time = res["time"]

# Get TF from Input 2 to Output 1
K[0][1],T[0][1],L[0][1] = alg.Integral_Identification(y,u,time)
# Get TF from Input 2 to Output 2
K[1][1],T[1][1],L[1][1] = alg.Integral_Identification(y2,u,time)

# Make variable storage
y = []
u = []
time = []

# Loop over the methods for controller design
for methods in range(0,3):
    if methods == 0:
        # Make a decentralized controller
        KY,B,D = alg.Control_Decentral(K,T,L)
    elif methods == 1:
        # Make a decoupled controller with Astrom
        KY,B,D = alg.Control_Astrom(K,T,L,0.01*np.eye(2,2))
    else:
        # Make a decoupled controller with modified Astrom
        KY,B,D = alg.Control_Decoupled(K,T,L,0.01*np.eye(2,2))

    # Make zeros to 1e-10 for numerical stable process
    KY[KY==0] = 1e-10
    B[B==0] = 1e-10
    D[D==0] = 1e-10


    # Load the closed loop model
    sim.clear()
    sim.loadModel("C:/Users/juliu/Documents/Thesis/Modelica/FMU/2_2/Masterthesis_Models_mimo_0closedloop.fmu")
    # Parameter Valuess
    params = {}
    
    # Loop over system size
    for outputs in range(1,3):
        for inputs in range(1,3):
            # Controller Parameter 
            # Proportional Gain
            params.update({"fmu.kp["+str(outputs)+","+str(inputs)+"]": KY[outputs-1][inputs-1][0]})
             # Integral Gain
            params.update({"fmu.ki["+str(outputs)+","+str(inputs)+"]": KY[outputs-1][inputs-1][1]})
            # Decoupler
            params.update({"fmu.d["+str(outputs)+","+str(inputs)+"]": D[outputs-1][inputs-1]})
            # Set Point Weight
            params.update({"fmu.b["+str(outputs)+","+str(inputs)+"]": B[outputs-1][inputs-1]})
            # Process Parameter 
            # Process Parameter 
            # System Gain
            params.update({"fmu.num["+str(outputs)+","+str(inputs)+",1]": k[outputs-1][inputs-1]})
            # System Lag
            params.update({"fmu.den["+str(outputs)+","+str(inputs)+",1]": t[outputs-1][inputs-1]})
            params.update({"fmu.den["+str(outputs)+","+str(inputs)+",2]": 1})
            # System Delay
            params.update({"fmu.delay["+str(outputs)+","+str(inputs)+"]": l[outputs-1][inputs-1]})

    # Set Parameter Values
    sim.set(params)
    
    # First run, Input 1 -> Output 1 & 2
    sim.resetModelState()
    sim.set({"fmu.u[1]": 1.,"fmu.u[2]": 0.})
    res=sim.simulate(0.05, 150)
    # Second run, Input 2-> Output 1 & 2
    sim.set({"fmu.u[1]": 1.,"fmu.u[2]": 1})
    res=sim.simulate(0.05, 300)

    # Store the output
    y.append([res["fmu.y[1]"],res["fmu.y[2]"]])
    u.append([res["fmu.u[1]"],res["fmu.u[2]"]])
    time.append([res["time"],res["time"]])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3782e5ba-271d-4324-a439-2c8e97937e06">Loading BokehJS ...</span>
#     </div>
# ()

# %%
# Make Aström Reference from Paper
KY = np.array([ [[1.1338, 0.19, 0], [0,0,0]], [[0,0,0], [0.7,0.123,0]] ])
B = np.array([[0,0],[0,0]])
D = np.linalg.inv(k)
print(D)
# Make zeros to 1e-10 for numerical stable process
KY[KY==0] = 1e-10
B[B==0] = 1e-10
D[D==0] = 1e-10


# Load the closed loop model
sim.clear()
sim.loadModel("C:/Users/juliu/Documents/Thesis/Modelica/FMU/2_2/Masterthesis_Models_mimo_0closedloop.fmu")
sim.reloadModel()
# Parameter Values
params = {}
# Loop over system size
for outputs in range(1,3):
    for inputs in range(1,3):
        # Controller Parameter 
        # Proportional Gain
        params.update({"fmu.kp["+str(outputs)+","+str(inputs)+"]": KY[outputs-1][inputs-1][0]})
         # Integral Gain
        params.update({"fmu.ki["+str(outputs)+","+str(inputs)+"]": KY[outputs-1][inputs-1][1]})
        # Decoupler
        params.update({"fmu.d["+str(outputs)+","+str(inputs)+"]": D[outputs-1][inputs-1]})
        # Set Point Weight
        params.update({"fmu.b["+str(outputs)+","+str(inputs)+"]": B[outputs-1][inputs-1]})
        # Process Parameter 
        # System Gain
        params.update({"fmu.num["+str(outputs)+","+str(inputs)+",1]": k[outputs-1][inputs-1]})
        # System Lag
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",1]": t[outputs-1][inputs-1]})
        params.update({"fmu.den["+str(outputs)+","+str(inputs)+",2]": 1})
        # System Delay
        params.update({"fmu.delay["+str(outputs)+","+str(inputs)+"]": l[outputs-1][inputs-1]})
# Set Parameter Values
sim.set(params)
#sim.showParameterDialog()

# First run, t<40
sim.resetModelState()
sim.set({"fmu.u[1]": 1,"fmu.u[2]": 0})
res=sim.simulate(0.1, 150)
# t>=40
sim.set({"fmu.u[1]": 1,"fmu.u[2]": 1})
# Set timestep = 1e-2, endtime = 100
res=sim.simulate(0.1, 300)

from bokeh.layouts import gridplot

p1 = bk.figure(title = "Wood-Berry's Binary Distillation Column", height= 300, width = 800, y_range = (0,1.5))
p1.line(res["time"],res["fmu.y[1]"], color = "grey")
p1.line(time[0][0],y[0][0], color = "red")
p1.line(time[1][0],y[1][0], color = "blue")
p1.line(time[2][0],y[2][0], color = "green")

p2 = bk.figure( height= 300, width = 800, y_range = (-0.5, 1.5))
p2.line(res["time"],res["fmu.y[2]"], color = "grey")
p2.line(time[0][1],y[0][1], color = "red")
p2.line(time[1][1],y[1][1], color = "blue")
p2.line(time[2][1],y[2][1], color = "green")

p = gridplot([[p1],[p2]])
bk.show(p)
# Out:
# [[ 0.15698333 -0.15293737]
#  [ 0.0534067  -0.10357663]]
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8a4fa791-2c5c-44d3-bd06-6ee96ef5fada"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("8a4fa791-2c5c-44d3-bd06-6ee96ef5fada");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8a4fa791-2c5c-44d3-bd06-6ee96ef5fada");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8a4fa791-2c5c-44d3-bd06-6ee96ef5fada' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"de7cbe66-6ab6-40fa-8ebb-91b4e71782f4":{"roots":{"references":[{"attributes":{},"id":"b6ae78a8-1f02-4ae0-9c22-12b3670ce278","type":"HelpTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"992effe4-3c64-4882-9541-d9107f8b1b50","type":"Line"},{"attributes":{},"id":"63bce85f-975f-4885-9653-b9aec9253771","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"ae12b485-c02c-4d71-8d15-e57118370908","type":"BasicTickFormatter"},"plot":{"id":"5b5efce4-f295-4616-8d13-c8f0ee7f6da9","subtype":"Figure","type":"Plot"},"ticker":{"id":"41e681bd-0684-4e1c-aa30-fa76edcc2a9a","type":"BasicTicker"}},"id":"6f301cbd-ccad-4691-9522-a58582e8cd10","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5251acd5-8f47-427d-ad2a-e9584a4679fe","type":"PanTool"},{"id":"ef9a2d9d-b0fd-4c60-9842-b9500284ca60","type":"WheelZoomTool"},{"id":"7f3a1e02-4598-410f-ba31-96ebb982156b","type":"BoxZoomTool"},{"id":"4417a423-44d5-4605-967d-a7a8ada7a203","type":"SaveTool"},{"id":"147b8c75-44b1-45b7-8bf1-0fee274b9fed","type":"ResetTool"},{"id":"43e758f2-7821-4220-af22-cf7f0c8a635b","type":"HelpTool"}]},"id":"f77117e9-0e9b-4e0b-ade6-620a90056cf0","type":"Toolbar"},{"attributes":{},"id":"5251acd5-8f47-427d-ad2a-e9584a4679fe","type":"PanTool"},{"attributes":{"plot":null,"text":"Wood-Berry's Binary Distillation Column"},"id":"4ff065ca-fa8e-4d65-a5fd-51a6151923b3","type":"Title"},{"attributes":{"children":[{"id":"345758a6-3f4f-4d5b-b3eb-c7836a8aaca0","type":"ToolbarBox"},{"id":"fc7261c1-6b45-47ac-9284-3d99ef89d7f8","type":"Column"}]},"id":"a2f90a4b-cf02-4540-8767-d93144fecb00","type":"Column"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c34515fe-6eae-4e98-bd98-f7725ef719d8","type":"Line"},{"attributes":{},"id":"2bb8d75c-2ea4-445f-adfe-5bd43dc81a04","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"5c84f3ad-a8a4-4a1a-a2ad-4ce2e4308fdd","subtype":"Figure","type":"Plot"},"ticker":{"id":"55c5f6ea-520f-4424-933b-82d45e78ed02","type":"BasicTicker"}},"id":"b3a6f875-b181-4dff-80c9-f80c946c7bbb","type":"Grid"},{"attributes":{"data_source":{"id":"acdee79a-e329-443a-b1de-4c9d89141ef6","type":"ColumnDataSource"},"glyph":{"id":"c34515fe-6eae-4e98-bd98-f7725ef719d8","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b99063d5-7954-4d31-ba09-e426a893415a","type":"Line"},"selection_glyph":null,"view":{"id":"a4cee2da-6834-403c-b9ea-1d8e024c1dfd","type":"CDSView"}},"id":"506ca78b-287a-47f1-945a-30c7a38abf9a","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"grey"},"x":{"field":"x"},"y":{"field":"y"}},"id":"419cd9a7-a9ee-4353-b1e7-3cccd564a29d","type":"Line"},{"attributes":{},"id":"fea452ce-e645-43ff-a24d-7a7990744d77","type":"SaveTool"},{"attributes":{"plot":{"id":"5c84f3ad-a8a4-4a1a-a2ad-4ce2e4308fdd","subtype":"Figure","type":"Plot"},"ticker":{"id":"2bb8d75c-2ea4-445f-adfe-5bd43dc81a04","type":"BasicTicker"}},"id":"28c1127b-a238-4fb6-95a7-5111f38b5ec3","type":"Grid"},{"attributes":{"callback":null,"end":1.5},"id":"c4ada603-0faf-4d6a-9f7d-6f3e72c396e5","type":"Range1d"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"930bb74a-e5e1-4b9e-863a-75a86b8e4b28","type":"Line"},{"attributes":{"line_color":{"value":"grey"},"x":{"field":"x"},"y":{"field":"y"}},"id":"eecf0173-a747-456f-8534-28dec1d875fd","type":"Line"},{"attributes":{"callback":null},"id":"6774e4e6-8743-4ca7-8675-7e4ae40b713c","type":"DataRange1d"},{"attributes":{"data_source":{"id":"4ad80c77-6be8-433c-a79b-ff96af9308e3","type":"ColumnDataSource"},"glyph":{"id":"eecf0173-a747-456f-8534-28dec1d875fd","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"17c4c4b1-552c-4b2b-8582-24ff975a6b91","type":"Line"},"selection_glyph":null,"view":{"id":"b119caf9-9ecb-475e-ac1a-d2c59cb10334","type ...

# %%
np.dot(np.dot(K,D),np.transpose(np.add(T,L)))-np.diag(np.max(np.transpose(L),axis=0))
# Out:
# array([[ 14.57087606,  17.89199245],
#        [ 23.86369573,  10.39173184]])

# %%
L,np.max(np.transpose(L),axis=0)
# Out:
# (array([[ 1.02785206,  3.08360155],
#         [ 7.00534209,  3.01178075]]), array([ 3.08360155,  7.00534209]))
