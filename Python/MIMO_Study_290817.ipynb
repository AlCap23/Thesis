# %%
# Import Pandas
import pandas as pd
# Import Numpy
import numpy as np
# Import Bokeh
import bokeh.plotting as bk
import bokeh.io as bi
from bokeh.io import export_svgs
bi.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a4db9757-4d1b-41d0-8363-23ac5a21b2e2">Loading BokehJS ...</span>
#     </div>

# %%
# Read the Data
Data = pd.read_csv('./Experiments/MIMO/MIMO_280817_1.csv', sep=';')
# Give the Columns
Data.columns
# Out:
# Index(['Unnamed: 0', 'Sample No.', 'Order', 'sig_max_cl_D', 'sig_min_cl_D',
#        'sig_max_s_D', 'sig_min_s_D', 'sig_max_cl_A', 'sig_min_cl_A',
#        'sig_max_s_A', 'sig_min_s_A', 'sig_max_cl_M', 'sig_min_cl_M',
#        'sig_max_s_M', 'sig_min_s_M', 'S_D', 'S_A', 'S_M'],
#       dtype='object')

# %%
# Sample Count
msd_sample = Data['sig_max_cl_D']
msd_sample = msd_sample.notnull().sum()

msa_sample = Data['sig_max_cl_A']
msa_sample = msa_sample.notnull().sum()

msm_sample = Data['sig_max_cl_M']
msm_sample = msm_sample.notnull().sum()

# Ist das wirklich nur numerisch oder stabilität!?

# Get Data above a maximum gain of 2 dB
msd_unstable = Data[Data['sig_max_s_D']>10.0]
msd_unstable = msd_unstable['sig_max_s_D'].notnull().sum()

msa_unstable = Data[Data['sig_max_s_A']>10.0]
msa_unstable = msa_unstable['sig_max_s_A'].notnull().sum()

msm_unstable = Data[Data['sig_max_s_M']>10.0]
msm_unstable = msm_unstable['sig_max_s_M'].notnull().sum()

# Print
msd_sample, msa_sample, msm_sample, msd_unstable, msa_unstable, msm_unstable
# Out:
# (8337, 8345, 8337, 599, 1158, 593)

# %% [markdown]
# # Plot the Evaluation

# %%
# select a palette
from bokeh.palettes import Plasma9  as palette
# itertools handles the cycling
import itertools  
from bokeh.models import Range1d, Label

# create a color iterator
colors = itertools.cycle(palette)
# count higher then MS > 5

# Closed loop vs Sensitivity

p2 = bk.figure(title="Decentralized Control", plot_width = 800, plot_height = 800, x_axis_label='Maximum Sensitivity Closed Loop', y_axis_label='Maximum Sensitivity Sensitivity Transfer Function', y_axis_type='log', x_axis_type='log')
for i, color in zip(range(6,0,-1), colors):
    # Load the Data Closed loop
    x = Data[((Data['Order'] == i))]['sig_max_cl_D']
    y = Data[((Data['Order'] == i))]['sig_max_s_D']
    
    p2.scatter(x,y, color = color, alpha = 1, legend='Order '+str(i))

# Get the legend horizontal    
p2.legend.orientation='horizontal'
# Make a copy for later plot
p3 = p2

# Add annotation
label1 = Label(x=50, y=1.0, text='No. of samples: '+str(msd_sample))
#label2 = Label(x=1.4, y=0.975, text='Critical Systems: '+str(msreal_unstable))
p2.add_layout(label1)
#p2.add_layout(label2)
# Show and Export
#p2.output_backend = "svg"
#export_svgs(p2, filename="SISO_Robustness.svg")

bk.show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ae771d64-00f1-4c5b-9049-c13336152e71"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ae771d64-00f1-4c5b-9049-c13336152e71");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ae771d64-00f1-4c5b-9049-c13336152e71");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ae771d64-00f1-4c5b-9049-c13336152e71' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cf2d988f-554c-49d3-8c07-993eaab49b8b":{"roots":{"references":[{"attributes":{"plot":{"id":"e9a9acba-7108-476d-85cc-033d5e4d1435","subtype":"Figure","type":"Plot"}},"id":"a316d40e-f64a-4346-bbf2-71a2f97b02ba","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"cb5e14d9-a142-4588-b741-b037de178857","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"c319190f-fe55-43fc-8f02-61d6be867286","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"1dddd4ca-36ca-4e07-8c6f-9425b1524f21","type":"LogAxis"}],"left":[{"id":"5b16e0d6-a757-48e6-85fa-a2f4eb4d735d","type":"LogAxis"}],"plot_height":800,"plot_width":800,"renderers":[{"id":"1dddd4ca-36ca-4e07-8c6f-9425b1524f21","type":"LogAxis"},{"id":"9fc63c94-468d-48d1-9ded-f8eb7c595b1f","type":"Grid"},{"id":"5b16e0d6-a757-48e6-85fa-a2f4eb4d735d","type":"LogAxis"},{"id":"dfd22979-fec2-4751-aa29-3b92928cff2b","type":"Grid"},{"id":"8bba687a-581b-4c10-90b4-4ff5409a8fed","type":"BoxAnnotation"},{"id":"86ce3dac-212a-4410-9caa-97a00eccade0","type":"Legend"},{"id":"aa88f198-69a5-43bc-80e1-bbee80c53462","type":"GlyphRenderer"},{"id":"89ea1602-2325-4691-8000-b450f7d5a820","type":"GlyphRenderer"},{"id":"44eacdcc-99c6-4c78-bc16-e3dc12a3042b","type":"GlyphRenderer"},{"id":"50f9b01b-eca1-47e2-bc20-b46fa7b15b0d","type":"GlyphRenderer"},{"id":"0b311786-c3ed-494f-8e78-76112ffc24a6","type":"GlyphRenderer"},{"id":"04eefafb-973f-4484-aff3-114050cd4c57","type":"GlyphRenderer"},{"id":"31ea5ca5-8e79-4828-bf8c-7ff4b8a2f63a","type":"Label"}],"title":{"id":"27aa94ef-d040-4513-a0dd-1f015d626918","type":"Title"},"tool_events":{"id":"d1b2ee53-2280-4175-8d66-a79f253161a2","type":"ToolEvents"},"toolbar":{"id":"dc0565f7-1879-4321-9ccb-79747b98036c","type":"Toolbar"},"x_range":{"id":"ed2afa58-8ede-4fd1-806e-b8188ef49246","type":"DataRange1d"},"x_scale":{"id":"6b0807f8-b9c1-4990-9112-f8c878bab5b3","type":"LogScale"},"y_range":{"id":"767fef4d-4729-468d-a4cb-ab2c0ec36200","type":"DataRange1d"},"y_scale":{"id":"dfd5fff7-d039-436b-9c6a-5bf1dc454ad7","type":"LogScale"}},"id":"e9a9acba-7108-476d-85cc-033d5e4d1435","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"767fef4d-4729-468d-a4cb-ab2c0ec36200","type":"DataRange1d"},{"attributes":{},"id":"6b0807f8-b9c1-4990-9112-f8c878bab5b3","type":"LogScale"},{"attributes":{"label":{"value":"Order 4"},"renderers":[{"id":"44eacdcc-99c6-4c78-bc16-e3dc12a3042b","type":"GlyphRenderer"}]},"id":"2e5d5fd4-61f4-472c-83e9-6306a0f52897","type":"LegendItem"},{"attributes":{"plot":{"id":"e9a9acba-7108-476d-85cc-033d5e4d1435","subtype":"Figure","type":"Plot"},"text":"No. of samples: 8337","x":50,"y":1.0},"id":"31ea5ca5-8e79-4828-bf8c-7ff4b8a2f63a","type":"Label"},{"attributes":{"fill_color":{"value":"#A82296"},"line_color":{"value":"#A82296"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f9c3f0d5-f765-4f9c-8a91-b7ac40749228","type":"Circle"},{"attributes":{"plot":{"id":"e9a9acba-7108-476d-85cc-033d5e4d1435","subtype":"Figure","type":"Plot"}},"id":"f7605f4c-c505-4c56-96d3-8e8121f384de","type":"WheelZoomTool"},{"attributes":{"fill_color":{"value":"#7C02A7"},"line_color":{"value":"#7C02A7"},"x":{"field":"x"},"y":{"field":"y"}},"id":"519dd509-2e9e-4d69-8788-d942c2cdd2c2","type":"Circle"},{"attributes":{"fill_color":{"value":"#4A02A0"},"line_color":{"value":"#4A02A0"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc7ab2a1-fd26-42b5-9dd8-519c2c81fb81","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"73dc5d76-edbc-44b4-9ef8-6fd507f2c84a","type":"Circle"},{"attributes":{"callback":null,"column_names":["x"," ...

# %%
# select a palette
from bokeh.palettes import Plasma9  as palette
# itertools handles the cycling
import itertools  
from bokeh.models import Range1d, Label

# create a color iterator
colors = itertools.cycle(palette)
# count higher then MS > 5

# Closed loop vs Sensitivity

p2 = bk.figure(title="Aström Control",plot_width = 800, plot_height = 800, x_axis_label='Maximum Sensitivity Closed Loop', y_axis_label='Maximum Sensitivity Sensitivity Transfer Function', y_axis_type='log', x_axis_type='log')
for i, color in zip(range(6,0,-1), colors):
    # Load the Data Closed loop
    x = Data[((Data['Order'] == i))]['sig_max_cl_A']
    y = Data[((Data['Order'] == i))]['sig_max_s_A']
    
    p2.scatter(x,y, color = color, alpha = 1, legend='Order '+str(i))

# Get the legend horizontal    
p2.legend.orientation='horizontal'
# Make a copy for later plot
p3 = p2

# Add annotation
label1 = Label(x=0.001, y=100.0, text='No. of samples: '+str(msa_sample))
#label2 = Label(x=1.4, y=0.975, text='Critical Systems: '+str(msreal_unstable))
p2.add_layout(label1)
#p2.add_layout(label2)
# Show and Export
#p2.output_backend = "svg"
#export_svgs(p2, filename="SISO_Robustness.svg")

bk.show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0a11195d-ecd5-4e13-a2e8-42753763f471"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0a11195d-ecd5-4e13-a2e8-42753763f471");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0a11195d-ecd5-4e13-a2e8-42753763f471");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0a11195d-ecd5-4e13-a2e8-42753763f471' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0343da0d-5853-4d7e-8d42-f6efd734432a":{"roots":{"references":[{"attributes":{"plot":{"id":"f44a7377-fda6-4fe6-9558-8a74ee6b8d91","subtype":"Figure","type":"Plot"}},"id":"a8e14872-fd9d-4b38-9f8d-50f174d293b7","type":"PanTool"},{"attributes":{"below":[{"id":"8a010424-fb1a-4033-a2c6-41c2f1ea4de9","type":"LogAxis"}],"left":[{"id":"e748a153-852c-4eec-ae3f-d99a33c942a9","type":"LogAxis"}],"plot_height":800,"plot_width":800,"renderers":[{"id":"8a010424-fb1a-4033-a2c6-41c2f1ea4de9","type":"LogAxis"},{"id":"bcf628d5-acf2-4964-97cf-7599f30655ca","type":"Grid"},{"id":"e748a153-852c-4eec-ae3f-d99a33c942a9","type":"LogAxis"},{"id":"0eb6d363-5e42-40c3-8dd5-05b41ec9ab21","type":"Grid"},{"id":"57e5f4b1-2b1e-4acd-b245-df26168a7923","type":"BoxAnnotation"},{"id":"5e0c5ef1-43b3-4ac4-9356-65639388163a","type":"Legend"},{"id":"4b699b1c-fe5d-4691-b67a-63401ac39130","type":"GlyphRenderer"},{"id":"dcc1be9d-4aa1-4c84-aeb0-1de27b7fda0f","type":"GlyphRenderer"},{"id":"ccf3c95b-3664-4f78-8650-805a73eb9300","type":"GlyphRenderer"},{"id":"c777b594-0550-4e94-a5c7-da94981e946b","type":"GlyphRenderer"},{"id":"50195415-af3f-4d33-8957-56046927b9f7","type":"GlyphRenderer"},{"id":"e9d2990e-25ea-4ba9-b585-bd1aa90f5901","type":"GlyphRenderer"},{"id":"1be995df-3ea3-45fc-935d-bb1cee44750f","type":"Label"}],"title":{"id":"2c4d99e4-a3c1-4d8b-b0cd-259d0d146ebc","type":"Title"},"tool_events":{"id":"ad0272c2-26e0-4fe2-ba3b-818fa1e3fc49","type":"ToolEvents"},"toolbar":{"id":"57094398-e1c0-4357-bed5-ccbc8d916de1","type":"Toolbar"},"x_range":{"id":"3212a1da-b8bb-4998-b1f0-a3a17c678f83","type":"DataRange1d"},"x_scale":{"id":"7beaa00f-00ac-4d77-87ca-c9d438ded6b2","type":"LogScale"},"y_range":{"id":"e46c8301-9430-49b9-ba31-f450f0463fae","type":"DataRange1d"},"y_scale":{"id":"bd7ec401-97d9-4b92-bd0b-b5630d7a2aaa","type":"LogScale"}},"id":"f44a7377-fda6-4fe6-9558-8a74ee6b8d91","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"7beaa00f-00ac-4d77-87ca-c9d438ded6b2","type":"LogScale"},{"attributes":{"plot":null,"text":"Astr\u00f6m Control"},"id":"2c4d99e4-a3c1-4d8b-b0cd-259d0d146ebc","type":"Title"},{"attributes":{"data_source":{"id":"7ff7e3cd-9b75-4cce-8a4a-b0f740021c09","type":"ColumnDataSource"},"glyph":{"id":"31e950b9-a92e-40c4-bb88-6961967edea9","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"cda20a37-fbf9-47e2-8bd5-7a0061da4716","type":"Circle"},"selection_glyph":null},"id":"4b699b1c-fe5d-4691-b67a-63401ac39130","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"10a6139e-9096-4038-96d9-c27c096ab6e2","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cda20a37-fbf9-47e2-8bd5-7a0061da4716","type":"Circle"},{"attributes":{"plot":{"id":"f44a7377-fda6-4fe6-9558-8a74ee6b8d91","subtype":"Figure","type":"Plot"}},"id":"708f0f5f-397d-4582-af75-05fe4e76f872","type":"SaveTool"},{"attributes":{"label":{"value":"Order 6"},"renderers":[{"id":"4b699b1c-fe5d-4691-b67a-63401ac39130","type":"GlyphRenderer"}]},"id":"707a11ff-111f-45c7-b276-e61413238515","type":"LegendItem"},{"attributes":{"label":{"value":"Order 2"},"renderers":[{"id":"50195415-af3f-4d33-8957-56046927b9f7","type":"GlyphRenderer"}]},"id":"cccc4f49-2c48-4839-8f8e-8039a549c9ff","type":"LegendItem"},{"attributes":{"data_source":{"id":"5d27e396-23f9-4862-a6b0-a762cbc632d7","type":"ColumnDataSource"},"glyph":{"id":"413ed062-6be1-4b20-bd60-f69bfa771644","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"dff62949-59b9-44c0-8b06-a97f8f872432","type":"Circle"},"selection_glyph":null},"id":"dcc1be9d-4aa1-4c84-aeb0-1de27b7fda0f","type":"GlyphRenderer"},{"attributes":{},"id":"bd7ec401-97d9-4b92-bd0b-b5630d7a2aaa","type":"LogScale" ...

# %%
# select a palette
from bokeh.palettes import Plasma9  as palette
# itertools handles the cycling
import itertools  
from bokeh.models import Range1d, Label

# create a color iterator
colors = itertools.cycle(palette)
# count higher then MS > 5

# Closed loop vs Sensitivity

p2 = bk.figure(title="Decoupled Control",plot_width = 800, plot_height = 800, x_axis_label='Maximum Sensitivity Closed Loop', y_axis_label='Maximum Sensitivity Sensitivity Transfer Function', y_axis_type='log', x_axis_type='log')
for i, color in zip(range(6,0,-1), colors):
    # Load the Data Closed loop
    x = Data[((Data['Order'] == i))]['sig_max_cl_M']
    y = Data[((Data['Order'] == i))]['sig_max_s_M']
    
    p2.scatter(x,y, color = color, alpha = 1, legend='Order '+str(i))

# Get the legend horizontal    
p2.legend.orientation='horizontal'
# Make a copy for later plot
p3 = p2

# Add annotation
label1 = Label(x=50, y=1.0, text='No. of samples: '+str(msm_sample))
#label2 = Label(x=1.4, y=0.975, text='Critical Systems: '+str(msreal_unstable))
p2.add_layout(label1)
#p2.add_layout(label2)
# Show and Export
#p2.output_backend = "svg"
#export_svgs(p2, filename="SISO_Robustness.svg")

bk.show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fa67b7fa-9393-4dcc-a4e8-cdf7d43e8e5d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fa67b7fa-9393-4dcc-a4e8-cdf7d43e8e5d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fa67b7fa-9393-4dcc-a4e8-cdf7d43e8e5d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fa67b7fa-9393-4dcc-a4e8-cdf7d43e8e5d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f55bd090-dd1e-4fe8-8082-150b324f08a3":{"roots":{"references":[{"attributes":{"label":{"value":"Order 2"},"renderers":[{"id":"ce4c92a8-d1d5-4251-91ee-394fcfa6b6dc","type":"GlyphRenderer"}]},"id":"a87b27c6-9a4d-45f9-a212-a062ad746633","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd507187-5be2-4096-996c-b6e576d4a437","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"61367fd0-f3f7-48e2-84b9-e071b08cfb8a","type":"ColumnDataSource"},{"attributes":{"ticker":null},"id":"806b053a-149e-4b08-bf4e-ee852ca51cdd","type":"LogTickFormatter"},{"attributes":{"label":{"value":"Order 1"},"renderers":[{"id":"bf6bf881-c35a-4cc3-a947-ddd06060a562","type":"GlyphRenderer"}]},"id":"8431ab06-1385-4ab5-919f-1f3d19d96713","type":"LegendItem"},{"attributes":{"plot":{"id":"4e3aff53-2289-4132-9500-281434b1d8e3","subtype":"Figure","type":"Plot"}},"id":"5b9e22c6-2db5-47be-8573-9c55cb9a3339","type":"PanTool"},{"attributes":{"data_source":{"id":"20382e0e-9823-4589-b32b-709a0beacb48","type":"ColumnDataSource"},"glyph":{"id":"5a234170-2276-4a99-9395-094d297df23c","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5d4e9fa8-ca96-401c-8b63-c224b5066fe1","type":"Circle"},"selection_glyph":null},"id":"936ab6d8-5e1a-4d1b-b1dd-b567219ad5ba","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"267799b6-4e26-41ce-bf2a-0c3ed3d46781","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ab7f124e-b008-45da-b0be-899abbc10e92","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"e3f62fda-8261-425c-86f9-3a806ebb0a2c","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5d4e9fa8-ca96-401c-8b63-c224b5066fe1","type":"Circle"},{"attributes":{"fill_color":{"value":"#A82296"},"line_color":{"value":"#A82296"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9057d3fb-86b1-481c-9558-6a5b57e5d58d","type":"Circle"},{"attributes":{"fill_color":{"value":"#0C0786"},"line_color":{"value":"#0C0786"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ab7dc05-fd6c-4e45-be83-98ae65998878","type":"Circle"},{"attributes":{"below":[{"id":"9a8c9ac2-f393-4406-af23-28adc3bda314","type":"LogAxis"}],"left":[{"id":"63ddac70-efe0-4f16-9864-afbf8fede0ee","type":"LogAxis"}],"plot_height":800,"plot_width":800,"renderers":[{"id":"9a8c9ac2-f393-4406-af23-28adc3bda314","type":"LogAxis"},{"id":"fda8dcad-4e45-4df0-a8c5-8600a2ec214d","type":"Grid"},{"id":"63ddac70-efe0-4f16-9864-afbf8fede0ee","type":"LogAxis"},{"id":"f37df182-5565-4101-a9e8-9887d735153e","type":"Grid"},{"id":"591ed732-868b-4c98-93de-cfb4586b023b","type":"BoxAnnotation"},{"id":"781f941a-f5f6-48e1-b6cf-d175ebcdf6c7","type":"Legend"},{"id":"68404a3b-9e4f-4415-94bb-4bb6a7107950","type":"GlyphRenderer"},{"id":"936ab6d8-5e1a-4d1b-b1dd-b567219ad5ba","type":"GlyphRenderer"},{"id":"0e555a19-12d1-4f61-929d-b5c62238336d","type":"GlyphRenderer"},{"id":"ab73b812-42d5-4461-a5c8-bfc6d628fdd4","type":"GlyphRenderer"},{"id":"ce4c92a8-d1d5-4251-91ee-394fcfa6b6dc","type":"GlyphRenderer"},{"id":"bf6bf881-c35a-4cc3-a947-ddd06060a562","type":"GlyphRenderer"},{"id":"bc1b1fd9-2995-4833-94a8-16f43e282f0e","type":"L ...

# %%
# Histogram

data1 = Data[Data['sig_max_s_D']<10.0]['sig_max_s_D'].dropna()
data2 = Data[Data['sig_max_s_A']<10.0]['sig_max_s_A'].dropna()
data3 = Data[Data['sig_max_s_M']<10.0]['sig_max_s_M'].dropna()

hist1, edge1 = np.histogram(data1.values , density=False, bins = 100)
hist2, edge2 = np.histogram(data2.values , density=False, bins = 100)
hist3, edge3 = np.histogram(data3.values , density=False, bins = 100)

p1 = bk.figure(title="Maximum Sensitivity Histogram", x_range=(0,10), x_axis_label = "Maximum Sensitivity", y_axis_label =" Samples")
p1.quad(top=hist1, bottom = 0, left=edge1[:-1], right=edge1[1:], color="red", alpha=0.5)
p1.quad(top=hist2, bottom = 0, left=edge2[:-1], right=edge2[1:], color = "green", alpha = 0.5)
p1.quad(top=hist3, bottom = 0, left=edge3[:-1], right=edge3[1:], color = "blue", alpha = 0.5)

bk.show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="de72514c-08fa-4dfa-acdf-f2009b3d8ee2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("de72514c-08fa-4dfa-acdf-f2009b3d8ee2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("de72514c-08fa-4dfa-acdf-f2009b3d8ee2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'de72514c-08fa-4dfa-acdf-f2009b3d8ee2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9ef99d41-714e-4d93-9adb-7dfda3b7d722":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["top","right","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[100]},"right":{"__ndarray__":"...","dtype":"float64","shape":[100]},"top":[106,99,148,284,587,822,866,772,621,478,341,223,200,155,146,115,94,87,80,86,75,57,74,53,33,25,46,43,48,30,33,32,25,34,31,24,23,19,29,21,25,20,17,22,20,16,18,20,13,16,18,17,18,11,18,12,12,12,10,14,21,10,7,18,10,10,16,4,8,10,5,11,7,8,13,7,17,11,11,10,5,8,9,10,4,13,8,8,4,9,8,2,3,11,3,4,2,6,7,12]}},"id":"80541105-76aa-4033-a395-f65c38716183","type":"ColumnDataSource"},{"attributes":{"axis_label":" Samples","formatter":{"id":"9f1b47ed-f099-4661-b035-aa7812089172","type":"BasicTickFormatter"},"plot":{"id":"3f2a494b-9f3f-4b9a-810c-38507cf2955e","subtype":"Figure","type":"Plot"},"ticker":{"id":"920694b7-9ceb-41e1-9735-093b050eac2c","type":"BasicTicker"}},"id":"3ea8a045-b896-4bf8-912e-79718ba59ba4","type":"LinearAxis"},{"attributes":{"data_source":{"id":"80541105-76aa-4033-a395-f65c38716183","type":"ColumnDataSource"},"glyph":{"id":"10d1485a-b00e-4dc7-bac9-600e8b3c175b","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"17fe4d8b-2cc5-4873-934f-502aa7ef7dc9","type":"Quad"},"selection_glyph":null},"id":"b24cc94c-a8f6-47b7-90e6-54e3dae122db","type":"GlyphRenderer"},{"attributes":{},"id":"2d4e04dc-76a8-4369-9265-16b2e28380f3","type":"ToolEvents"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.5},"fill_color":{"value":"blue"},"left":{"field":"left"},"line_alpha":{"value":0.5},"line_color":{"value":"blue"},"right":{"field":"right"},"top":{"field":"top"}},"id":"10d1485a-b00e-4dc7-bac9-600e8b3c175b","type":"Quad"},{"attributes":{},"id":"9f1b47ed-f099-4661-b035-aa7812089172","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["top","right","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[100]},"right":{"__ndarray__":"...","dtype":"float64","shape":[100]},"top":[550,543,493,508,441,421,340,303,249,200,169,183,162,149,138,141,105,95,83,91,73,97,66,60,63,60,48,56,53,52,55,35,45,43,54,40,37,26,29,33,40,29,23,26,32,34,26,29,27,21,21,24,20,23,25,20,15,21,11,13,19,18,15,17,15,8,14,14,20,18,19,19,18,15,12,17,9,17,8,7,13,6,11,10,9,9,8,11,6,5,11,8,8,4,13,6,8,8,5,9]}},"id":"5d5eced4-88af-4422-96d3-a7058fbacf91","type":"ColumnDataSource"},{"attributes":{},"id":"3bb02f0d-c33a-49b4-9ba8-239106618d91","type":"LinearScale"},{"attributes":{"callback":null},"id":"e19a7a2b-99d6-4429-84d1-7bedea61a9b5","type":"DataRange1d"},{"attributes":{"below":[{"id":"1d6a9d62-39ab-4c8f-8952-4b2d82add9dd","type":"LinearAxis"}],"left":[{"id":"3ea8a045-b896-4bf8-912e-79718ba59ba4","type":"LinearAxis"}],"renderers":[{"id":"1d6a9d62-39ab-4c8f-8952-4b2d82add9dd","type":"LinearAxis"},{"id":"6d0d2eee-e07e-46cd-9902-c17650f58302","type":"Grid"},{"id":"3ea8a045-b896-4bf8-912e-79718ba59ba4","type":"LinearAxis"},{"id":"fd1a35ce-1b74-4f43-a0c4-6401965f3916","type":"Grid"},{"id":"eb543e55-efac-45b5-a1fe-72fc1effbe36","type":"BoxAnnotation"},{"id":"448a7207-6887-45bd-91a1-b50b687c8a13","type":"GlyphRenderer"},{"id":"705b22e2-f1a3-49dc-8bf2-93137faac108","type":"GlyphRenderer"},{"id":"b24cc94c-a8f6-47b7-90e6-54e3dae122db","type":"GlyphRenderer"}],"title":{"id":"3b2c1602-ba8a-418c-b87a-3d762daea25a","type":"Title"},"tool_events":{"id":"2d4e04dc-76a8-4369-9265-16b2e28380f3","type":"ToolEvents"},"toolbar":{"id":"50239826-49ec-4654-8207-cdaf948b2c4b","type":"Toolbar"},"x_range":{"id":"aa13c4d6-bbed-4789-b8eb-2273654f0513","type":"Range1d"},"x_scale":{"id":"4608690a-3e2c-4c3c-b709-a8fa1619d713","type":"LinearScale"},"y_range":{"id":"e19a7a2b-99d6-4429-84d1-7bedea61a9b5","type":"DataRange1d"},"y_scale":{"id":"3bb02f0d-c33a-49b4-9ba8-239106618d91","type":"LinearScale"}},"id":"3f2a494b-9f3f-4b9a-810c-38507cf2955e","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"end":10},"id":"aa13c4d6-bbed-4789-b8eb-227 ...

# %%
data1 = Data[Data['Order']<7]['sig_max_s_D'].dropna()
data1 = data1[Data['sig_max_s_D']<10.0]
no1 = data1.notnull().sum()
data2 = Data[Data['Order']<7]['sig_max_s_A'].dropna()
data2 = data2[Data['sig_max_s_A']<10.0]
no2 = data2.notnull().sum()
data3 = Data[Data['Order']<7]['sig_max_s_M'].dropna()
data3 = data3[Data['sig_max_s_M']<10.0]
no3 = data3.notnull().sum()

hist1, edge1 = np.histogram(data1.values , density=False, bins = 100)
hist2, edge2 = np.histogram(data2.values , density=False, bins = 100)
hist3, edge3 = np.histogram(data3.values , density=False, bins = 100)

p1 = bk.figure(title="Maximum Sensitivity Histogram", x_axis_label = "Maximum Sensitivity", y_axis_label =" Samples")
p1.quad(top=hist1, bottom = 0, left=edge1[:-1], right=edge1[1:], color="red", alpha=0.5)
p1.quad(top=hist2, bottom = 0, left=edge2[:-1], right=edge2[1:], color = "green", alpha = 0.5)
p1.quad(top=hist3, bottom = 0, left=edge3[:-1], right=edge3[1:], color = "blue", alpha = 0.5)

# Add annotation
label1 = Label(x=6, y=800.0, text='Decentral Samples '+str(no1))
label2 = Label(x=6, y=750.0, text='Aström Samples '+str(no2))
label3 = Label(x=6, y=700.0, text='Modified Samples '+str(no3))
#label2 = Label(x=1.4, y=0.975, text='Critical Systems: '+str(msreal_unstable))
p1.add_layout(label1)
p1.add_layout(label2)
p1.add_layout(label3)

bk.show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="15de8a95-93c2-4029-95cb-da997e685c82"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("15de8a95-93c2-4029-95cb-da997e685c82");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("15de8a95-93c2-4029-95cb-da997e685c82");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '15de8a95-93c2-4029-95cb-da997e685c82' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"740bc3d2-64d2-457c-99e2-1ab31f81d503":{"roots":{"references":[{"attributes":{"plot":{"id":"cd7cf42c-1d3b-4474-badd-a0c6b4b23ae9","subtype":"Figure","type":"Plot"}},"id":"40401309-3cf1-465e-b583-2db7d631b432","type":"HelpTool"},{"attributes":{"below":[{"id":"3a2ee3f1-7f0c-4878-84e4-63658d078140","type":"LinearAxis"}],"left":[{"id":"16f45119-4591-487a-b9be-e980ed0e3e18","type":"LinearAxis"}],"renderers":[{"id":"3a2ee3f1-7f0c-4878-84e4-63658d078140","type":"LinearAxis"},{"id":"9b0ae764-37bf-47e3-8997-377579d4bb47","type":"Grid"},{"id":"16f45119-4591-487a-b9be-e980ed0e3e18","type":"LinearAxis"},{"id":"93818b9f-3b8e-4b59-bb42-83f67dfbc734","type":"Grid"},{"id":"8f29f2ea-dd63-4795-9eb6-55b3577d6a90","type":"BoxAnnotation"},{"id":"31dc5bd0-dd4e-46c4-aaa9-4dcf306b4c0a","type":"GlyphRenderer"},{"id":"49643d29-b731-498c-a27f-b44eba793f9e","type":"GlyphRenderer"},{"id":"f3cf09b5-6adb-4e0d-a03e-0f56a5f0bbb9","type":"GlyphRenderer"},{"id":"99a20429-1634-4a20-8b43-ff07f6f40e94","type":"Label"},{"id":"8b8d2536-1a81-43d1-9d0d-ee8e9f2ea53a","type":"Label"},{"id":"d196e18f-cc88-47d4-9b6f-db7766b281be","type":"Label"}],"title":{"id":"5b041493-ae82-49ec-ba70-2404da7f126e","type":"Title"},"tool_events":{"id":"034d6a4e-e88d-49e2-b13b-be4317258da0","type":"ToolEvents"},"toolbar":{"id":"046165a1-35fe-46ea-a3a0-5c2dc6088fda","type":"Toolbar"},"x_range":{"id":"f37232a3-6981-4d52-a3ff-26e5bd2b6e02","type":"DataRange1d"},"x_scale":{"id":"0efc6398-0dd4-43c1-8c19-f24b8f1f8be7","type":"LinearScale"},"y_range":{"id":"049da219-f9e7-4e81-aa29-2e55809d92fd","type":"DataRange1d"},"y_scale":{"id":"5676893a-bde0-44e9-a3e8-ffdd1c8c4fab","type":"LinearScale"}},"id":"cd7cf42c-1d3b-4474-badd-a0c6b4b23ae9","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"5676893a-bde0-44e9-a3e8-ffdd1c8c4fab","type":"LinearScale"},{"attributes":{"callback":null},"id":"049da219-f9e7-4e81-aa29-2e55809d92fd","type":"DataRange1d"},{"attributes":{"plot":{"id":"cd7cf42c-1d3b-4474-badd-a0c6b4b23ae9","subtype":"Figure","type":"Plot"},"text":"Astr\u00f6m Samples 5173","x":6,"y":750.0},"id":"8b8d2536-1a81-43d1-9d0d-ee8e9f2ea53a","type":"Label"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8d1e458a-0e76-419a-904f-8b4e50d1d8ab","type":"PanTool"},{"id":"2c467fbc-c13b-4046-b787-9324972c1b23","type":"WheelZoomTool"},{"id":"5efc6cbd-a415-4acb-98e0-79dafa4adf89","type":"BoxZoomTool"},{"id":"c28d4367-0e25-4bc7-a0a1-ea7786b64727","type":"SaveTool"},{"id":"14196d6d-b778-43c7-97f5-1e25cc3452f6","type":"ResetTool"},{"id":"40401309-3cf1-465e-b583-2db7d631b432","type":"HelpTool"}]},"id":"046165a1-35fe-46ea-a3a0-5c2dc6088fda","type":"Toolbar"},{"attributes":{"data_source":{"id":"3618caa6-5ff8-4a8e-80fe-812b3fa933eb","type":"ColumnDataSource"},"glyph":{"id":"62fb4e5e-55ab-4b15-8492-477784e0db5c","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3979b851-fd2c-45c9-aef2-759d7c538465","type":"Quad"},"selection_glyph":null},"id":"49643d29-b731-498c-a27f-b44eba793f9e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["top","right","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[100]},"right":{"__ndarray__":"...","dtype":"float64","shape":[100]},"top":[208,347,249,239,557,792,758,665,526,339,229,135,106,89,82,63,39,49,40,25,39,19,25,16,15,14,17,22,16,7,9,9,11,10,6,7,6,7,3,6,5,8,4,5,6,4,6,6,2,5,1,3,2,4,4,4,4,3,4,1,2,3,3,1,2,1,0,3,0,2,1,0,1,0,0,0,0,1,1,2,1,0,0,3,2,2,2,2,2,1,1,0,0,0,0,2,1,0,1,3]}},"id":"9a08b32f-947d-44b8-a751-9d0244ce7267","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"655d068a-d971-48cb-9fdb-87e124ec1973","type":"Quad"},{"attributes":{},"id":"034d6a4e-e88d-49e2-b13b-be4317258da0","type":"ToolEvents"},{"attri ...

# %%
no1,no2,no3
# Out:
# (5928, 5173, 5939)
